# %%
import csv
import timeit
import datetime
from pyspark.sql.types import *
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
import matplotlib.pyplot as plt
import pandas as pd
import os
from pyspark.sql import Window, Column
spark = SparkSession \
    .builder \
    .appName("Python Spark SQL basic example") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()
folder = "book/"

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("somnambwl/bookcrossing-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/somnambwl/bookcrossing-dataset?dataset_version_number=1...
# 100%|██████████| 16.8M/16.8M [00:01<00:00, 10.9MB/s]
# Extracting files...
# Path to dataset files: /home/zhijie/.cache/kagglehub/datasets/somnambwl/bookcrossing-dataset/versions/1

# %%
def filter_data(line):
    if 'User' in line:
        return False
    return True

def split_data(data):
    datas = data.split(';')
    ISBN = datas[1].strip().strip("'").strip("\\").strip('"').strip("#").strip("(").strip(")")
    return int(datas[0]), ISBN, int(datas[2])

book_fields = [
    StructField("ISBN", StringType(), False), StructField("Title", StringType(), False), StructField("Author", StringType(), False),
    StructField("Year", IntegerType(), False), StructField("Publisher", StringType(), False)
]
book_schema = StructType(book_fields)

rating_fields = [
    StructField("UserId", IntegerType(), False), StructField("ISBN", StringType(), False), StructField("Rating", IntegerType(), True)
]
rating_schema = StructType(rating_fields)

user_fields = [
    StructField("UserId", IntegerType(), False), StructField("Age", IntegerType(), True)
]
user_schema = StructType(user_fields)

if not os.path.exists(folder + "Books.parquet"):
    data = spark.read.csv(folder+"Books.csv", header=True, schema=book_schema, sep=";")
    data.write.save(folder+"Books.parquet")

if not os.path.exists(folder + "Ratings.parquet"):
    from pyspark import SparkContext
    sc = SparkContext.getOrCreate()
    data = spark.createDataFrame(sc.textFile(folder+'Ratings.csv', 8).filter(filter_data).map(split_data), rating_schema)
    data.write.save(folder+"Ratings.parquet")

if not os.path.exists(folder + "Users.parquet"):
    data = spark.read.csv(folder+"Users.csv", header=True, schema=user_schema, sep=";")
    data.write.save(folder+"Users.parquet")

# %%
books = spark.read.load(folder+"Books.parquet").distinct()
ratings = spark.read.load(folder+"Ratings.parquet").distinct()
users = spark.read.load(folder+"Users.parquet").distinct().fillna({"age": 0})

join = users.join(ratings, 'UserId', 'inner')
data = join.join(books, 'ISBN', 'inner')

print("Books:", books.count())
print("Ratings:", ratings.count())
print("Users:", users.count())
print("Joined:", join.count())
print("Joined:", data.count())
# Out:
# Books: 271378
# Ratings: 1149780
# Users: 278859
# Joined: 1149780
# Joined: 1031178
# 24/12/23 17:13:47 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
data.show(10)
# Out:
# +----------+------+---+------+--------------------+-----------+----+--------------------+
# |      ISBN|UserId|Age|Rating|               Title|     Author|Year|           Publisher|
# +----------+------+---+------+--------------------+-----------+----+--------------------+
# |0440201101|  3177| 44|     0|More Die of Heart...|Saul Bellow|1988|Dell Publishing C...|
# |      NULL|  1173| 22|  NULL|                NULL|       NULL|NULL|                NULL|
# |      NULL|  1657| 59|  NULL|                NULL|       NULL|NULL|                NULL|
# |      NULL|  1662| 25|  NULL|                NULL|       NULL|NULL|                NULL|
# |      NULL|  2342| 60|  NULL|                NULL|       NULL|NULL|                NULL|
# |      NULL|  2408| 33|  NULL|                NULL|       NULL|NULL|                NULL|
# |      NULL|  2874| 19|  NULL|                NULL|       NULL|NULL|                NULL|
# |      NULL|  3182| 19|  NULL|                NULL|       NULL|NULL|                NULL|
# |      NULL|   583| 19|  NULL|                NULL|       NULL|NULL|                NULL|
# |      NULL|   812| 17|  NULL|                NULL|       NULL|NULL|                NULL|
# +----------+------+---+------+--------------------+-----------+----+--------------------+
# only showing top 10 rows

# %%
data.filter("author IS NULL").show(100)
# Out:
# 24/12/22 23:27:49 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# +-------------+------+---+------+-----+------+----+---------+
# |         ISBN|UserId|Age|Rating|Title|Author|Year|Publisher|
# +-------------+------+---+------+-----+------+----+---------+
# |0 440 20615 4| 71726| 18|     9| NULL|  NULL|NULL|     NULL|
# |0 7525 1962 x|266641|  0|     0| NULL|  NULL|NULL|     NULL|
# |0.380.44099.7| 20919|  0|    10| NULL|  NULL|NULL|     NULL|
# | 000000046565|159014|  0|     1| NULL|  NULL|NULL|     NULL|
# | 000001246971|213324| 48|     0| NULL|  NULL|NULL|     NULL|
# | 000001246971| 11776| 31|     8| NULL|  NULL|NULL|     NULL|
# | 000001246971|268423| 42|     8| NULL|  NULL|NULL|     NULL|
# |  0000225820X|242060| 50|     5| NULL|  NULL|NULL|     NULL|
# |  00006715885| 33759|  0|     0| NULL|  NULL|NULL|     NULL|
# |  00006715885|158856|  0|     0| NULL|  NULL|NULL|     NULL|
# |   0001604465|168387| 32|     0| NULL|  NULL|NULL|     NULL|
# |   000185741X|125774| 36|     8| NULL|  NULL|NULL|     NULL|
# |   0001911619| 94853| 27|    10| NULL|  NULL|NULL|     NULL|
# |   0002006758|148199| 50|     8| NULL|  NULL|NULL|     NULL|
# |   0002173743| 23288|  0|     0| NULL|  NULL|NULL|     NULL|
# |   0002226936| 42400|  0|     0| NULL|  NULL|NULL|     NULL|
# |   000223999X| 69636|  0|     0| NULL|  NULL|NULL|     NULL|
# |   0002241471| 77153| 35|     8| NULL|  NULL|NULL|     NULL|
# |   0002241471|200746| 20|     0| NULL|  NULL|NULL|     NULL|
# |   0002246759| 96554| 36|     0| NULL|  NULL|NULL|     NULL|
# |   0002246953|177458| 29|     0| NULL|  NULL|NULL|     NULL|
# |   000225672X| 54622|  0|     8| NULL|  NULL|NULL|     NULL|
# |   0002259044|258152| 29|     0| NULL|  NULL|NULL|     NULL|
# |   0002259044|177458| 29|     0| NULL|  NULL|NULL|     NULL|
# |   0002259923| 29528| 22|     7| NULL|  NULL|NULL|     NULL|
# |   0002261537| 86033| 26|     7| NULL|  NULL|NULL|     NULL|
# |   0002261758|245182| 35|     0| NULL|  NULL|NULL|     NULL|
# |   0002261758|213663|  0|     0| NULL|  NULL|NULL|     NULL|
# |   0002313219|203820| 31|     7| NULL|  NULL|NULL|     NULL|
# |   0002571110| 42400|  0|     0| NULL|  NULL|NULL|     NULL|
# |   0002571579| 56271| 22|     0| NULL|  NULL|NULL|     NULL|
# |   0002611503| 42594| 40|     0| NULL|  NULL|NULL|     NULL|
# |000276983II20| 79459| 21|     0| NULL|  NULL|NULL|     NULL|
# |   0003750450| 60787|  0|     0| NULL|  NULL|NULL|     NULL|
# |   0004125479|266866| 33|     7| NULL|  NULL|NULL|     NULL|
# |   0004244117|170184| 51|    10| NULL|  NULL|NULL|     NULL|
# |   0005477097|249924| 38|     0| NULL|  NULL|NULL|     NULL|
# |   000609405X|193560| 37|     0| NULL|  NULL|NULL|     NULL|
# |   0006127754|144131| 39|     0| NULL|  NULL|NULL|     NULL|
# |   0006127754|231857| 46|     8| NULL|  NULL|NULL|     NULL|
# |   0006127754|167007| 23|     8| NULL|  NULL|NULL|     NULL|
# |   0006127754|222716|  0|     0| NULL|  NULL|NULL|     NULL|
# |   0006127754| 11676|  0|     7| NULL|  NULL|NULL|     NULL|
# |   0006130410|144131| 39|     0| NULL|  NULL|NULL|     NULL|
# |   0006134890|266866| 33|     0| NULL|  NULL|NULL|     NULL|
# |   0006142516|175886| 52|     0| NULL|  NULL|NULL|     NULL|
# |   0006142567|175886| 52|     0| NULL|  NULL|NULL|     NULL|
# |   0006159532|116031| 46|     5| NULL|  NULL|NULL|     NULL|
# |   0006161731| 30509| 51|     0| NULL|  NULL|NULL|     NULL|
# |   0006161731|147462| 36|     0| NULL|  NULL|NULL|     NULL|
# |   0006161731|205276| 31|     8| NULL|  NULL|NULL|     NULL|
# |   0006162746| 56271| 22|    10| NULL|  NULL|NULL|     NULL|
# |   0006162746|266866| 33|     0| NULL|  NULL|NULL|     NULL|
# |   0006162754| 17646| 40|     0| NULL|  NULL|NULL|     NULL|
# |   0006163769| 43246| 36|     0| NULL|  NULL|NULL|     NULL|
# |   0006165516| 78973| 29|     8| NULL|  NULL|NULL|     NULL|
# |   0006165516|252674| 16|     7| NULL|  NULL|NULL|     NULL|
# |   0006166512|182881| 23|    10| NULL|  NULL|NULL|     NULL|
# |   0006166512|263344| 17|     0| NULL|  NULL|NULL|     NULL|
# |   0006167144| 78973| 29|     8| NULL|  NULL|NULL|     NULL|
# |   0006167446| 25048|  0|     0| NULL|  NULL|NULL|     NULL|
# |   0006167632|144131| 39|     0| NULL|  NULL|NULL|     NULL|
# |   0006167632|225986| 36|     0| NULL|  NULL|NULL|     NULL|
# |   0006169309| 41731| 29|     0| NULL|  NULL|NULL|     NULL|
# |    000616984|260448|  0|     0| NULL|  NULL|NULL|     NULL|
# |   0006171583|180707| 46|     0| NULL|  NULL|NULL|     NULL|
# |   0006171583|231857| 46|     0| NULL|  NULL|NULL|     NULL|
# |   0006171583|227276| 41|     6| NULL|  NULL|NULL|     NULL|
# |   000617342X|227835| 52|     2| NULL|  NULL|NULL|     NULL|
# |   0006174183| 16943|  0|     0| NULL|  NULL|NULL|     NULL|
# |   0006174442|175886| 52|     0| NULL|  NULL|NULL|     NULL|
# |   0006174760| 23902|  0|     6| NULL|  NULL|NULL|     NULL|
# |   0006174789|131402|  0|     0| NULL|  NULL|NULL|     NULL|
# |   0006174795|145644| 24|     5| NULL|  NULL|NULL|     NULL|
# |   0006178227|193560| 37|     0| NULL|  NULL|NULL|     NULL|
# |   0006179088| 67079| 35|     9| NULL|  NULL|NULL|     NULL|
# |   0006179088| 25217|  0|     8| NULL|  NULL|NULL|     NULL|
# |   0006179851|147462| 36|     0| NULL|  NULL|NULL|     NULL|
# |   0006333710|251605|101|     0| NULL|  NULL|NULL|     NULL|
# |   0006334075|229329| 56|     7| NULL|  NULL|NULL|     NULL|
# |   0006363997|225232|  4|     0| NULL|  NULL|NULL|     NULL|
# |   0006367534| 29401|  0|     1| NULL|  NULL|NULL|     NULL|
# |   0006367534|231857| 46|     7| NULL|  NULL|NULL|     NULL|
# |   0006367534|104657| 25|     0| NULL|  NULL|NULL|     NULL|
# |   0006367534|  6092|  0|     0| NULL|  NULL|NULL|     NULL|
# |   0006384986|177458| 29|     0| NULL|  NULL|NULL|     NULL|
# |   0006387462| 76626| 38|    10| NULL|  NULL|NULL|     NULL|
# |   0006392105| 28077| 58|     0| NULL|  NULL|NULL|     NULL|
# |   0006471250|201290| 35|     5| NULL|  NULL|NULL|     NULL|
# |   0006471250|134837| 28|     5| NULL|  NULL|NULL|     NULL|
# |   0006473342|192514| 69|     0| NULL|  NULL|NULL|     NULL|
# |   0006473342|158618|  0|     6| NULL|  NULL|NULL|     NULL|
# |   0006473342|163608| 31|     0| NULL|  NULL|NULL|     NULL|
# |   0006475973| 74725| 24|     7| NULL|  NULL|NULL|     NULL|
# |   0006475973|180651| 54|     7| NULL|  NULL|NULL|     NULL|
# |   0006475973|227835| 52|     0| NULL|  NULL|NULL|     NULL|
# |   0006475973|249250| 38|     7| NULL|  NULL|NULL|     NULL|
# |   0006475973| 25533| 38|     0| NULL|  NULL|NULL|     NULL|
# |   0006475973|244708|  0|     0| NULL|  NULL|NULL|     NULL|
# |   0006475973|147156| 42|     0| NULL|  NULL|NULL|     NULL|
# +-------------+------+---+------+-----+------+----+---------+
# only showing top 100 rows

# %%
data = users.join(ratings, 'UserId', 'left')
data.groupBy("UserId").agg(F.count(F.when(data.ISBN.isNotNull(), 1)).alias("BookCount")).orderBy("BookCount", ascending=False).collect()
# Out:
# 278859

# %%
data = books.join(ratings, 'ISBN', 'left')
data.groupBy("publisher").agg(F.max(data.Rating)).collect()
# Out:
# [Row(publisher='Harper Mass Market Paperbacks (Mm)', max(Rating)=10),
#  Row(publisher='LPC Group', max(Rating)=9),
#  Row(publisher='Chicago Review Press', max(Rating)=10),
#  Row(publisher='Adams Media Corp', max(Rating)=10),
#  Row(publisher='Celestial Arts', max(Rating)=10),
#  Row(publisher='Cleis Press', max(Rating)=10),
#  Row(publisher='Chosen Books', max(Rating)=10),
#  Row(publisher='Carroll &amp; Graf Publishers', max(Rating)=10),
#  Row(publisher='Aqua Explorers', max(Rating)=9),
#  Row(publisher='Houghton Mifflin Co (Jp)', max(Rating)=10),
#  Row(publisher='Ramana Pubn', max(Rating)=0),
#  Row(publisher='Regina Press Malhame & Company', max(Rating)=9),
#  Row(publisher='Joshua Odell Editions Capra Press', max(Rating)=10),
#  Row(publisher='No Exit Press', max(Rating)=7),
#  Row(publisher='Lorenz Books', max(Rating)=10),
#  Row(publisher='High Country Publishers', max(Rating)=10),
#  Row(publisher='Ediciones Alfaguara, S.A.', max(Rating)=10),
#  Row(publisher='Ullstein-Taschenbuch-Verlag, Zweigniederlassung der Ullstein Buchverlage GmbH', max(Rating)=10),
#  Row(publisher='Faith Publishing Company', max(Rating)=8),
#  Row(publisher='Daughters, inc.]', max(Rating)=10),
#  Row(publisher='Paidos', max(Rating)=0),
#  Row(publisher='Doubleday', max(Rating)=10),
#  Row(publisher='Moody Pr', max(Rating)=10),
#  Row(publisher='G.K. Hall', max(Rating)=7),
#  Row(publisher='Dtv', max(Rating)=10),
#  Row(publisher='Roc', max(Rating)=10),
#  Row(publisher='Verso', max(Rating)=10),
#  Row(publisher='Eden Studios, Inc.', max(Rating)=10),
#  Row(publisher="McGraw-Hill Children's Publishing", max(Rating)=10),
#  Row(publisher='Texas Bookman', max(Rating)=9),
#  Row(publisher='Franciscan University Press', max(Rating)=9),
#  Row(publisher='Love Line Books', max(Rating)=10),
#  Row(publisher='Apricot Press', max(Rating)=8),
#  Row(publisher="St. Martin's True Crime Classics", max(Rating)=10),
#  Row(publisher='High Plains Press', max(Rating)=10),
#  Row(publisher='Zero-G Press', max(Rating)=5),
#  Row(publisher='Harpertorch', max(Rating)=10),
#  Row(publisher='Story Line Press', max(Rating)=9),
#  Row(publisher='Editorial Kairos', max(Rating)=10),
#  Row(publisher='Liberty Pub. Co', max(Rating)=0),
#  Row(publisher='Checkerboard Books', max(Rating)=5),
#  Row(publisher='Saqi Books', max(Rating)=9),
#  Row(publisher='Harper & Row', max(Rating)=10),
#  Row(publisher='Ivy Books', max(Rating)=10),
#  Row(publisher='Auer', max(Rating)=0),
#  Row(publisher='Viking Penguin', max(Rating)=10),
#  Row(publisher='Editions Flammarion', max(Rating)=10),
#  Row(publisher='Clear Light Books', max(Rating)=10),
#  Row(publisher='Course Technology Ptr', max(Rating)=10),
#  Row(publisher='Disney Pr', max(Rating)=10),
#  Row(publisher='Northstone Publishing', max(Rating)=7),
#  Row(publisher='Pottersfield Press', max(Rating)=10),
#  Row(publisher='Yale Univ Pr', max(Rating)=10),
#  Row(publisher='Stewart Publishing', max(Rating)=10),
#  Row(publisher='Editorial Anagrama', max(Rating)=10),
#  Row(publisher='Codhill Press', max(Rating)=10),
#  Row(publisher='Key Porter Books', max(Rating)=10),
#  Row(publisher='Harcourt Religious Publishers', max(Rating)=10),
#  Row(publisher='Laura Geringer', max(Rating)=10),
#  Row(publisher='T J Publishers, Incorporated', max(Rating)=10),
#  Row(publisher='Dove Books Audio', max(Rating)=9),
#  Row(publisher='Hylas Publishing', max(Rating)=10),
#  Row(publisher='J.M. Dent', max(Rating)=8),
#  Row(publisher='Time Warner Audio Books', max(Rating)=10),
#  Row(publisher='Insel', max(Rating)=9),
#  Row(publisher='Cleveland State Univ Poetry Center', max(Rating)=10),
#  Row(publisher='HarperTrophy', max(Rating)=10),
#  Row(publisher='Whitecap Books', max(Rating)=10),
#  Row(publisher='Paragon House Publishers', max(Rating)=10),
#  Row(publisher='Manoa Press', max(Rating)=0),
#  Row(publisher='Knightsbridge Pub Co Mass', max(Rating)=8),
#  Row(publisher='W. Kohlhammer', max(Rating)=8),
#  Row(publisher='Constable Robinson', max(Rating)=10),
#  Row(publisher='Catbird Press', max(Rating)=10),
#  Row(publisher='J. P. Tarcher; distributed by Hawthorn Books, New York', max(Rating)=7),
#  Row(publisher='Bookthrift', max(Rating)=10),
#  Row(publisher='Quail Ridge Press', max(Rating)=9),
#  Row(publisher='Editora Guanabara', max(Rating)=9),
#  Row(publisher='Sterling*+ Publishing Company', max(Rating)=10),
#  Row(publisher='Jane Yolen Books', max(Rating)=7),
#  Row(publisher='Paper Tiger', max(Rating)=10),
#  Row(publisher='Senate', max(Rating)=10),
#  Row(publisher='Phoenix', max(Rating)=9),
#  Row(publisher='Timberholme Books Ltd.', max(Rating)=0),
#  Row(publisher='Barnes &amp; Noble Books', max(Rating)=10),
#  Row(publisher='American Diabetes Association', max(Rating)=9),
#  Row(publisher='Lerner Pub Group (T)', max(Rating)=9),
#  Row(publisher='Morrow Cookbooks', max(Rating)=10),
#  Row(publisher="Random House Children's Books", max(Rating)=10),
#  Row(publisher='Continuum International Publishing Group', max(Rating)=10),
#  Row(publisher='Grosset & Dunlap', max(Rating)=10),
#  Row(publisher='Nick Varner', max(Rating)=0),
#  Row(publisher='Visible Ink Press', max(Rating)=10),
#  Row(publisher='Walker Large Print', max(Rating)=10),
#  Row(publisher='Alpha Books', max(Rating)=10),
#  Row(publisher='Distribooks', max(Rating)=10),
#  Row(publisher='Conran Octopus', max(Rating)=4),
#  Row(publisher='J Countryman Books', max(Rating)=10),
#  Row(publisher="Child's World", max(Rating)=10),
#  Row(publisher='A.T.E', max(Rating)=0),
#  Row(publisher='Information USA', max(Rating)=9),
#  Row(publisher='Volcano Pr', max(Rating)=0),
#  Row(publisher='Diogenes', max(Rating)=10),
#  Row(publisher='Reward Books', max(Rating)=10),
#  Row(publisher='Edimat Libros', max(Rating)=10),
#  Row(publisher='Anchor Press', max(Rating)=10),
#  Row(publisher='Soggy Cracker Press', max(Rating)=0),
#  Row(publisher="Scribner's", max(Rating)=8),
#  Row(publisher='University of Iowa Press', max(Rating)=10),
#  Row(publisher='Calmann-LÃ?Â©vy', max(Rating)=10),
#  Row(publisher='Time Inc Home Entertainment', max(Rating)=10),
#  Row(publisher='Vintage Of Random House', max(Rating)=7),
#  Row(publisher="Karen Brown's Guides", max(Rating)=7),
#  Row(publisher='Alpine Publications, Inc.', max(Rating)=8),
#  Row(publisher='Odile Jacob', max(Rating)=10),
#  Row(publisher='Atheneum Books', max(Rating)=10),
#  Row(publisher='Landoll, Inc', max(Rating)=0),
#  Row(publisher='Harpercollins', max(Rating)=10),
#  Row(publisher='LÃ?Â¼bbe', max(Rating)=10),
#  Row(publisher='North American Fishing Club', max(Rating)=10),
#  Row(publisher='Alfred A. Knopf', max(Rating)=10),
#  Row(publisher='Sterling Publishing', max(Rating)=10),
#  Row(publisher='Columbia University Press', max(Rating)=10),
#  Row(publisher='AAAI Press', max(Rating)=0),
#  Row(publisher='Collins Harvill', max(Rating)=0),
#  Row(publisher='RX Humor', max(Rating)=6),
#  Row(publisher='Atheneum/Richard Jackson Books', max(Rating)=10),
#  Row(publisher='le Livre de poche', max(Rating)=7),
#  Row(publisher='VÃ\xada LÃ¡ctea', max(Rating)=0),
#  Row(publisher='Gallimard-Jeunesse', max(Rating)=9),
#  Row(publisher='Phoenix mass market p/bk', max(Rating)=10),
#  Row(publisher='Perseus Publishing', max(Rating)=10),
#  Row(publisher='Arch Books', max(Rating)=0),
#  Row(publisher='Intercontinental Publishing', max(Rating)=7),
#  Row(publisher='Jarrold Publishing', max(Rating)=10),
#  Row(publisher="Orion Children's", max(Rating)=8),
#  Row(publisher='Bibliographisches Institut, Mannheim', max(Rating)=10),
#  Row(publisher='Kingdom Publishing', max(Rating)=0),
#  Row(publisher='Siloam Press', max(Rating)=0),
#  Row(publisher='Heinemann Educational Books - Secondary Division', max(Rating)=10),
#  Row(publisher='Editions du Seuil', max(Rating)=10),
#  Row(publisher='Fleuve Noir', max(Rating)=6),
#  Row(publisher='Clothespin Fever Press', max(Rating)=10),
#  Row(publisher='Sterling', max(Rating)=10),
#  Row(publisher='Smith & Kraus', max(Rating)=10),
#  Row(publisher='South End Press', max(Rating)=10),
#  Row(publisher='Thomas Nelson(J)', max(Rating)=10),
#  Row(publisher='Harri Deutsch, Ffm.', max(Rating)=10),
#  Row(publisher='Edward Arnold', max(Rating)=9),
#  Row(publisher='Mercury Press (Canada)', max(Rating)=8),
#  Row(publisher='Edicions de la Magrana', max(Rating)=9),
#  Row(publisher='Barricade Books', max(Rating)=10),
#  Row(publisher='Ogden Pub Inc', max(Rating)=10),
#  Row(publisher='Fog City Press', max(Rating)=10),
#  Row(publisher='Quadrillion Publishing', max(Rating)=10),
#  Row(publisher='Delair Pub Co', max(Rating)=8),
#  Row(publisher='Scholastic Hippo', max(Rating)=9),
#  Row(publisher='Scholastic, Inc', max(Rating)=10),
#  Row(publisher='Good News Pub', max(Rating)=8),
#  Row(publisher='Distribooks Inc', max(Rating)=10),
#  Row(publisher='Geographia Ltd', max(Rating)=7),
#  Row(publisher='Attic Press', max(Rating)=9),
#  Row(publisher='Thewaryeye.Com', max(Rating)=10),
#  Row(publisher='Egmont EHAPA Verlag GmbH', max(Rating)=0),
#  Row(publisher='Hachette LittÃ?Â©rature', max(Rating)=10),
#  Row(publisher='Teacher Created Materials', max(Rating)=10),
#  Row(publisher='Sowelu Pr', max(Rating)=0),
#  Row(publisher='Uglytown Productions', max(Rating)=8),
#  Row(publisher='Audioworks', max(Rating)=10),
#  Row(publisher='Quartet Books (UK)', max(Rating)=7),
#  Row(publisher='Ediciones', max(Rating)=0),
#  Row(publisher='Amer Psychological Assn', max(Rating)=10),
#  Row(publisher='Synergy Pub', max(Rating)=7),
#  Row(publisher='New Millenium Pr', max(Rating)=8),
#  Row(publisher='Prentice Hall (K-12)', max(Rating)=10),
#  Row(publisher='Iso Production Inc', max(Rating)=8),
#  Row(publisher="Women's Health Boutique", max(Rating)=0),
#  Row(publisher='Harcourt Brace College Publishers', max(Rating)=10),
#  Row(publisher='Winter Press', max(Rating)=None),
#  Row(publisher='Not Avail', max(Rating)=10),
#  Row(publisher='Roberts Rinehart Publishers', max(Rating)=10),
#  Row(publisher='Fischer (Tb.), Frankfurt', max(Rating)=10),
#  Row(publisher='Pantheon', max(Rating)=10),
#  Row(publisher='Penguin USA (Paper)', max(Rating)=10),
#  Row(publisher='Library of America', max(Rating)=10),
#  Row(publisher='Editech Pr', max(Rating)=7),
#  Row(publisher="Antique Collectors' Club", max(Rating)=10),
#  Row(publisher='Shire Publications', max(Rating)=10),
#  Row(publisher='Quirk Books', max(Rating)=10),
#  Row(publisher="Traveler's Tales", max(Rating)=10),
#  Row(publisher='Benedikt Taschen Verlag', max(Rating)=10),
#  Row(publisher='Hayden Book Co', max(Rating)=8),
#  Row(publisher='Hambledon & London', max(Rating)=8),
#  Row(publisher='Unity Books (Unity School of Christianity)', max(Rating)=10),
#  Row(publisher='R. Brent & Company', max(Rating)=10),
#  Row(publisher='Picador', max(Rating)=10),
#  Row(publisher='Peter Pauper Pr', max(Rating)=10),
#  Row(publisher='Owl Publishing Company', max(Rating)=10),
#  Row(publisher='W.B. Saunders Company', max(Rating)=10),
#  Row(publisher='Harvest House Pub', max(Rating)=10),
#  Row(publisher='University of New Mexico Press', max(Rating)=10),
#  Row(publisher='McGraw-Hill Trade', max(Rating)=10),
#  Row(publisher='TV Books', max(Rating)=10),
#  Row(publisher='Pocket Star', max(Rating)=10),
#  Row(publisher='Pearson Higher Education', max(Rating)=10),
#  Row(publisher='New York Univ Pr', max(Rating)=9),
#  Row(publisher='Thorsons Publishers', max(Rating)=10),
#  Row(publisher='Grupo Zeta', max(Rating)=9),
#  Row(publisher='Hill & Wang', max(Rating)=10),
#  Row(publisher='Krause Publications', max(Rating)=10),
#  Row(publisher='T.Y. Crowell Junior Books', max(Rating)=0),
#  Row(publisher='L.A. Weekly Books', max(Rating)=10),
#  Row(publisher='Fanpro', max(Rating)=10),
#  Row(publisher='Harlequin Sales Corp (Mm)', max(Rating)=8),
#  Row(publisher='Bruce Sims Books', max(Rating)=7),
#  Row(publisher='Blackstaff Press Ltd', max(Rating)=9),
#  Row(publisher='Sparknotes', max(Rating)=10),
#  Row(publisher='Barbour Bargain Books', max(Rating)=10),
#  Row(publisher='Fredonia Books (NL)', max(Rating)=10),
#  Row(publisher='Jessica Kingsley Publishers', max(Rating)=10),
#  Row(publisher='Greenhaven Press', max(Rating)=10),
#  Row(publisher='Association for Supervision & Curriculum Deve', max(Rating)=10),
#  Row(publisher='BRAVA', max(Rating)=10),
#  Row(publisher='Onder protectoraat van Uitgeverij Atlas', max(Rating)=8),
#  Row(publisher='C. Reality Publishers', max(Rating)=5),
#  Row(publisher='Gospel Light Pubns', max(Rating)=10),
#  Row(publisher='Annick Press', max(Rating)=10),
#  Row(publisher='Triumph Books', max(Rating)=10),
#  Row(publisher='Forge', max(Rating)=10),
#  Row(publisher='Bridge Logos Pub', max(Rating)=8),
#  Row(publisher='Sudamericana', max(Rating)=10),
#  Row(publisher='Citadel Pr', max(Rating)=8),
#  Row(publisher='Wizards of the Coast (Mm)', max(Rating)=9),
#  Row(publisher='Trans-Atlantic Publications', max(Rating)=10),
#  Row(publisher='Interlink Publishing+group Inc', max(Rating)=10),
#  Row(publisher='Taschen', max(Rating)=10),
#  Row(publisher='Woodhaven Pub', max(Rating)=8),
#  Row(publisher='Prelude Press', max(Rating)=10),
#  Row(publisher='Random Century', max(Rating)=0),
#  Row(publisher='Little Brown Uk', max(Rating)=10),
#  Row(publisher='Ortho Books', max(Rating)=10),
#  Row(publisher="Reader's Digest Kids", max(Rating)=6),
#  Row(publisher='Nightingale-Conant', max(Rating)=0),
#  Row(publisher='Riverwood Books', max(Rating)=9),
#  Row(publisher='Arte Publico Press', max(Rating)=10),
#  Row(publisher='Marian Wood Book', max(Rating)=10),
#  Row(publisher='Akadine Press', max(Rating)=10),
#  Row(publisher='Albin Michel', max(Rating)=10),
#  Row(publisher='Authorhouse', max(Rating)=10),
#  Row(publisher='Leisure Books', max(Rating)=10),
#  Row(publisher='Destiny Image Publishers', max(Rating)=10),
#  Row(publisher='One World/Strivers Row', max(Rating)=7),
#  Row(publisher='Alfaguara Ediciones, S.A. (Spain)', max(Rating)=10),
#  Row(publisher='Farrar Straus &amp; Giroux', max(Rating)=10),
#  Row(publisher='Janus Publishing Co Ltd', max(Rating)=6),
#  Row(publisher='Univ of Oklahoma Pr', max(Rating)=10),
#  Row(publisher='Bluedoor Publishing', max(Rating)=10),
#  Row(publisher='Apple Signature (Scholastic)', max(Rating)=10),
#  Row(publisher='Aspen West Publishing', max(Rating)=10),
#  Row(publisher='Planeta Editorial S A', max(Rating)=8),
#  Row(publisher='Delmar Learning', max(Rating)=10),
#  Row(publisher='Ogp', max(Rating)=8),
#  Row(publisher='Livre De Poche French', max(Rating)=10),
#  Row(publisher='Publications International, Ltd.', max(Rating)=10),
#  Row(publisher="McGraw Hill Children's Pub", max(Rating)=10),
#  Row(publisher='Magi Publications', max(Rating)=9),
#  Row(publisher='Resources for Christian Living', max(Rating)=0),
#  Row(publisher='Fondo de Cultura Economica de Espana, S.L.', max(Rating)=0),
#  Row(publisher='Possibilities', max(Rating)=4),
#  Row(publisher='Center Point Large Print', max(Rating)=10),
#  Row(publisher='Orbit Book Co.', max(Rating)=10),
#  Row(publisher='Golden Turtle (Cal)', max(Rating)=7),
#  Row(publisher='Fischer Taschenbuch', max(Rating)=8),
#  Row(publisher='Context Books', max(Rating)=10),
#  Row(publisher='Secker & Warburg Ltd', max(Rating)=7),
#  Row(publisher='Villard', max(Rating)=10),
#  Row(publisher='Sophia Inst Pr', max(Rating)=10),
#  Row(publisher='West Publishing Company', max(Rating)=10),
#  Row(publisher='Nilgiri Press', max(Rating)=10),
#  Row(publisher='Corgi Childrens', max(Rating)=10),
#  Row(publisher='Bartholomew', max(Rating)=8),
#  Row(publisher='Four Directions PR', max(Rating)=9),
#  Row(publisher='The Lyons Press', max(Rating)=10),
#  Row(publisher='Noble House', max(Rating)=8),
#  Row(publisher='Simon & Schuster (J)', max(Rating)=10),
#  Row(publisher='Research Associates School Times Publications', max(Rating)=0),
#  Row(publisher='Schocken Books', max(Rating)=10),
#  Row(publisher='Cordovan Corp', max(Rating)=0),
#  Row(publisher='Delacorte Books for Young Readers', max(Rating)=10),
#  Row(publisher='Bolchazy-Carducci Publishers', max(Rating)=10),
#  Row(publisher='Harcourt Childrens Books', max(Rating)=10),
#  Row(publisher='Le Temps des Cerises', max(Rating)=8),
#  Row(publisher='Fondo de Cultura Economica USA', max(Rating)=10),
#  Row(publisher='Value Communications', max(Rating)=7),
#  Row(publisher='Overdue Media', max(Rating)=10),
#  Row(publisher='Oceano', max(Rating)=0),
#  Row(publisher='Learning Express', max(Rating)=10),
#  Row(publisher='Charles E Tuttle Co', max(Rating)=0),
#  Row(publisher='PLUTO PRESS', max(Rating)=10),
#  Row(publisher='scholastic', max(Rating)=10),
#  Row(publisher='Favre', max(Rating)=8),
#  Row(publisher='I B S Books Stocked', max(Rating)=10),
#  Row(publisher='Lyceum Books, Incorporated', max(Rating)=0),
#  Row(publisher='Magnum Photos Inc', max(Rating)=9),
#  Row(publisher='Oscar Italian', max(Rating)=10),
#  Row(publisher='Manic D Press', max(Rating)=10),
#  Row(publisher='Tusquets Editores', max(Rating)=10),
#  Row(publisher='PowerKids Press', max(Rating)=0),
#  Row(publisher='CMT', max(Rating)=0),
#  Row(publisher='Woodbridge Press Publishing Company', max(Rating)=8),
#  Row(publisher='Pamiela Argitaletxea', max(Rating)=None),
#  Row(publisher='Marian Press', max(Rating)=10),
#  Row(publisher='Carol Publishing Corporation', max(Rating)=10),
#  Row(publisher='Putnam Pub Group', max(Rating)=10),
#  Row(publisher='Capitol Hill Press', max(Rating)=0),
#  Row(publisher='Chaosium', max(Rating)=10),
#  Row(publisher='Chrysalis Books', max(Rating)=10),
#  Row(publisher='Delta', max(Rating)=10),
#  Row(publisher='Ediciones Internacionales Universitarias', max(Rating)=0),
#  Row(publisher='Little Brown & Co (Pap)', max(Rating)=0),
#  Row(publisher='Dupuis', max(Rating)=10),
#  Row(publisher='Para Publishing', max(Rating)=9),
#  Row(publisher='Editions Internationales A. StankÃ©', max(Rating)=0),
#  Row(publisher='Replica Books', max(Rating)=10),
#  Row(publisher='Omnibus Books', max(Rating)=8),
#  Row(publisher='Peter Montoya & Tim Vandehey', max(Rating)=0),
#  Row(publisher='Solaris', max(Rating)=8),
#  Row(publisher='John Muir Publications', max(Rating)=10),
#  Row(publisher='New Family Traditions', max(Rating)=0),
#  Row(publisher='Bristol Publishing Enterprises', max(Rating)=7),
#  Row(publisher='Wilshire Book Company', max(Rating)=10),
#  Row(publisher='Bedford Books', max(Rating)=10),
#  Row(publisher='Ten Speed Pr', max(Rating)=10),
#  Row(publisher='McClelland & Stewart Ltd', max(Rating)=10),
#  Row(publisher='Eerdmans Pub Co', max(Rating)=10),
#  Row(publisher='First Word Learning System', max(Rating)=5),
#  Row(publisher='John Wiley &amp; Sons (Canada)', max(Rating)=5),
#  Row(publisher='Angsana Books', max(Rating)=9),
#  Row(publisher='A Plume Book', max(Rating)=6),
#  Row(publisher='Fromm Intl', max(Rating)=10),
#  Row(publisher='Love Spectrum', max(Rating)=10),
#  Row(publisher='Christian Literature Crusade', max(Rating)=10),
#  Row(publisher='Pocket Books/Minstrel', max(Rating)=0),
#  Row(publisher='McClanahan Book Company', max(Rating)=10),
#  Row(publisher='Putnam Pub Group (Paper)', max(Rating)=10),
#  Row(publisher='Drawn & Quarterly', max(Rating)=10),
#  Row(publisher='Audio Renaissance', max(Rating)=10),
#  Row(publisher='Little Brown Company', max(Rating)=10),
#  Row(publisher='Scarborough House Publishers', max(Rating)=10),
#  Row(publisher='Braguelonne', max(Rating)=10),
#  Row(publisher='Harlem Moon', max(Rating)=10),
#  Row(publisher='Tyndale Entertainment', max(Rating)=0),
#  Row(publisher='CRCS Publications', max(Rating)=10),
#  Row(publisher='Alianza', max(Rating)=10),
#  Row(publisher='Penguin Uk', max(Rating)=10),
#  Row(publisher='Silhouette Books', max(Rating)=10),
#  Row(publisher='TFH Publications', max(Rating)=10),
#  Row(publisher='Intl Learning Systems', max(Rating)=9),
#  Row(publisher='American Photographic Book Pub. Co', max(Rating)=0),
#  Row(publisher='AMG Publishers', max(Rating)=10),
#  Row(publisher='Phaidon Press Inc.', max(Rating)=10),
#  Row(publisher='Vantage Pr', max(Rating)=10),
#  Row(publisher='Castalia Publishing Company', max(Rating)=10),
#  Row(publisher='Pogue Press', max(Rating)=10),
#  Row(publisher='Giron Spanish Books Distributors', max(Rating)=10),
#  Row(publisher='R. F. Quinn Publishing Co.', max(Rating)=8),
#  Row(publisher='Univ Of Wa+press', max(Rating)=0),
#  Row(publisher='Le Serpent Ã?Â\xa0 plumes', max(Rating)=7),
#  Row(publisher='Rairarubia Books', max(Rating)=0),
#  Row(publisher='Critics Choice Paperbacks', max(Rating)=0),
#  Row(publisher='New Society Publishers', max(Rating)=10),
#  Row(publisher='Kendall/Hunt Publishing Company', max(Rating)=5),
#  Row(publisher='Random House Large Print Publishing', max(Rating)=10),
#  Row(publisher='Popular Library', max(Rating)=9),
#  Row(publisher='Fourth Estate', max(Rating)=10),
#  Row(publisher='Sword of the Lord', max(Rating)=10),
#  Row(publisher='Sterling Pub. Co', max(Rating)=8),
#  Row(publisher='Black Rose Books', max(Rating)=6),
#  Row(publisher='Destiny Books', max(Rating)=10),
#  Row(publisher='Review', max(Rating)=7),
#  Row(publisher='Cambridge University Press', max(Rating)=10),
#  Row(publisher='Penguin Putnam', max(Rating)=10),
#  Row(publisher='Galilee Book', max(Rating)=0),
#  Row(publisher='Family Vision Pr', max(Rating)=0),
#  Row(publisher='United Hospital Fund', max(Rating)=0),
#  Row(publisher='Virtual Publications', max(Rating)=9),
#  Row(publisher='Anderson World', max(Rating)=6),
#  Row(publisher='Hayden Books', max(Rating)=6),
#  Row(publisher='Sagamore Publishing', max(Rating)=5),
#  Row(publisher='Van Nostrand Reinhold', max(Rating)=10),
#  Row(publisher='Bloomsbury Pub', max(Rating)=9),
#  Row(publisher='Zytglogge Verlag', max(Rating)=8),
#  Row(publisher='Nature Study Guild Publishers', max(Rating)=10),
#  Row(publisher='Orion Publishing Group', max(Rating)=10),
#  Row(publisher='Top Shelf Productions', max(Rating)=9),
#  Row(publisher='Oberon Pr', max(Rating)=10),
#  Row(publisher='Mayhaven Publishing', max(Rating)=10),
#  Row(publisher='Beaufort Books', max(Rating)=10),
#  Row(publisher='Cq Products', max(Rating)=10),
#  Row(publisher='Ueberreuter', max(Rating)=10),
#  Row(publisher='Phoenix Publishing (WA)', max(Rating)=10),
#  Row(publisher='Navpress Publishing Group', max(Rating)=10),
#  Row(publisher='Walker & Company', max(Rating)=10),
#  Row(publisher='Daedalus Books', max(Rating)=10),
#  Row(publisher='University of Minnesota Press', max(Rating)=10),
#  Row(publisher='Aguilar', max(Rating)=10),
#  Row(publisher='Severn House Publishers', max(Rating)=10),
#  Row(publisher='Galahad Books', max(Rating)=10),
#  Row(publisher="Asian American Writers' Workshop", max(Rating)=7),
#  Row(publisher="L'Atalante", max(Rating)=10),
#  Row(publisher='Boston Mills Press', max(Rating)=9),
#  Row(publisher='Futura', max(Rating)=9),
#  Row(publisher='Dressler Verlag', max(Rating)=10),
#  Row(publisher='McGraw-Hill/Dushkin', max(Rating)=7),
#  Row(publisher='C.V. Mosby', max(Rating)=10),
#  Row(publisher='Miguel Angel Porrua', max(Rating)=10),
#  Row(publisher='W H Freeman & Co', max(Rating)=10),
#  Row(publisher='Harrap', max(Rating)=10),
#  Row(publisher='Stoddart+publishing', max(Rating)=10),
#  Row(publisher='Cryptic Press (NY)', max(Rating)=8),
#  Row(publisher='Kyle Cathie Ltd', max(Rating)=9),
#  Row(publisher='Tyndale Kids', max(Rating)=10),
#  Row(publisher='Libraries Unlimited', max(Rating)=10),
#  Row(publisher='Distributed by Orient Longman', max(Rating)=8),
#  Row(publisher='Head Heritage', max(Rating)=10),
#  Row(publisher='Liberty Publishing Company Inc.', max(Rating)=10),
#  Row(publisher='Bare Bones Press', max(Rating)=9),
#  Row(publisher='Langenscheidt Publishers', max(Rating)=10),
#  Row(publisher='Thames and Hudson', max(Rating)=10),
#  Row(publisher='New Amer Library (Mm)', max(Rating)=10),
#  Row(publisher="Children's Press (CT)", max(Rating)=10),
#  Row(publisher='Tom Doherty Associates', max(Rating)=9),
#  Row(publisher='Humble Creek / Barber Publishing Inc.', max(Rating)=0),
#  Row(publisher='Starscape Books', max(Rating)=10),
#  Row(publisher='Leetes Island Books', max(Rating)=8),
#  Row(publisher='New Messenger Books', max(Rating)=9),
#  Row(publisher='Richelieu Court Publications', max(Rating)=0),
#  Row(publisher='Del Rey', max(Rating)=10),
#  Row(publisher='Helter Skelter Publishing', max(Rating)=10),
#  Row(publisher='Walking Stick Press', max(Rating)=8),
#  Row(publisher='H.W. Sams', max(Rating)=8),
#  Row(publisher='Blake et Mortimer', max(Rating)=10),
#  Row(publisher='Loveland Press', max(Rating)=10),
#  Row(publisher='Polestar', max(Rating)=8),
#  Row(publisher='Marietta Publishing Company', max(Rating)=10),
#  Row(publisher='Price Stern Sloan Pub (J)', max(Rating)=10),
#  Row(publisher='Faber & Faber', max(Rating)=10),
#  Row(publisher='Penguin Books Ltd', max(Rating)=10),
#  Row(publisher='Anchor Bible Commentary', max(Rating)=0),
#  Row(publisher='Prometheus Books', max(Rating)=10),
#  Row(publisher='Fantagraphics Books', max(Rating)=10),
#  Row(publisher='New Riders', max(Rating)=10),
#  Row(publisher='Honor Books (OK)', max(Rating)=10),
#  Row(publisher='Transworld Publishers Limited', max(Rating)=10),
#  Row(publisher='Robert Laffont', max(Rating)=10),
#  Row(publisher='New Harbinger Publications', max(Rating)=10),
#  Row(publisher='Metropolitan Books', max(Rating)=10),
#  Row(publisher='Cook Communications Ministries International', max(Rating)=7),
#  Row(publisher='W.H. Allen', max(Rating)=10),
#  Row(publisher='Silver Roads Publishing', max(Rating)=5),
#  Row(publisher='Playboy Mass Market Paperbacks', max(Rating)=9),
#  Row(publisher='MercuryBooks', max(Rating)=9),
#  Row(publisher='Univ of Chicago Pr', max(Rating)=9),
#  Row(publisher="Penguin Children's Audiobooks", max(Rating)=7),
#  Row(publisher='Nathan', max(Rating)=7),
#  Row(publisher='Lyons Group Incorporated', max(Rating)=7),
#  Row(publisher='Random House Canada', max(Rating)=10),
#  Row(publisher='Pearson Allyn & Bacon', max(Rating)=10),
#  Row(publisher='Underwood Books', max(Rating)=10),
#  Row(publisher='Random House Inc', max(Rating)=10),
#  Row(publisher='Wholly Life Center', max(Rating)=0),
#  Row(publisher='Gracewing', max(Rating)=8),
#  Row(publisher='Thomas Nelson', max(Rating)=10),
#  Row(publisher='National Geographic Society', max(Rating)=10),
#  Row(publisher='Billy Graham Evangelistic Association', max(Rating)=10),
#  Row(publisher='Westminster John Knox Press', max(Rating)=10),
#  Row(publisher='Goldencraft', max(Rating)=10),
#  Row(publisher='Omnibus', max(Rating)=10),
#  Row(publisher='HarperCollinsPublishers Australia', max(Rating)=9),
#  Row(publisher='Klopp', max(Rating)=5),
#  Row(publisher="Vents d'Ouest", max(Rating)=8),
#  Row(publisher='Anagrama, Editorial S.A.', max(Rating)=6),
#  Row(publisher='Longman Publishing Group', max(Rating)=10),
#  Row(publisher='Academic Press', max(Rating)=10),
#  Row(publisher='Te Neues Publishing Company', max(Rating)=10),
#  Row(publisher='Community Communications Inc.', max(Rating)=0),
#  Row(publisher='Bbc Pubns', max(Rating)=10),
#  Row(publisher='STRAPLESS', max(Rating)=10),
#  Row(publisher="Charles Scribner's Sons", max(Rating)=10),
#  Row(publisher='Kryon Writings', max(Rating)=8),
#  Row(publisher='Sumrall Pub', max(Rating)=10),
#  Row(publisher='A & W Pub', max(Rating)=10),
#  Row(publisher='Aufbau-Verlag', max(Rating)=10),
#  Row(publisher='Carnegie Mellon University', max(Rating)=8),
#  Row(publisher='Forbes Inc', max(Rating)=0),
#  Row(publisher='Pineapple Pr Inc', max(Rating)=0),
#  Row(publisher='Harvest House Publishers', max(Rating)=10),
#  Row(publisher='Harvest Books', max(Rating)=10),
#  Row(publisher='Regnery Publishing', max(Rating)=10),
#  Row(publisher='Rowohlt Taschenbuch Verlag GmbH', max(Rating)=10),
#  Row(publisher='Globe Pequot', max(Rating)=10),
#  Row(publisher='Oni Press', max(Rating)=10),
#  Row(publisher='Rutledge Hill Press', max(Rating)=10),
#  Row(publisher='Hennessey & Ingalls', max(Rating)=10),
#  Row(publisher='Hazelden Publishing & Educational Services', max(Rating)=10),
#  Row(publisher='Common Courage Press', max(Rating)=10),
#  Row(publisher='Bruo', max(Rating)=7),
#  Row(publisher='Wrens Park', max(Rating)=0),
#  Row(publisher='E.E. Sinclair', max(Rating)=10),
#  Row(publisher='Phillimore & Co Ltd', max(Rating)=7),
#  Row(publisher='Fundacion Jorge Guillen', max(Rating)=0),
#  Row(publisher='Bloodletting Pr', max(Rating)=0),
#  Row(publisher='Stonewall Inn Editions', max(Rating)=10),
#  Row(publisher='InstantPublisher.com', max(Rating)=10),
#  Row(publisher='C.R. Gibson Company', max(Rating)=10),
#  Row(publisher='Favorite Recipes Press (FRP)', max(Rating)=8),
#  Row(publisher='Philomel Books', max(Rating)=10),
#  Row(publisher='Minotauro', max(Rating)=10),
#  Row(publisher='Smithsonian Books', max(Rating)=10),
#  Row(publisher='Summit Books', max(Rating)=10),
#  Row(publisher='Cooper Square Publishers', max(Rating)=10),
#  Row(publisher='Broadway Books', max(Rating)=10),
#  Row(publisher='Arbeiderspers', max(Rating)=9),
#  Row(publisher='Audio Partners', max(Rating)=10),
#  Row(publisher='John Wiley &amp; Sons Inc', max(Rating)=8),
#  Row(publisher='Bantam Classic & Loveswept', max(Rating)=0),
#  Row(publisher="Dramatist's Play Service", max(Rating)=10),
#  Row(publisher='iUniversity Press', max(Rating)=0),
#  Row(publisher='Ohara Publications', max(Rating)=10),
#  Row(publisher='Verlagsunion Pabel Moewig KG Moewig, Neff Hestia', max(Rating)=8),
#  Row(publisher='Editions Berlitz', max(Rating)=10),
#  Row(publisher='Anchor Books', max(Rating)=10),
#  Row(publisher='Anchor Distributors', max(Rating)=10),
#  Row(publisher='Hampton Roads Pub Co Inc', max(Rating)=10),
#  Row(publisher='Ullstein Buchverlage Gmbh', max(Rating)=10),
#  Row(publisher='Feltrinelli', max(Rating)=10),
#  Row(publisher='F. Warne', max(Rating)=8),
#  Row(publisher='Heinemann Ed Uk', max(Rating)=0),
#  Row(publisher='HarperCollins', max(Rating)=10),
#  Row(publisher='Mystic Rose Books', max(Rating)=10),
#  Row(publisher='Gangor Pr', max(Rating)=0),
#  Row(publisher='Fischer Taschenbuch Verlag', max(Rating)=10),
#  Row(publisher='Sunburst', max(Rating)=10),
#  Row(publisher='Sidgwick & Jackson', max(Rating)=10),
#  Row(publisher='Dk Publishing Inc', max(Rating)=7),
#  Row(publisher='Prentice Hall Press', max(Rating)=10),
#  Row(publisher='Wendy Lamb Books', max(Rating)=8),
#  Row(publisher="St. Martin's True Crime", max(Rating)=10),
#  Row(publisher='Fanfare', max(Rating)=10),
#  Row(publisher='Ediciones B, SA', max(Rating)=8),
#  Row(publisher='Prentice-Hall', max(Rating)=10),
#  Row(publisher="Reader's Digest", max(Rating)=10),
#  Row(publisher='Houghton Mifflin College Div', max(Rating)=10),
#  Row(publisher='Ltdbooks', max(Rating)=10),
#  Row(publisher='Critics Choice Paperbacks/Lorevan Publishing', max(Rating)=10),
#  Row(publisher='Petersons', max(Rating)=10),
#  Row(publisher='Editions Du Seuil', max(Rating)=10),
#  Row(publisher='Sociedad General Espanola de Libreria, S.A. (SGEL)', max(Rating)=0),
#  Row(publisher='Thorndike Pr', max(Rating)=10),
#  Row(publisher='Berkley Boulevard Books', max(Rating)=9),
#  Row(publisher='Atheneum', max(Rating)=10),
#  Row(publisher='Macmillan Pub Ltd', max(Rating)=10),
#  Row(publisher='Samo Press', max(Rating)=0),
#  Row(publisher='Pruett Publishing Company', max(Rating)=9),
#  Row(publisher='Insel Verlag', max(Rating)=0),
#  Row(publisher='Writers & Readers Publishing', max(Rating)=10),
#  Row(publisher='M&amp;T Books', max(Rating)=8),
#  Row(publisher='A. Bonniers', max(Rating)=0),
#  Row(publisher='Harveys Books', max(Rating)=10),
#  Row(publisher='Columna', max(Rating)=10),
#  Row(publisher='Cedco Publishing Company', max(Rating)=10),
#  Row(publisher='Hot Head Glass', max(Rating)=10),
#  Row(publisher='Harper &amp; Row', max(Rating)=8),
#  Row(publisher='Pagefree Publishing', max(Rating)=10),
#  Row(publisher='Quill Press', max(Rating)=10),
#  Row(publisher='Countryside Books', max(Rating)=10),
#  Row(publisher='Bantam Doubleday Dell Pub (T)', max(Rating)=10),
#  Row(publisher='Warner Futura', max(Rating)=10),
#  Row(publisher='Collier Macmillan', max(Rating)=10),
#  Row(publisher='Schofield & Sims Ltd', max(Rating)=0),
#  Row(publisher='Dragonfly Books', max(Rating)=10),
#  Row(publisher='Planeta', max(Rating)=10),
#  Row(publisher="Travelers' Tales Guides", max(Rating)=10),
#  Row(publisher='Discovery Pr', max(Rating)=0),
#  Row(publisher='Broadman & Holman Publishers', max(Rating)=10),
#  Row(publisher='Bogfire Inc.', max(Rating)=0),
#  Row(publisher='Au Diable Vauvert', max(Rating)=10),
#  Row(publisher='Perelandra', max(Rating)=8),
#  Row(publisher='Sedgewood Press', max(Rating)=10),
#  Row(publisher='Universal Sales Marketing', max(Rating)=10),
#  Row(publisher='Howard Univ Pr', max(Rating)=10),
#  Row(publisher='Corgi Books', max(Rating)=10),
#  Row(publisher='Lake Claremont Press', max(Rating)=8),
#  Row(publisher='Master Design', max(Rating)=8),
#  Row(publisher='Hamlyn', max(Rating)=10),
#  Row(publisher='Random House Value Pub', max(Rating)=10),
#  Row(publisher='Element Books', max(Rating)=10),
#  Row(publisher='Bethany House', max(Rating)=10),
#  Row(publisher='Rpi Publishing', max(Rating)=0),
#  Row(publisher='University Press of Mississippi', max(Rating)=9),
#  Row(publisher='Newport House', max(Rating)=0),
#  Row(publisher='Ronsdale Press', max(Rating)=7),
#  Row(publisher='Guernica Editions', max(Rating)=8),
#  Row(publisher='Word Books', max(Rating)=10),
#  Row(publisher='Extique', max(Rating)=10),
#  Row(publisher='Wgbh Pubns', max(Rating)=0),
#  Row(publisher='Channel 4 books', max(Rating)=10),
#  Row(publisher='Quiet Vision Pub', max(Rating)=10),
#  Row(publisher='Craigs', max(Rating)=7),
#  Row(publisher='Rand McNally & Company', max(Rating)=10),
#  Row(publisher='DrPen Publishing', max(Rating)=0),
#  Row(publisher='Snow Lion Publications', max(Rating)=10),
#  Row(publisher='J. Paul Getty Trust Publications', max(Rating)=8),
#  Row(publisher='Macmillan Distribution', max(Rating)=10),
#  Row(publisher='Carroll Graf', max(Rating)=9),
#  Row(publisher='Rowohlt Tb.', max(Rating)=10),
#  Row(publisher='Bantam Books', max(Rating)=10),
#  Row(publisher='Pantheon Books', max(Rating)=10),
#  Row(publisher='W.C. Brown Publishers', max(Rating)=0),
#  Row(publisher='Melren Enterprises', max(Rating)=0),
#  Row(publisher='National Association for the Education of You', max(Rating)=5),
#  Row(publisher='Philippe Picquier', max(Rating)=10),
#  Row(publisher='Bradygames', max(Rating)=10),
#  Row(publisher='Darling & Company', max(Rating)=10),
#  Row(publisher='Publications International Ltd', max(Rating)=10),
#  Row(publisher='Cornelsen', max(Rating)=10),
#  Row(publisher='New Millennium Audio', max(Rating)=9),
#  Row(publisher='Distributed by Prentice Hall Trade', max(Rating)=0),
#  Row(publisher='Karen Brown', max(Rating)=8),
#  Row(publisher='Joanna Cotler', max(Rating)=10),
#  Row(publisher='Museum of New Mexico Press', max(Rating)=9),
#  Row(publisher='Nelsonword Publishing Group', max(Rating)=9),
#  Row(publisher='Prentice Hall Art', max(Rating)=10),
#  Row(publisher='House of Collectibles', max(Rating)=10),
#  Row(publisher='Eakin Pr', max(Rating)=10),
#  Row(publisher='Alistair Press (IN)', max(Rating)=None),
#  Row(publisher='Broadview Press', max(Rating)=10),
#  Row(publisher='Hitchcock Pub Co', max(Rating)=5),
#  Row(publisher='Regan Books', max(Rating)=10),
#  Row(publisher='Time-Life Books', max(Rating)=10),
#  Row(publisher='Broadman & Holman Pub', max(Rating)=10),
#  Row(publisher='Call Center Press', max(Rating)=0),
#  Row(publisher='Macmillan Computer Pub', max(Rating)=10),
#  Row(publisher='W Publishing Group', max(Rating)=10),
#  Row(publisher='Johns Hopkins University Press', max(Rating)=10),
#  Row(publisher='Berlitz Guides', max(Rating)=10),
#  Row(publisher='Santillana Pub Co', max(Rating)=9),
#  Row(publisher='Morgan Kaufmann Pub', max(Rating)=8),
#  Row(publisher='Crowswing Books', max(Rating)=0),
#  Row(publisher='Ballantine', max(Rating)=10),
#  Row(publisher='Sunset Publishing Corporation', max(Rating)=10),
#  Row(publisher='Transworld Publishers (Division of Random House Australia)', max(Rating)=9),
#  Row(publisher='Overeaters Anonymous', max(Rating)=10),
#  Row(publisher='Scott, Foresman', max(Rating)=10),
#  Row(publisher='Benbella Books', max(Rating)=10),
#  Row(publisher='Ibs Pr', max(Rating)=0),
#  Row(publisher='Lark Books', max(Rating)=0),
#  Row(publisher='McGraw-Hill College', max(Rating)=10),
#  Row(publisher='Tyndale House Pub', max(Rating)=10),
#  Row(publisher='Oxford Univ Pr', max(Rating)=10),
#  Row(publisher='Vintage Books USA', max(Rating)=10),
#  Row(publisher='Allen & Unwin Pty., Limited (Australia)', max(Rating)=10),
#  Row(publisher='Darton Longman and Todd', max(Rating)=6),
#  Row(publisher='Sybex Inc', max(Rating)=10),
#  Row(publisher='Big Cat Press', max(Rating)=0),
#  Row(publisher='Client Distribution Services', max(Rating)=10),
#  Row(publisher='C.H.Beck', max(Rating)=10),
#  Row(publisher='Fearon Teacher AIDS', max(Rating)=10),
#  Row(publisher='Aero Publishers', max(Rating)=8),
#  Row(publisher='Austin Junior Forum', max(Rating)=8),
#  Row(publisher='D. R. Godine', max(Rating)=0),
#  Row(publisher='Iowa State Press', max(Rating)=7),
#  Row(publisher='The Museum', max(Rating)=10),
#  Row(publisher='Syracuse University Press', max(Rating)=10),
#  Row(publisher='Currier-Davis Pub', max(Rating)=10),
#  Row(publisher='Nord-Sud Verlag', max(Rating)=10),
#  Row(publisher='Trafalgar Square (J)', max(Rating)=10),
#  Row(publisher='Winedale Publishing', max(Rating)=8),
#  Row(publisher='Avon Publishers', max(Rating)=0),
#  Row(publisher='Center Point Publishing', max(Rating)=9),
#  Row(publisher='Tempo', max(Rating)=None),
#  Row(publisher='Norton', max(Rating)=10),
#  Row(publisher='Hackett Publishing Company', max(Rating)=10),
#  Row(publisher='Multnomah', max(Rating)=10),
#  Row(publisher='William Morrow &amp; Company', max(Rating)=10),
#  Row(publisher='M. Wiener Pub.', max(Rating)=0),
#  Row(publisher='David R. Godine Publisher', max(Rating)=10),
#  Row(publisher='Banner of Truth', max(Rating)=10),
#  Row(publisher='Knopf : distributed by Random House', max(Rating)=10),
#  Row(publisher='Green Frog Publishers', max(Rating)=0),
#  Row(publisher='Barney Publishing', max(Rating)=10),
#  Row(publisher='Enslow Publishers', max(Rating)=10),
#  Row(publisher='Blue Mountain Arts', max(Rating)=10),
#  Row(publisher='De Haan', max(Rating)=7),
#  Row(publisher='The Seabury Press, Inc.', max(Rating)=0),
#  Row(publisher='Irish Books & Media', max(Rating)=10),
#  Row(publisher='Great Plains Publications', max(Rating)=0),
#  Row(publisher="St. Martin's Press", max(Rating)=10),
#  Row(publisher='A. Michel', max(Rating)=10),
#  Row(publisher='Star Trek', max(Rating)=10),
#  Row(publisher='Time Warner Books UK', max(Rating)=10),
#  Row(publisher='Spence Publishing Company', max(Rating)=8),
#  Row(publisher='Belle Grove Publishing Company', max(Rating)=8),
#  Row(publisher='Methuen Publishing', max(Rating)=10),
#  Row(publisher='Chelsea House Publications', max(Rating)=10),
#  Row(publisher='Contemporary Perspectives Inc.', max(Rating)=7),
#  Row(publisher='Eos (HarperCollins)', max(Rating)=10),
#  Row(publisher='Pavilion Books', max(Rating)=10),
#  Row(publisher="Patriot's Pub.", max(Rating)=0),
#  Row(publisher='Consortium Book Sales &amp; Dist', max(Rating)=10),
#  Row(publisher='Harpercollins Publisher', max(Rating)=10),
#  Row(publisher='Simon Pulse', max(Rating)=10),
#  Row(publisher='Picador (UK)', max(Rating)=10),
#  Row(publisher='Main Street Books', max(Rating)=10),
#  Row(publisher='Centurion Books Ltd', max(Rating)=0),
#  Row(publisher='The Association', max(Rating)=5),
#  Row(publisher='Sellerio di Giorgianni', max(Rating)=10),
#  Row(publisher='Invisible College Press', max(Rating)=10),
#  Row(publisher='Mosaik Verlag, Mchn.', max(Rating)=10),
#  Row(publisher='Streetbeat Publications', max(Rating)=0),
#  Row(publisher='Laughing Elephant', max(Rating)=10),
#  Row(publisher='Marvel Comics', max(Rating)=10),
#  Row(publisher='Syren Book Co', max(Rating)=0),
#  Row(publisher='Roedway Press', max(Rating)=0),
#  Row(publisher='Lindos Books', max(Rating)=0),
#  Row(publisher='Wyndham Publications', max(Rating)=0),
#  Row(publisher='Proa', max(Rating)=7),
#  Row(publisher='M. F. Feheley', max(Rating)=9),
#  Row(publisher='Dell Publishing', max(Rating)=10),
#  Row(publisher='Random House UK Ltd (A Division of Random House Group)', max(Rating)=10),
#  Row(publisher='Eschaton Productions Inc.', max(Rating)=8),
#  Row(publisher='Exclusive distributor, ISBS', max(Rating)=0),
#  Row(publisher='Delmar Publishers', max(Rating)=10),
#  Row(publisher='Phoenix Press', max(Rating)=10),
#  Row(publisher='Alaska Pacific Univ Pr', max(Rating)=0),
#  Row(publisher='Carlton Books Limited', max(Rating)=10),
#  Row(publisher='Coppola', max(Rating)=0),
#  Row(publisher='Mosaic Press', max(Rating)=10),
#  Row(publisher='Orchard Books', max(Rating)=10),
#  Row(publisher='Fluide Glacial', max(Rating)=9),
#  Row(publisher='Park Slope Pr', max(Rating)=3),
#  Row(publisher='Coronet Books & Publications', max(Rating)=9),
#  Row(publisher='Putnam Adult', max(Rating)=10),
#  Row(publisher='Guardians of Order', max(Rating)=8),
#  Row(publisher='Better Homes and Gardens Books', max(Rating)=10),
#  Row(publisher='DUMONT monte', max(Rating)=9),
#  Row(publisher='Barnes Noble Books', max(Rating)=10),
#  Row(publisher='Oregon Historical Society Press', max(Rating)=8),
#  Row(publisher='Ammann', max(Rating)=10),
#  Row(publisher='Paul &amp; Co Pub Consortium', max(Rating)=8),
#  Row(publisher='Pierrot', max(Rating)=0),
#  Row(publisher='Taunton Press', max(Rating)=10),
#  Row(publisher='Hampton Roads Publishing Company', max(Rating)=10),
#  Row(publisher='Reprint Services Corp', max(Rating)=5),
#  Row(publisher='HQN Books', max(Rating)=10),
#  Row(publisher='Edaf', max(Rating)=10),
#  Row(publisher='Wisdom Publications', max(Rating)=10),
#  Row(publisher='Brooks/Cole Publishing Company', max(Rating)=10),
#  Row(publisher='Atomium Books', max(Rating)=0),
#  Row(publisher='Oxford Univ Pr (Sd)', max(Rating)=8),
#  Row(publisher='Creative Pub Intl', max(Rating)=9),
#  Row(publisher='HP Books', max(Rating)=10),
#  Row(publisher='HarperFestival', max(Rating)=10),
#  Row(publisher='Piatkus Books', max(Rating)=10),
#  Row(publisher='Arthur A. Levine Books', max(Rating)=10),
#  Row(publisher='Microsoft Press', max(Rating)=10),
#  Row(publisher='Campus Fachbuch', max(Rating)=0),
#  Row(publisher='Virago Press Limited', max(Rating)=10),
#  Row(publisher='Spencer Press', max(Rating)=0),
#  Row(publisher='Gibbs Smith', max(Rating)=10),
#  Row(publisher='Picture Me Books', max(Rating)=10),
#  Row(publisher='Editorial Oveja Negra', max(Rating)=7),
#  Row(publisher='Plan Nine Pub', max(Rating)=10),
#  Row(publisher='Cicerone Press', max(Rating)=9),
#  Row(publisher='Heyday Books', max(Rating)=9),
#  Row(publisher='New Falcon Publications', max(Rating)=10),
#  Row(publisher='Siruela', max(Rating)=10),
#  Row(publisher='Crown House Publishing', max(Rating)=6),
#  Row(publisher='Bev Hawley & Company', max(Rating)=0),
#  Row(publisher='W. H. Allen', max(Rating)=10),
#  Row(publisher='Pond Publishing', max(Rating)=10),
#  Row(publisher='UBC Press', max(Rating)=0),
#  Row(publisher='Palisades', max(Rating)=10),
#  Row(publisher='Grolier Educational Corporation', max(Rating)=0),
#  Row(publisher='Lewis S. Maxwell', max(Rating)=0),
#  Row(publisher='Tuttle C E Co Inc', max(Rating)=9),
#  Row(publisher='Loyal', max(Rating)=10),
#  Row(publisher='Tudor Publishers', max(Rating)=7),
#  Row(publisher='Zagat Survey', max(Rating)=8),
#  Row(publisher='Perseus Book Group', max(Rating)=10),
#  Row(publisher='Reed New Zealand', max(Rating)=10),
#  Row(publisher='Sunstar Publishing (IA)', max(Rating)=0),
#  Row(publisher='NTC/Contemporary Publishing Company', max(Rating)=10),
#  Row(publisher='Intl Pub Marketing', max(Rating)=10),
#  Row(publisher='EdiciÃ³s do Castro', max(Rating)=8),
#  Row(publisher='Morning Light Publications', max(Rating)=9),
#  Row(publisher='Nal Trade', max(Rating)=10),
#  Row(publisher='Hartline Marketing', max(Rating)=0),
#  Row(publisher='Blanvalet', max(Rating)=10),
#  Row(publisher='Quartet Books Ltd', max(Rating)=8),
#  Row(publisher='Scholastic School Market Edition', max(Rating)=10),
#  Row(publisher='FootHills Publishing', max(Rating)=7),
#  Row(publisher='Disney Books by Mail', max(Rating)=10),
#  Row(publisher='Michael Joseph', max(Rating)=10),
#  Row(publisher='Koch, Neff & Oetinger &amp; Co', max(Rating)=10),
#  Row(publisher='Howell Books', max(Rating)=10),
#  Row(publisher='3rd Bed', max(Rating)=8),
#  Row(publisher='HarperCollins New Zealand', max(Rating)=10),
#  Row(publisher='Reiman Publications, L.P.', max(Rating)=10),
#  Row(publisher='Award Publications', max(Rating)=10),
#  Row(publisher='H. Bauer', max(Rating)=0),
#  Row(publisher='Ediciones Catedra S.A.', max(Rating)=10),
#  Row(publisher='D. Coutinho', max(Rating)=0),
#  Row(publisher='Distributed by Caroline House Publishers', max(Rating)=0),
#  Row(publisher='Green Magic', max(Rating)=10),
#  Row(publisher='English Tourist Board', max(Rating)=0),
#  Row(publisher='TokyoPop', max(Rating)=10),
#  Row(publisher='Imajinn Books', max(Rating)=10),
#  Row(publisher='Frank Amato Publications', max(Rating)=9),
#  Row(publisher='Verlag Kiepenheuer & Witsch GmbH &amp; Co KG', max(Rating)=10),
#  Row(publisher='Lynx Books', max(Rating)=10),
#  Row(publisher='Crime and Again Press', max(Rating)=0),
#  Row(publisher='Berkley', max(Rating)=10),
#  Row(publisher='Teachers College Press', max(Rating)=10),
#  Row(publisher='Pss Adult', max(Rating)=10),
#  Row(publisher='Pluto Press (UK)', max(Rating)=0),
#  Row(publisher='Harlequinade Press', max(Rating)=0),
#  Row(publisher='Bantam Book', max(Rating)=7),
#  Row(publisher='Creation Books', max(Rating)=10),
#  Row(publisher='Playmore Inc. Publishers', max(Rating)=10),
#  Row(publisher='Worldwide Mystery', max(Rating)=10),
#  Row(publisher='Xs Books', max(Rating)=10),
#  Row(publisher='Larousse Kingfisher+chambers', max(Rating)=8),
#  Row(publisher='Macmillan Canada', max(Rating)=6),
#  Row(publisher='Joseph Henry Press', max(Rating)=8),
#  Row(publisher='SauerlÃ?Â¤nder', max(Rating)=10),
#  Row(publisher='Flammarion', max(Rating)=10),
#  Row(publisher='E P Dutton', max(Rating)=10),
#  Row(publisher='Published for the Crime Club by Doubleday', max(Rating)=8),
#  Row(publisher='Faith Library Publications', max(Rating)=10),
#  Row(publisher='Benjamin/Cummings Pub. Co', max(Rating)=8),
#  Row(publisher='Stock', max(Rating)=9),
#  Row(publisher='Free Range Pr', max(Rating)=0),
#  Row(publisher='Miraguano Ediciones', max(Rating)=0),
#  Row(publisher='A. Barker', max(Rating)=0),
#  Row(publisher='Imprint Books', max(Rating)=10),
#  Row(publisher='Michael Omara', max(Rating)=5),
#  Row(publisher='Random House of Canada Ltd', max(Rating)=0),
#  Row(publisher='W W Norton', max(Rating)=10),
#  Row(publisher='Fides', max(Rating)=7),
#  Row(publisher='Aum Publications', max(Rating)=0),
#  Row(publisher='Welcome Publishing', max(Rating)=0),
#  Row(publisher='Stark Books', max(Rating)=8),
#  Row(publisher='Meteor Publishing Corp', max(Rating)=8),
#  Row(publisher='PublishAmerica', max(Rating)=10),
#  Row(publisher='Starfire', max(Rating)=10),
#  Row(publisher='Pleasant Company Publications', max(Rating)=10),
#  Row(publisher='Windham Bay Press', max(Rating)=0),
#  Row(publisher='In-Fisherman Inc.', max(Rating)=0),
#  Row(publisher='University of Arizona Press', max(Rating)=10),
#  Row(publisher='University Press of Kentucky', max(Rating)=10),
#  Row(publisher='Simax', max(Rating)=9),
#  Row(publisher='Sun Dog Press', max(Rating)=0),
#  Row(publisher='Bergin & Garvey Paperback', max(Rating)=10),
#  Row(publisher='Review and Herald Pub. Association', max(Rating)=8),
#  Row(publisher='D.C. Cook Pub. Co', max(Rating)=0),
#  Row(publisher='Wesleyan University Press Distributed by Univ', max(Rating)=10),
#  Row(publisher='Worth Publishing', max(Rating)=0),
#  Row(publisher='Pub Overstock Unlimited Inc', max(Rating)=10),
#  Row(publisher='Luso Brazilian Books', max(Rating)=10),
#  Row(publisher='Transit', max(Rating)=7),
#  Row(publisher='Noray', max(Rating)=7),
#  Row(publisher='Fine Enterprises', max(Rating)=8),
#  Row(publisher='Troll', max(Rating)=10),
#  Row(publisher='Coronet Books', max(Rating)=9),
#  Row(publisher='Dietz, Berlin', max(Rating)=0),
#  Row(publisher='Zebra Books', max(Rating)=10),
#  Row(publisher='Reeder Pub', max(Rating)=0),
#  Row(publisher='Editorial Planeta, S.A. (Barcelona)', max(Rating)=9),
#  Row(publisher='Modern Language Association', max(Rating)=10),
#  Row(publisher='Inner City Books', max(Rating)=10),
#  Row(publisher='J. Cape', max(Rating)=10),
#  Row(publisher="Porcupine's Quill", max(Rating)=8),
#  Row(publisher='Folio', max(Rating)=10),
#  Row(publisher='Pattloch', max(Rating)=9),
#  Row(publisher='CrossAmerica Books', max(Rating)=0),
#  Row(publisher='G I A Pubns', max(Rating)=9),
#  Row(publisher='Red Letter Press', max(Rating)=10),
#  Row(publisher='Impressions', max(Rating)=5),
#  Row(publisher='Merriam-Webster', max(Rating)=10),
#  Row(publisher='R. Laffont', max(Rating)=10),
#  Row(publisher='Abbey Press', max(Rating)=10),
#  Row(publisher='Purnell', max(Rating)=10),
#  Row(publisher='Monolith Graphics', max(Rating)=6),
#  Row(publisher='Pfeifer-Hamilton Pubs', max(Rating)=10),
#  Row(publisher='HotsaÂ®at sefarim Â°a. sh. Y.L. Magnes, ha-Universitah ha-Â°Ivrit', max(Rating)=0),
#  Row(publisher='Shambhala', max(Rating)=10),
#  Row(publisher='W. W. Norton & Company', max(Rating)=10),
#  Row(publisher='Titan Books (UK)', max(Rating)=10),
#  Row(publisher='Macmillan', max(Rating)=10),
#  Row(publisher='Multnomah Pub', max(Rating)=10),
#  Row(publisher='Nick Hern Books', max(Rating)=10),
#  Row(publisher='Running Press Book Publishers', max(Rating)=10),
#  Row(publisher='Ambo', max(Rating)=9),
#  Row(publisher="Liv'Editions", max(Rating)=5),
#  Row(publisher='Interweave Press', max(Rating)=10),
#  Row(publisher='Fortress Press', max(Rating)=0),
#  Row(publisher='Dandelion Books, LLC', max(Rating)=8),
#  Row(publisher='Gospel Light Publications', max(Rating)=9),
#  Row(publisher='Greenwillow', max(Rating)=10),
#  Row(publisher='Biblioteca del Vascello', max(Rating)=8),
#  Row(publisher='Random House Childrens Pub (Lib)', max(Rating)=10),
#  Row(publisher='Greenwood Press', max(Rating)=10),
#  Row(publisher='Advance Publishers LLC', max(Rating)=10),
#  Row(publisher='Scribe Publications', max(Rating)=6),
#  Row(publisher='Coffee Time Pubns', max(Rating)=0),
#  Row(publisher='P. Reclam', max(Rating)=8),
#  Row(publisher='Arthur Vanous Co', max(Rating)=9),
#  Row(publisher='Association of Universal Philosophy, Inc.', max(Rating)=10),
#  Row(publisher='Paladin Pr', max(Rating)=0),
#  Row(publisher='Beacon Hill Press', max(Rating)=9),
#  Row(publisher=None, max(Rating)=10),
#  Row(publisher='Moody Press', max(Rating)=8),
#  Row(publisher='Sams', max(Rating)=10),
#  Row(publisher='Octagon Press, Limited', max(Rating)=10),
#  Row(publisher='Houghton Mifflin', max(Rating)=10),
#  Row(publisher='Macmillan of Canada', max(Rating)=10),
#  Row(publisher='Hodder & Stoughton Ltd', max(Rating)=10),
#  Row(publisher='Inspirio', max(Rating)=10),
#  Row(publisher='Actes sud', max(Rating)=8),
#  Row(publisher='MJF Books', max(Rating)=10),
#  Row(publisher='Abingdon Press', max(Rating)=10),
#  Row(publisher='Jodere Group', max(Rating)=10),
#  Row(publisher='Stone Bridge Press', max(Rating)=10),
#  Row(publisher='Family Circle', max(Rating)=9),
#  Row(publisher='Pacific Press Publishing Association', max(Rating)=10),
#  Row(publisher='Dramatists Play Service Inc', max(Rating)=10),
#  Row(publisher='Ediciones Colihue', max(Rating)=10),
#  Row(publisher='Sheffield Pub Co', max(Rating)=9),
#  Row(publisher='Allison & Busby Ltd', max(Rating)=9),
#  Row(publisher='StoryPeople', max(Rating)=10),
#  Row(publisher='Askild & KÃ¤rnekull', max(Rating)=8),
#  Row(publisher='Monte Sano Publishing', max(Rating)=0),
#  Row(publisher='HarperLargePrint', max(Rating)=10),
#  Row(publisher='Hale', max(Rating)=8),
#  Row(publisher='Focus on the Family Publishing', max(Rating)=10),
#  Row(publisher='Value Proprietary', max(Rating)=10),
#  Row(publisher='Bayard', max(Rating)=8),
#  Row(publisher='Barbour Publishing Inc.', max(Rating)=0),
#  Row(publisher="Fodor's Travel Publications", max(Rating)=10),
#  Row(publisher='Penguin/Puffin Mass Market', max(Rating)=10),
#  Row(publisher='Octopus Books', max(Rating)=10),
#  Row(publisher='Longacre Press', max(Rating)=7),
#  Row(publisher='Publications Intl', max(Rating)=10),
#  Row(publisher='Currency', max(Rating)=10),
#  Row(publisher='Olivia & Hill Pr', max(Rating)=0),
#  Row(publisher='Mountaineers Books', max(Rating)=10),
#  Row(publisher='Gestion 2000', max(Rating)=6),
#  Row(publisher='Mateos Ediciones', max(Rating)=10),
#  Row(publisher='Baldini e Castoldi', max(Rating)=10),
#  Row(publisher='Errepar', max(Rating)=10),
#  Row(publisher='Claassen', max(Rating)=10),
#  Row(publisher='Sellerio', max(Rating)=10),
#  Row(publisher='Haffmans', max(Rating)=8),
#  Row(publisher='Blue Dolphin Publishing', max(Rating)=9),
#  Row(publisher="Gay Men's Press", max(Rating)=9),
#  Row(publisher='Perennial', max(Rating)=10),
#  Row(publisher='Consortium Book Sales & Dist', max(Rating)=10),
#  Row(publisher='Garborgs Heart N Home', max(Rating)=8),
#  Row(publisher='Clarion Books', max(Rating)=10),
#  Row(publisher='Chronicle Books Llc', max(Rating)=10),
#  Row(publisher='Naiad Pr', max(Rating)=10),
#  Row(publisher='Meulenhoff', max(Rating)=9),
#  Row(publisher='Des Femmes', max(Rating)=8),
#  Row(publisher='Distributed in the USA and Canada by International Specialized Book Services', max(Rating)=5),
#  Row(publisher='Taylor Trade Publishing', max(Rating)=10),
#  Row(publisher='Lorimer', max(Rating)=9),
#  Row(publisher='Houghton Mifflin/Walter Lorraine Books', max(Rating)=10),
#  Row(publisher='Quartet Books', max(Rating)=10),
#  Row(publisher='Seniors Coalition, The Incorporated', max(Rating)=0),
#  Row(publisher='Talk Trust & Feel Pr', max(Rating)=0),
#  Row(publisher='Univ of Nebraska Pr', max(Rating)=10),
#  Row(publisher='Cartwheel Books (Scholastics)', max(Rating)=10),
#  Row(publisher='United Church Press', max(Rating)=10),
#  Row(publisher='BDD Promotional Books Company', max(Rating)=10),
#  Row(publisher='Penguin Books]', max(Rating)=0),
#  Row(publisher='Urban & Schwarzenberg', max(Rating)=0),
#  Row(publisher='Artemis & Winkler', max(Rating)=10),
#  Row(publisher='Doubleday Books', max(Rating)=10),
#  Row(publisher='InterVarsity Press', max(Rating)=10),
#  Row(publisher='Cyberage Books', max(Rating)=10),
#  Row(publisher='Kingsport Press', max(Rating)=0),
#  Row(publisher='Smithmark Publishers', max(Rating)=10),
#  Row(publisher='Audio Literature', max(Rating)=10),
#  Row(publisher='Bloomsbury Publishing PLC', max(Rating)=10),
#  Row(publisher='Boyds Mills Press', max(Rating)=10),
#  Row(publisher='Bell Tower Book', max(Rating)=10),
#  Row(publisher='Di Capua', max(Rating)=5),
#  Row(publisher='Insomniac Press', max(Rating)=10),
#  Row(publisher='Horizon Book Promotions', max(Rating)=10),
#  ...]

# %%
data = books.join(ratings, 'ISBN', 'left')
data.groupBy("Author").agg(F.count(data.Rating).alias("NumRatings")).orderBy("NumRatings", ascending=False).select("Author").first()
# Out:
# Row(Author='Stephen King')

# %%
data = books.join(ratings, 'ISBN', 'left')
overRating = Window.partitionBy(data.Publisher).orderBy(data.Rating.desc())
data.withColumn("rank", F.dense_rank().over(overRating)).where("rank <= 1").select("Publisher", "Title").collect()
# Out:
# [Row(Publisher='"""Otokar Kersovani\\"""', Title='"Gdje pijevac ne pjeva (Biblioteka ""Zlatni paun\\"")"'),
#  Row(Publisher='"Flemish-Netherlands Foundation ""Stichting Ons Erfdeel,\\"""', Title='Contemporary poetry of the low countries'),
#  Row(Publisher='101 Productions; [distributed by Scribner, New York]', Title='Manna: foods of the frontier'),
#  Row(Publisher='22nd. Century, New York', Title='Portraits of Cities'),
#  Row(Publisher='3', Title="Restoring Intimacy: The Patient's Guide to Maintaining Relationships During Depression"),
#  Row(Publisher='3D Press', Title='Denver Hiking Guide:  45 Hikes within 45 Minutes of Denver'),
#  Row(Publisher='3H Productions, Inc.', Title="Haley's Cleaning Hints"),
#  Row(Publisher='3rd Woman Press', Title='Dictee'),
#  Row(Publisher='A & W Pub', Title='The Adventures of Sherlock Holmes'),
#  Row(Publisher='A & W Visual Library', Title="The left-handers' handbook"),
#  Row(Publisher='A Golden Book', Title="What's In Oscar's Trash Can? (Sesame Street Good-Night Stories)"),
#  Row(Publisher='A H M Publications', Title='The Subjection of Women (Crofts Classics)'),
#  Row(Publisher='A New Hope Pub', Title='Pent Up Passion'),
#  Row(Publisher='A Plume Book', Title='The Prodigal Project: Genesis (Book 1)'),
#  Row(Publisher='A V Pubns', Title="New Age Bible Versions: An Exhaustive Documentation of the Message, Men & Manuscripts Moving Mankind to the Antichrist's One World Religion"),
#  Row(Publisher='A&b Publishers Group', Title='Afrikan Holistic Health   : Complete Herb Remedy Guide, Disease Treatment, Nutrition, Diet, Wholistic Perspectives,African Herb History, Self Diagnosis'),
#  Row(Publisher='A. & C. Black', Title="Writing for television in the 70's"),
#  Row(Publisher='A. & M. Muchnik', Title='Comuna Verdad (Analectas)'),
#  Row(Publisher='A. Bernhardt Pub. Co', Title='Mohammed: Life and work of the forerunner in Arabia : received in the proximity of Abd-ru-shin through the special gift of one called for the purpose ([Forerunners])'),
#  Row(Publisher='A. Bonnier', Title='I skuggan av oron'),
#  Row(Publisher='A. Bonniers', Title='Oskuldens minut'),
#  Row(Publisher='A. Deutsch', Title='Russia in revolution, 1900-1930'),
#  Row(Publisher='A.T.E', Title='El triÃ¡ngulo mortal de las Bermudas'),
#  Row(Publisher='AAAI Press', Title='Computers and Thought'),
#  Row(Publisher='ADV Manga', Title='PrÃ©tear Volume 1'),
#  Row(Publisher='AIMS International Books', Title='Asesinato en el campo de golf'),
#  Row(Publisher='AIMS International Books', Title='Carmen Laforet: Nada (Coleccion Destinolibro; V. 42)'),
#  Row(Publisher='AIMS International Books', Title='El Guardian Entre El Centeno'),
#  Row(Publisher='AIMS International Books', Title='El Guardian Entre El Centeno'),
#  Row(Publisher='AIMS International Books', Title='El Guardian Entre El Centeno'),
#  Row(Publisher='AK Press', Title='The Little Book of Vegan Poems'),
#  Row(Publisher='AK Press', Title='Shibboleth: My Revolting Life'),
#  Row(Publisher='AK Press', Title='Immediatism'),
#  Row(Publisher='AK Press', Title='Answer Me!: First Three Issues of Legendary Magazine'),
#  Row(Publisher='AM', Title='La tahona de FroilÃ¡n'),
#  Row(Publisher='AMG Publishers', Title='Two Hundred and Eighty Titles and Symbols of Christ (Bible Study Series)'),
#  Row(Publisher='AMG Publishers', Title='Hebrew-Greek Key Word Study Bible, New American Standard Bible, Leather, Bonded Burgandy'),
#  Row(Publisher='AVON', Title='Wedding Night'),
#  Row(Publisher='AVON', Title='Wedding Night'),
#  Row(Publisher='AVON', Title="Project Moon Dust: : Beyond Roswell--exposing The Government's Covert Investigations And Cover-ups"),
#  Row(Publisher='AVON Books', Title='Adventures of a Scottish Heiress'),
#  Row(Publisher='Abc-Clio Inc', Title='Cannery Row (Mainstream Series)'),
#  Row(Publisher='Able Inc', Title='Your Journey of Healing, A Workbook'),
#  Row(Publisher='Abradale Press', Title='An illustrated treasury of Bible stories,'),
#  Row(Publisher='Abson Books', Title='Rhyming Cockney slang;'),
#  Row(Publisher='Academic Press', Title='Dinosaur Imagery: The Science of Lost Worlds and Jurassic Art (The Lanzendorf Collection)'),
#  Row(Publisher='Academic Press', Title='Origins of Life : On Earth and in the Cosmos'),
#  Row(Publisher='Academic Press', Title='Encyclopedia of Volcanoes'),
#  Row(Publisher='Ace', Title='The Nimble Man (Menagerie)'),
#  Row(Publisher='Ace', Title='For Those Who Fell'),
#  Row(Publisher='Ace', Title='Furies Of Calderon'),
#  Row(Publisher='Ace', Title="Conqueror's Moon (The Boreal Moon Tale, Book 1)"),
#  Row(Publisher='Acme Press', Title='Superfan'),
#  Row(Publisher='Acolyte Media', Title='Monsters from the Id (Brainstorm)'),
#  Row(Publisher='Acorn Books', Title='Forbidden Grief: The Unspoken Pain of Abortion'),
#  Row(Publisher='Acta Pubns', Title='A Contemporary Celtic Prayer Book'),
#  Row(Publisher='Actar', Title='Chillida: 1948-1998'),
#  Row(Publisher='Active Synapse', Title='The Sandwalk Adventures: An Adventure in Evolution Told in Five Chapters'),
#  Row(Publisher='Active Synapse', Title='Clan Apis'),
#  Row(Publisher='Ad Vice Marketing Inc', Title='Media Tried Justice Denied, Behind the truth and Lies of the Darlie Lynn Routier Murder Case'),
#  Row(Publisher='Adam Smith Institute', Title='The Myths of Privatisation'),
#  Row(Publisher='Adamis International, Incorporated', Title='Exploring Atlantis, No I (Exploring Atlantis)'),
#  Row(Publisher='Adams & Ambrose Pub', Title='The Legal Research Manual: A Game Plan for Legal Research and Analysis'),
#  Row(Publisher='Adams Media Corp', Title='The Verbally Abusive Relationship: How to Recognize It and How to Respond'),
#  Row(Publisher='Adams Media Corp', Title='365 Tv-Free Activities You Can Do With Your Child'),
#  Row(Publisher='Adams Media Corp', Title='365 Tv-Free Activities You Can Do With Your Child'),
#  Row(Publisher='Adams Media Corp', Title='The Minority Career Book'),
#  Row(Publisher='Adams Media Corp', Title='Museum of Science Book of Answers & Questions'),
#  Row(Publisher='Adams Media Corp', Title='I Fall to Pieces: The Music and the Life of Patsy Cline'),
#  Row(Publisher='Adams Pub Co', Title="Becoming: A Master's Manual (Becoming series)"),
#  Row(Publisher='Adams-Blake Publishing', Title='Tears and Rage: The Nursing Crisis in America'),
#  Row(Publisher='Addison Books', Title='Business and Information Systems'),
#  Row(Publisher='Addison-wesley', Title='Taking Care of Your Child'),
#  Row(Publisher='Adrenaline Audiobooks', Title='Survive: Stories of Castaways and Cannibals'),
#  Row(Publisher='Advaita Pr', Title='From Consciousness to Consciousness'),
#  Row(Publisher='Advance Pub Llc', Title="My First Word Book (Disney's Fun to Learn Ser)"),
#  Row(Publisher='Advantage Books', Title='Help4Add High School'),
#  Row(Publisher='Adventure Imports', Title='Guatemalan Ikat Unlined Journal'),
#  Row(Publisher='Ageless Pr', Title='Computer Legends, Lies & Lore'),
#  Row(Publisher='Aglow Pubns', Title='When Love Is Not Perfect: Discovering Gods Reparenting Process'),
#  Row(Publisher='Agreka Tm Llc', Title='Jackals In Iron'),
#  Row(Publisher='Aguabonita Books', Title='Fly Fishing the Sierra Nevada'),
#  Row(Publisher='Aguilar', Title='El Cuento de La Isla Desconocida'),
#  Row(Publisher='Aguilar', Title='Vicki Sherpa: Una Maestra En Katmandu'),
#  Row(Publisher='Aguilar', Title='Historias de Cronopios y de Famas'),
#  Row(Publisher='Aguilar', Title='62 Modelo Para Armar'),
#  Row(Publisher='Ahrens Pub. Co', Title="The bakers' manual for quantity baking and pastry making"),
#  Row(Publisher='Air USA Inc', Title='Fundamentals of Aircraft Material Factors (2nd ed - JS312646)'),
#  Row(Publisher='Ajuntament de Lleida', Title='Nadal a Lleida (1940-1995) (Quaderns de divulgaciÃ³ ciutadana. ColÂ¨lecciÃ³ La banqueta)'),
#  Row(Publisher='Ajuntament de Lleida', Title='La premsa a Lleida (Quaderns de divulgaciÃ³ ciutadana)'),
#  Row(Publisher='Akadine Press', Title='Come, Tell Me How You Live (Common Reader Editions:  Rediscoveries: LONDON)'),
#  Row(Publisher='Akadine Press', Title='Walls Came Tumbling Down (Common Reader Editions)'),
#  Row(Publisher='Akadine Press', Title='Fairy Tale (Common Reader Editions)'),
#  Row(Publisher='Akadine Press', Title='My Cousin Rachel (Common Reader Editions)'),
#  Row(Publisher='Akadine Press', Title='The Inn at the Edge of the World (Common Reader Editions)'),
#  Row(Publisher='Aladdin Publishing Company', Title='Turnabout'),
#  Row(Publisher='Aladdin Publishing Company', Title="The Sign in Mendel's Window (Aladdin Picture Books)"),
#  Row(Publisher='Alaf 21', Title='Original'),
#  Row(Publisher='Alan Richards Co', Title='Stop! Are You Thinking of Moving From the City to the Country?'),
#  Row(Publisher='Alan Sutton Publ Ltd', Title='Ups and Downs of Umbrellas'),
#  Row(Publisher='Alba', Title='Retrato de Dorian Gray, El'),
#  Row(Publisher='Albin Michel', Title='La vie en rose'),
#  Row(Publisher='Albin Michel', Title="Cherchez l'erreur"),
#  Row(Publisher='Albin Michel', Title='Un aller simple: Roman'),
#  Row(Publisher='Albin Michel', Title='Un aller simple: Roman'),
#  Row(Publisher='Albin Michel', Title="L'Arbre des possibles et autres histoires"),
#  Row(Publisher='Albin Michel', Title='Tao Te King'),
#  Row(Publisher='Albin Michel', Title="L'empire des anges: Roman"),
#  Row(Publisher='Albin Michel', Title='Ã?Â?a'),
#  Row(Publisher='Albin Michel', Title="Comment cuisiner son mari Ã?Â\xa0 l'africaine"),
#  Row(Publisher='Albin Michel', Title='Le Journal de Bridget Jones'),
#  Row(Publisher='Albin Michel', Title='Et nous nous reverrons--'),
#  Row(Publisher='Albin Michel', Title='Oscar et la dame rose'),
#  Row(Publisher='Albin Michel', Title='Oscar et la dame rose'),
#  Row(Publisher='Albin Michel', Title='Oscar et la dame rose'),
#  Row(Publisher='Albin Michel', Title='Oscar et la dame rose'),
#  Row(Publisher='Albin Michel', Title='Oscar et la dame rose'),
#  Row(Publisher='Albin Michel', Title='Rue des Bons-Enfants'),
#  Row(Publisher='Albin Michel', Title='Monsieur Ibrahim et les Fleurs du Coran'),
#  Row(Publisher='Albury Publishing', Title="Shout to the Lord: Stories of God's Love and Power"),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Cuentos Completos, Benedetti (Alfaguara Cuentos Completos)'),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Club Dumas, El'),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='El Hombre Duplicado'),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Ensayo Sobre LA Ceguera'),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='El hombre duplicado'),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Un Tal Lucas'),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='El Cuento De LA Isla Desconocida'),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Cuentos Completos/1 (Alfaguara Cuentos Completos)'),
#  Row(Publisher='Alfaguara Infantil', Title='LA Tabla De Flandes (Alfaguara Extra)'),
#  Row(Publisher='Alfranpedoc Publishing', Title='A Family Tree, Taking Root'),
#  Row(Publisher='Alfred A. Knopf', Title='The New Book of Middle Eastern Food'),
#  Row(Publisher='Alfred A. Knopf', Title="Sleeping Beauty (Everyman's Library Children's Classics)"),
#  Row(Publisher='Alfred A. Knopf', Title="The Brand You 50 : Or : Fifty Ways to Transform Yourself from an 'Employee' into a Brand That Shouts Distinction, Commitment, and Passion!"),
#  Row(Publisher='Alfred A. Knopf', Title="The Brand You 50 : Or : Fifty Ways to Transform Yourself from an 'Employee' into a Brand That Shouts Distinction, Commitment, and Passion!"),
#  Row(Publisher='Alfred A. Knopf', Title='The Velveteen Rabbit'),
#  Row(Publisher='Alfred A. Knopf', Title='Mr Ape'),
#  Row(Publisher='Alfred A. Knopf', Title='Charlie and the Great Glass Elevator: The Further Adventures of Charlie Bucket and Willy Wonka, Chocolate-Maker Extraordinary'),
#  Row(Publisher='Alfred A. Knopf', Title='Charlie and the Great Glass Elevator: The Further Adventures of Charlie Bucket and Willy Wonka, Chocolate-Maker Extraordinary'),
#  Row(Publisher='Alfred A. Knopf', Title='Prophet (Kahlil Gibran Pocket Library Series)'),
#  Row(Publisher='Alfred A. Knopf', Title='Prophet (Kahlil Gibran Pocket Library Series)'),
#  Row(Publisher='Alfred A. Knopf', Title='In My Hands: Memories of a Holocaust Rescuer'),
#  Row(Publisher='Alfred A. Knopf', Title='In My Hands: Memories of a Holocaust Rescuer'),
#  Row(Publisher='Alfred A. Knopf', Title='The Man Who Ate Everything: And Other Gastronomic Feats, Disputes and Pleasurable Pursuits'),
#  Row(Publisher='Alfred A. Knopf', Title='The Man Who Ate Everything: And Other Gastronomic Feats, Disputes and Pleasurable Pursuits'),
#  Row(Publisher='Alfred A. Knopf', Title='The Subtle Knife (His Dark Materials, Book 2)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Subtle Knife (His Dark Materials, Book 2)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Subtle Knife (His Dark Materials, Book 2)'),
#  Row(Publisher='Alfred A. Knopf', Title='Plainsong'),
#  Row(Publisher='Alfred A. Knopf', Title='Plainsong'),
#  Row(Publisher='Alfred A. Knopf', Title='Plainsong'),
#  Row(Publisher='Alfred A. Knopf', Title='Plainsong'),
#  Row(Publisher='Alfred A. Knopf', Title='National Audubon Society Field Guide to North American Insects and Spiders (Audubon Society Field Guide)'),
#  Row(Publisher='Alfred A. Knopf', Title='National Audubon Society Field Guide to North American Insects and Spiders (Audubon Society Field Guide)'),
#  Row(Publisher='Alfred A. Knopf', Title='Chasing Cezanne'),
#  Row(Publisher='Alfred A. Knopf', Title='Blackwood Farm (The Vampire Chronicles)'),
#  Row(Publisher='Alfred A. Knopf', Title='Blackwood Farm (The Vampire Chronicles)'),
#  Row(Publisher='Alfred A. Knopf', Title='Blackwood Farm (The Vampire Chronicles)'),
#  Row(Publisher='Alfred A. Knopf', Title='Blackwood Farm (The Vampire Chronicles)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Cold Six Thousand: A Novel'),
#  Row(Publisher='Alfred A. Knopf', Title='The Cold Six Thousand: A Novel'),
#  Row(Publisher='Alfred A. Knopf', Title='National Audubon Society Field Guide to North American Birds: Eastern Region'),
#  Row(Publisher='Alfred A. Knopf', Title='National Audubon Society Field Guide to North American Birds: Eastern Region'),
#  Row(Publisher='Alfred A. Knopf', Title='The Subtle Knife (His Dark Materials, Book 2)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Subtle Knife (His Dark Materials, Book 2)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Subtle Knife (His Dark Materials, Book 2)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Subtle Knife (His Dark Materials, Book 2)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Subtle Knife (His Dark Materials, Book 2)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Subtle Knife (His Dark Materials, Book 2)'),
#  Row(Publisher='Alfred A. Knopf', Title='Lasher'),
#  Row(Publisher='Alfred A. Knopf', Title='Lasher'),
#  Row(Publisher='Alfred A. Knopf', Title='Lasher'),
#  Row(Publisher='Alfred A. Knopf', Title='Lasher'),
#  Row(Publisher='Alfred A. Knopf', Title='Lasher'),
#  Row(Publisher='Alfred A. Knopf', Title='Lasher'),
#  Row(Publisher='Alfred A. Knopf', Title='A Year in Provence'),
#  Row(Publisher='Alfred A. Knopf', Title='A Year in Provence'),
#  Row(Publisher='Alfred A. Knopf', Title='Familiar Trees of North America: Eastern Region (The Audubon Society Pocket Guides)'),
#  Row(Publisher='Alfred A. Knopf', Title='Safekeeping: Some True Stories from a Life'),
#  Row(Publisher='Alfred A. Knopf', Title='The Stories of Ray Bradbury'),
#  Row(Publisher='Alfred A. Knopf', Title='National Audubon Society Field Guide to North American Fossils (Audubon Society Field Guide)'),
#  Row(Publisher='Alfred A. Knopf', Title='Familiar Fossils North America (Audubon Society Pocket Guides)'),
#  Row(Publisher='Alfred A. Knopf', Title='Push'),
#  Row(Publisher='Alfred A. Knopf', Title='Not for Ourselves Alone: The Story of Elizabeth Cady Stanton & Susan B. Anthony : An Illustrated History'),
#  Row(Publisher='Alfred A. Knopf', Title='Masters of Death: The SS-Einsatzgruppen and the Invention of the Holocaust'),
#  Row(Publisher='Alfred A. Knopf', Title='Airframe'),
#  Row(Publisher='Alfred A. Knopf', Title='Airframe'),
#  Row(Publisher='Alfred A. Knopf', Title='Airframe'),
#  Row(Publisher='Alfred A. Knopf', Title='Airframe'),
#  Row(Publisher='Alfred A. Knopf', Title='Airframe'),
#  Row(Publisher='Alfred A. Knopf', Title='Airframe'),
#  Row(Publisher='Alfred A. Knopf', Title='Airframe'),
#  Row(Publisher='Alfred A. Knopf', Title='Autobiography of Red: A Novel in Verse'),
#  Row(Publisher='Alfred A. Knopf', Title='The White'),
#  Row(Publisher='Alfred A. Knopf', Title='The House on Mango Street'),
#  Row(Publisher='Alfred A. Knopf', Title='Timeline'),
#  Row(Publisher='Alfred A. Knopf', Title='Timeline'),
#  Row(Publisher='Alfred A. Knopf', Title='Timeline'),
#  Row(Publisher='Alfred A. Knopf', Title='Timeline'),
#  Row(Publisher='Alfred A. Knopf', Title='Timeline'),
#  Row(Publisher='Alfred A. Knopf', Title='Timeline'),
#  Row(Publisher='Alfred A. Knopf', Title='Timeline'),
#  Row(Publisher='Alfred A. Knopf', Title='Timeline'),
#  Row(Publisher='Alfred A. Knopf', Title='Timeline'),
#  Row(Publisher='Alfred A. Knopf', Title='Timeline'),
#  Row(Publisher='Alfred A. Knopf', Title='Amazing Poisonous Animals (Eyewitness Junior)'),
#  Row(Publisher='Alfred A. Knopf', Title='North American Indian (Eyewitness Books)'),
#  Row(Publisher='Alfred A. Knopf', Title='The People Could Fly: American Black Folktales'),
#  Row(Publisher='Alfred A. Knopf', Title='Seek My Face'),
#  Row(Publisher='Alfred A. Knopf', Title='Cities of the Plain : A Novel (Border Trilogy, V. 3.)'),
#  Row(Publisher='Alfred A. Knopf', Title='Full Moon'),
#  Row(Publisher='Alfred A. Knopf', Title='Witches of Eastwick'),
#  Row(Publisher='Alfred A. Knopf', Title='Memoirs of a Geisha'),
#  Row(Publisher='Alfred A. Knopf', Title='Memoirs of a Geisha'),
#  Row(Publisher='Alfred A. Knopf', Title='Memoirs of a Geisha'),
#  Row(Publisher='Alfred A. Knopf', Title='Memoirs of a Geisha'),
#  Row(Publisher='Alfred A. Knopf', Title='Memoirs of a Geisha'),
#  Row(Publisher='Alfred A. Knopf', Title='Memoirs of a Geisha'),
#  Row(Publisher='Alfred A. Knopf', Title='Memoirs of a Geisha'),
#  Row(Publisher='Alfred A. Knopf', Title='Memoirs of a Geisha'),
#  Row(Publisher='Alfred A. Knopf', Title='Memoirs of a Geisha'),
#  Row(Publisher='Alfred A. Knopf', Title='Memoirs of a Geisha'),
#  Row(Publisher='Alfred A. Knopf', Title='Memoirs of a Geisha'),
#  Row(Publisher='Alfred A. Knopf', Title='Memoirs of a Geisha'),
#  Row(Publisher='Alfred A. Knopf', Title='Memoirs of a Geisha'),
#  Row(Publisher='Alfred A. Knopf', Title='Memoirs of a Geisha'),
#  Row(Publisher='Alfred A. Knopf', Title='Memoirs of a Geisha'),
#  Row(Publisher='Alfred A. Knopf', Title='Memoirs of a Geisha'),
#  Row(Publisher='Alfred A. Knopf', Title='Memoirs of a Geisha'),
#  Row(Publisher='Alfred A. Knopf', Title='Memoirs of a Geisha'),
#  Row(Publisher='Alfred A. Knopf', Title='Memoirs of a Geisha'),
#  Row(Publisher='Alfred A. Knopf', Title='Paradise'),
#  Row(Publisher='Alfred A. Knopf', Title='National Audubon Society Field Guide to North American Seashore Creatures (Audubon Society Field Guide)'),
#  Row(Publisher='Alfred A. Knopf', Title='Planets and Their Moons (National Audubon Society Pocket Guides)'),
#  Row(Publisher='Alfred A. Knopf', Title='Family Matters'),
#  Row(Publisher='Alfred A. Knopf', Title='For the Relief of Unbearable Urges'),
#  Row(Publisher='Alfred A. Knopf', Title='The Tale of the Body Thief (Vampire Chronicles)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Tale of the Body Thief (Vampire Chronicles)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Tale of the Body Thief (Vampire Chronicles)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Tale of the Body Thief (Vampire Chronicles)'),
#  Row(Publisher='Alfred A. Knopf', Title='Caramelo'),
#  Row(Publisher='Alfred A. Knopf', Title='Caramelo'),
#  Row(Publisher='Alfred A. Knopf', Title='Caramelo'),
#  Row(Publisher='Alfred A. Knopf', Title='The Book of Jewish Food: An Odyssey from Samarkand to New York'),
#  Row(Publisher='Alfred A. Knopf', Title='Rocks and Minerals (Eyewitness Books)'),
#  Row(Publisher='Alfred A. Knopf', Title='Rocks and Minerals (Eyewitness Books)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Complete Walker IV'),
#  Row(Publisher='Alfred A. Knopf', Title='Selected Stories'),
#  Row(Publisher='Alfred A. Knopf', Title='Constellations of the Northern Sky (National Audubon Society Pocket Guides)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Practical Heart: Four Novellas'),
#  Row(Publisher='Alfred A. Knopf', Title='Crossing the Threshold of Hope'),
#  Row(Publisher='Alfred A. Knopf', Title="Imogene's Antlers"),
#  Row(Publisher='Alfred A. Knopf', Title="I Don't Know How She Does It: The Life of Kate Reddy, Working Mother"),
#  Row(Publisher='Alfred A. Knopf', Title="I Don't Know How She Does It: The Life of Kate Reddy, Working Mother"),
#  Row(Publisher='Alfred A. Knopf', Title="I Don't Know How She Does It: The Life of Kate Reddy, Working Mother"),
#  Row(Publisher='Alfred A. Knopf', Title='National Audubon Society Field Guide to the Night Sky (Audubon Society Field Guide Series)'),
#  Row(Publisher='Alfred A. Knopf', Title='American Rhapsody'),
#  Row(Publisher='Alfred A. Knopf', Title='Bare: On Women, Dancing, Sex, and Power'),
#  Row(Publisher='Alfred A. Knopf', Title='Stormy Weather'),
#  Row(Publisher='Alfred A. Knopf', Title="You Read to Me & I'll Read to You: Stories to Share from the 20th Century"),
#  Row(Publisher='Alfred A. Knopf', Title='Familiar Heat: A Novel'),
#  Row(Publisher='Alfred A. Knopf', Title='Presence: Poems (World of Man)'),
#  Row(Publisher='Alfred A. Knopf', Title='Familiar Animal Tracks (The Audubon Society Pocket Guides)'),
#  Row(Publisher='Alfred A. Knopf', Title='The New Yorker Book of Doctor Cartoons and Psychiatrist'),
#  Row(Publisher='Alfred A. Knopf', Title='Making the Team (Angel Park All-Stars (Hardcover))'),
#  Row(Publisher='Alfred A. Knopf', Title='Living a Life That Matters: Resolving the Conflict Between Conscience and Success'),
#  Row(Publisher='Alfred A. Knopf', Title='Living a Life That Matters: Resolving the Conflict Between Conscience and Success'),
#  Row(Publisher='Alfred A. Knopf', Title='The Vampire Armand : The Vampire Chronicles (Rice, Anne, Vampire Chronicles)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Vampire Armand : The Vampire Chronicles (Rice, Anne, Vampire Chronicles)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Vampire Armand : The Vampire Chronicles (Rice, Anne, Vampire Chronicles)'),
#  Row(Publisher='Alfred A. Knopf', Title='Pobby and Dingan'),
#  Row(Publisher='Alfred A. Knopf', Title='Pobby and Dingan'),
#  Row(Publisher='Alfred A. Knopf', Title="Men's Wardrobe (Chic Simple)"),
#  Row(Publisher='Alfred A. Knopf', Title='Sputnik Sweetheart'),
#  Row(Publisher='Alfred A. Knopf', Title='Clothes (Chic Simple)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Remains of the Day'),
#  Row(Publisher='Alfred A. Knopf', Title='Your Baby and Child from Birth to Age Five'),
#  Row(Publisher='Alfred A. Knopf', Title='A Fine Balance'),
#  Row(Publisher='Alfred A. Knopf', Title='Encore Provence'),
#  Row(Publisher='Alfred A. Knopf', Title='Encore Provence'),
#  Row(Publisher='Alfred A. Knopf', Title='National Audubon Society Field Guide to Fishes: North America'),
#  Row(Publisher='Alfred A. Knopf', Title='The Halloween Tree'),
#  Row(Publisher='Alfred A. Knopf', Title='Sons of Mississippi: A Story of Race and Its Legacy'),
#  Row(Publisher='Alfred A. Knopf', Title='The Pencil: A History of Design and Circumstance'),
#  Row(Publisher='Alfred A. Knopf', Title="The Endurance: Shackleton's Legendary Antarctic Expedition"),
#  Row(Publisher='Alfred A. Knopf', Title="The Endurance: Shackleton's Legendary Antarctic Expedition"),
#  Row(Publisher='Alfred A. Knopf', Title="Spontaneous Healing: How to Discover and Enhance Your Body's Natural Ability to Maintain and Heal Itself"),
#  Row(Publisher='Alfred A. Knopf', Title="Spontaneous Healing: How to Discover and Enhance Your Body's Natural Ability to Maintain and Heal Itself"),
#  Row(Publisher='Alfred A. Knopf', Title='Merrick (Vampire Chronicles)'),
#  Row(Publisher='Alfred A. Knopf', Title='Merrick (Vampire Chronicles)'),
#  Row(Publisher='Alfred A. Knopf', Title='Merrick (Vampire Chronicles)'),
#  Row(Publisher='Alfred A. Knopf', Title='Dogwalker: Stories'),
#  Row(Publisher='Alfred A. Knopf', Title='National Audubon Society Field Guide to North American Wildflowers: Eastern Region (Audubon Society Field Guide)'),
#  Row(Publisher='Alfred A. Knopf', Title='National Audubon Society Field Guide to North American Wildflowers: Eastern Region (Audubon Society Field Guide)'),
#  Row(Publisher='Alfred A. Knopf', Title='National Audubon Society Field Guide to North American Wildflowers: Eastern Region (Audubon Society Field Guide)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Lost World: A Novel'),
#  Row(Publisher='Alfred A. Knopf', Title='Dark Lady'),
#  Row(Publisher='Alfred A. Knopf', Title='Dark Lady'),
#  Row(Publisher='Alfred A. Knopf', Title='Gertrude and Claudius'),
#  Row(Publisher='Alfred A. Knopf', Title='The Collected Poems of Langston Hughes'),
#  Row(Publisher='Alfred A. Knopf', Title='The Crossing (Border Trilogy, Vol 2)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Crossing (Border Trilogy, Vol 2)'),
#  Row(Publisher='Alfred A. Knopf', Title='Balzac and the Little Chinese Seamstress'),
#  Row(Publisher='Alfred A. Knopf', Title='Balzac and the Little Chinese Seamstress'),
#  Row(Publisher='Alfred A. Knopf', Title='Balzac and the Little Chinese Seamstress'),
#  Row(Publisher='Alfred A. Knopf', Title='Balzac and the Little Chinese Seamstress'),
#  Row(Publisher='Alfred A. Knopf', Title='The Chocolate War'),
#  Row(Publisher='Alfred A. Knopf', Title='Deserts (Audubon Society Nature Guides)'),
#  Row(Publisher='Alfred A. Knopf', Title='Mother, Mother, I Want Another'),
#  Row(Publisher='Alfred A. Knopf', Title='Swimming Toward the Ocean'),
#  Row(Publisher='Alfred A. Knopf', Title='Sand and Foam: A Book of Aphorisms (The Kahlil Gibran Pocket Library)'),
#  Row(Publisher='Alfred A. Knopf', Title='National Audubon Society Field Guide to North American Butterflies (Audubon Society Field Guide)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Sibley Guide to Birds'),
#  Row(Publisher='Alfred A. Knopf', Title='Practicing Resurrection: A Memoir of Work, Doubt, Discernment, and Moments of Grace'),
#  Row(Publisher='Alfred A. Knopf', Title='E-Mail This Book!'),
#  Row(Publisher='Alfred A. Knopf', Title="Ava's Man"),
#  Row(Publisher='Alfred A. Knopf', Title='The New Yorker Book of Dog Cartoons'),
#  Row(Publisher='Alfred A. Knopf', Title='The New Yorker Book of Dog Cartoons'),
#  Row(Publisher='Alfred A. Knopf', Title='The New Yorker Book of Dog Cartoons'),
#  Row(Publisher='Alfred A. Knopf', Title='The Emperor of Ocean Park (Today Show Book Club #1)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Emperor of Ocean Park (Today Show Book Club #1)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Emperor of Ocean Park (Today Show Book Club #1)'),
#  Row(Publisher='Alfred A. Knopf', Title='All the Pretty Horses (Border Trilogy, Vol 1)'),
#  Row(Publisher='Alfred A. Knopf', Title='All the Pretty Horses (Border Trilogy, Vol 1)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Prophet'),
#  Row(Publisher='Alfred A. Knopf', Title='The Prophet'),
#  Row(Publisher='Alfred A. Knopf', Title='The Prophet'),
#  Row(Publisher='Alfred A. Knopf', Title='The Prophet'),
#  Row(Publisher='Alfred A. Knopf', Title='The Prophet'),
#  Row(Publisher='Alfred A. Knopf', Title='The Prophet'),
#  Row(Publisher='Alfred A. Knopf', Title='The Prophet'),
#  Row(Publisher='Alfred A. Knopf', Title='The Prophet'),
#  Row(Publisher='Alfred A. Knopf', Title='The Prophet'),
#  Row(Publisher='Alfred A. Knopf', Title='The Prophet'),
#  Row(Publisher='Alfred A. Knopf', Title='The Prophet'),
#  Row(Publisher='Alfred A. Knopf', Title='The Prophet'),
#  Row(Publisher='Alfred A. Knopf', Title='Money (Eyewitness Books)'),
#  Row(Publisher='Alfred A. Knopf', Title='Ug: Boy Genius of the Stone Age and His Search for Soft Trousers'),
#  Row(Publisher='Alfred A. Knopf', Title='Essentials of Classic Italian Cooking'),
#  Row(Publisher='Alfred A. Knopf', Title="I'll Always Love You"),
#  Row(Publisher='Alfred A. Knopf', Title="The 20th-Century Children's Book Treasury: Picture Books and Stories to Read Aloud"),
#  Row(Publisher='Alfred A. Knopf', Title='The Prophet (Kahlil Gibran Pocket Library)'),
#  Row(Publisher='Alfred A. Knopf', Title='My Dark Places: An L.A. Crime Memoir'),
#  Row(Publisher='Alfred A. Knopf', Title='The Wind-Up Bird Chronicle'),
#  Row(Publisher='Alfred A. Knopf', Title='Cat (Eyewitness Books (Knopf))'),
#  Row(Publisher='Alfred A. Knopf', Title="Marmalade's Snowy Day"),
#  Row(Publisher='Alfred A. Knopf', Title='Disclosure'),
#  Row(Publisher='Alfred A. Knopf', Title='Disclosure'),
#  Row(Publisher='Alfred A. Knopf', Title='Disclosure'),
#  Row(Publisher='Alfred A. Knopf', Title='Personal History'),
#  Row(Publisher='Alfred A. Knopf', Title="In the Kitchen With Rosie: Oprah's Favorite Recipes"),
#  Row(Publisher='Alfred A. Knopf', Title="In the Kitchen With Rosie: Oprah's Favorite Recipes"),
#  Row(Publisher='Alfred A. Knopf', Title="In the Kitchen With Rosie: Oprah's Favorite Recipes"),
#  Row(Publisher='Alfred A. Knopf', Title='My Wicked Wicked Ways'),
#  Row(Publisher='Alfred A. Knopf', Title='Flipped'),
#  Row(Publisher='Alfred A. Knopf', Title='Hiroshima'),
#  Row(Publisher='Alfred A. Knopf', Title='Hotel Pastis: A Novel of Provence'),
#  Row(Publisher='Alfred A. Knopf', Title='Queen of the Damned (Vampire Chronicles, Book III)'),
#  Row(Publisher='Alfred A. Knopf', Title='Queen of the Damned (Vampire Chronicles, Book III)'),
#  Row(Publisher='Alfred A. Knopf', Title='Queen of the Damned (Vampire Chronicles, Book III)'),
#  Row(Publisher='Alfred A. Knopf', Title='Queen of the Damned (Vampire Chronicles, Book III)'),
#  Row(Publisher='Alfred A. Knopf', Title='Queen of the Damned (Vampire Chronicles, Book III)'),
#  Row(Publisher='Alfred A. Knopf', Title='Lost World'),
#  Row(Publisher='Alfred A. Knopf', Title='Lost World'),
#  Row(Publisher='Alfred A. Knopf', Title='Dead and Gone (Burke Novels)'),
#  Row(Publisher='Alfred A. Knopf', Title='Dead and Gone (Burke Novels)'),
#  Row(Publisher='Alfred A. Knopf', Title='Lasso the Wind : Away to the New West'),
#  Row(Publisher='Alfred A. Knopf', Title='You and Your Dog'),
#  Row(Publisher='Alfred A. Knopf', Title='National Audubon Society Guide to Marine Mammals of the World (National Audubon Society Field Guide Series.)'),
#  Row(Publisher='Alfred A. Knopf', Title='Julia and Jacques Cooking at Home'),
#  Row(Publisher='Alfred A. Knopf', Title="Eight Weeks to Optimum Health: A Proven Program for Taking Full Advantage of Your Body's Natural Healing Power (Proven Program for Taking Full Advantage of Your Body's Natural Healing Power)"),
#  Row(Publisher='Alfred A. Knopf', Title="Eight Weeks to Optimum Health: A Proven Program for Taking Full Advantage of Your Body's Natural Healing Power (Proven Program for Taking Full Advantage of Your Body's Natural Healing Power)"),
#  Row(Publisher='Alfred A. Knopf', Title="Eight Weeks to Optimum Health: A Proven Program for Taking Full Advantage of Your Body's Natural Healing Power (Proven Program for Taking Full Advantage of Your Body's Natural Healing Power)"),
#  Row(Publisher='Alfred A. Knopf', Title="Eight Weeks to Optimum Health: A Proven Program for Taking Full Advantage of Your Body's Natural Healing Power (Proven Program for Taking Full Advantage of Your Body's Natural Healing Power)"),
#  Row(Publisher='Alfred A. Knopf', Title='The Amber Spyglass (His Dark Materials, Book 3)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Amber Spyglass (His Dark Materials, Book 3)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Amber Spyglass (His Dark Materials, Book 3)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Amber Spyglass (His Dark Materials, Book 3)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Amber Spyglass (His Dark Materials, Book 3)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Amber Spyglass (His Dark Materials, Book 3)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Amber Spyglass (His Dark Materials, Book 3)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Amber Spyglass (His Dark Materials, Book 3)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Family Orchard: A Novel'),
#  Row(Publisher='Alfred A. Knopf', Title='Sick Puppy'),
#  Row(Publisher='Alfred A. Knopf', Title='Sick Puppy'),
#  Row(Publisher='Alfred A. Knopf', Title='Sick Puppy'),
#  Row(Publisher='Alfred A. Knopf', Title='Taltos: Lives of the Mayfair Witches'),
#  Row(Publisher='Alfred A. Knopf', Title='Taltos: Lives of the Mayfair Witches'),
#  Row(Publisher='Alfred A. Knopf', Title='Taltos: Lives of the Mayfair Witches'),
#  Row(Publisher='Alfred A. Knopf', Title="How We Die: Reflections on Life's Final Chapter"),
#  Row(Publisher='Alfred A. Knopf', Title='Familiar Flowers of North America: Eastern Region (The Audubon Society Pocket Guides)'),
#  Row(Publisher='Alfred A. Knopf', Title='Rabbit at Rest'),
#  Row(Publisher='Alfred A. Knopf', Title='Blood and Gold (Vampire Chronicles)'),
#  Row(Publisher='Alfred A. Knopf', Title='Blood and Gold (Vampire Chronicles)'),
#  Row(Publisher='Alfred A. Knopf', Title='Blood and Gold (Vampire Chronicles)'),
#  Row(Publisher='Alfred A. Knopf', Title='The Piano Tuner'),
#  Row(Publisher='Alfred A. Knopf', Title='The Piano Tuner'),
#  Row(Publisher='Alfred A. Knopf', Title='The Piano Tuner'),
#  Row(Publisher='Alfred A. Knopf', Title="Nobody's Perfect: Selected Writings from the New Yorker"),
#  Row(Publisher='Alfred A. Knopf', Title='Charlie and the Chocolate Factory'),
#  Row(Publisher='Alfred E Knopf', Title='The History of Luminous Motion'),
#  Row(Publisher='Alfred E Knopf', Title='The History of Luminous Motion'),
#  Row(Publisher='Alianza', Title='Obras 4'),
#  Row(Publisher='Alianza', Title='El Viaje de Baldassare'),
#  Row(Publisher='Alianza', Title='El Fantasma De Canterville'),
#  Row(Publisher='Alianza', Title='Caso de Charles Dexter Ward, El'),
#  Row(Publisher='Alianza', Title='La tregua'),
#  Row(Publisher='Alianza', Title='Tres Mosqueteros, Los'),
#  Row(Publisher='Alianza', Title='Ernestina O El Nacimiento del Amor'),
#  Row(Publisher='Alianza', Title='Artificios'),
#  Row(Publisher='Alianza', Title='Artificios'),
#  Row(Publisher='Alianza', Title='El Perseguidor'),
#  Row(Publisher='Alianza', Title='Nueve Cuentos'),
#  Row(Publisher='Alianza', Title='Obras 1'),
#  Row(Publisher='Alianza', Title='El Hacedor'),
#  Row(Publisher='Alianza', Title='Demian'),
#  Row(Publisher='Alianza', Title='Mi familia y otros animales'),
#  Row(Publisher='Alianza', Title='Niebla'),
#  Row(Publisher='Alianza', Title='Cosecha Roja'),
#  Row(Publisher='Alianza', Title='Antologia Poetica'),
#  Row(Publisher='Alianza', Title='Poemas y Canciones'),
#  Row(Publisher='Alianza', Title='Ecce homo'),
#  Row(Publisher='Alianza', Title='Los Mitos de Cthulhu'),
#  Row(Publisher='Alianza', Title='El Cine'),
#  Row(Publisher='Alianza', Title='El Aleph'),
#  Row(Publisher='Alianza', Title='El Aleph'),
#  Row(Publisher='Alianza', Title='El Aleph'),
#  Row(Publisher='Alianza', Title='Obras 3'),
#  Row(Publisher='Alianza', Title='El lobo estepario'),
#  Row(Publisher='Alianza', Title='Maestro y Margarita, El'),
#  Row(Publisher='Alianza', Title='Obras 2'),
#  Row(Publisher='Alianza', Title='Relatos del Piloto Prix'),
#  Row(Publisher='Alianza', Title='Obras 5'),
#  Row(Publisher='Alianza', Title='Demian'),
#  Row(Publisher='Alianza', Title='El Horla'),
#  Row(Publisher='Alianza', Title='Lobo Estepario, El'),
#  Row(Publisher='Alianza', Title='Lobo Estepario, El'),
#  Row(Publisher='Aliform Pub', Title='My World Is Not of This Kingdom'),
#  Row(Publisher='Allan', Title='Warships of World War II'),
#  Row(Publisher='Allcat Pr', Title='A Trellis for Mr. Ellis Or, How I Saved the World from Global Warming'),
#  Row(Publisher='Allen & Unwin Pty Ltd', Title='The sunken road'),
#  Row(Publisher="Allen & Unwin children's books", Title='The Quicksand Pony (A Little Ark Book)'),
#  Row(Publisher='Allia', Title='Livre et typographie'),
#  Row(Publisher='Allia', Title='De la bÃ?Âªtise'),
#  Row(Publisher='Alliance for Committed Civic Engagement & Social Solutions (ACCESS)', Title='Savoring Seattle'),
#  Row(Publisher='Allied Mouse', Title='The Heartstone Odyssey'),
#  Row(Publisher='Allyn &amp; Bacon', Title='Statistics Without Tears: A Primer for Non-Mathematicians (Allyn & Bacon Classics Edition)'),
#  Row(Publisher='Almarabu', Title='Por boca de los dioses (Textos tÃ\xadmidos)'),
#  Row(Publisher='Alpha Books', Title="Complete Idiot's Guide to Getting Your Romance Published"),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Getting Along with Difficult People"),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Handwriting Analysis"),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Knitting & Crocheting"),
#  Row(Publisher='Alpha Books', Title="Complete Idiot's Guide to Throwing a Great Party"),
#  Row(Publisher='Alpha Books', Title="Complete Idiot's Guide to Wicca and Witchcraft"),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Yoga Illustrated, Third Edition"),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Classical Music"),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Understanding Buddhism"),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Understanding Buddhism"),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to the American Revolution"),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Dog Health and Nutrition (Complete Idiot's Guides (Lifestyle Paperback))"),
#  Row(Publisher='Alpha Books', Title='Power Over Panic (2nd Edition)'),
#  Row(Publisher='Alpha Books', Title="The Pocket Idiot's Guide to Being a Groom"),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Philosophy (2nd Edition)"),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Astrology (2nd Edition)"),
#  Row(Publisher='Alpine Publications, Inc.', Title='Understanding Showmanship: Everything You Need to Know to Win in Showmanship Classes'),
#  Row(Publisher='Alpine Publications, Inc.', Title='How to Raise a Puppy You Can Live With'),
#  Row(Publisher='Altitude Publishing Ltd', Title='Vancouver Panorama'),
#  Row(Publisher='Alvarellos', Title='Os mil e un refrÃ¡ns galegos da muller'),
#  Row(Publisher='Alyson Pubns', Title="That's Mr. Faggot to You : Further Trials from My Queer Life"),
#  Row(Publisher='Alyson Pubns', Title='My Big Fat Queer Life: The Best of Michael Thomas Ford'),
#  Row(Publisher='Amadeus', Title="The Invaluable Guide to Life After Stroke: An Owner's Manual"),
#  Row(Publisher='Amer Inst of Chemical Engineers', Title='Project Management for the Process Industry'),
#  Row(Publisher='Amer Philosophical Society', Title="One Grand Pursuit: A Brief History of the American Philosophical Society's First 250 Years, 1743-1993"),
#  Row(Publisher='Amer Psychological Assn', Title='Publication Manual of the American Psychological Association (Publication Manual of the American Psychological Association, 4th ed)'),
#  Row(Publisher='Amer Psychological Assn', Title='Publication Manual of the American Psychological Association (Publication Manual of the American Psychological Association, 4th ed)'),
#  Row(Publisher='Amer Red Cross', Title='Advanced First Aid and Emergency Care'),
#  Row(Publisher='Amer Society for Microbiology', Title='Manual of Clinical Microbiology/Pa1-030-6'),
#  Row(Publisher="America's Test Kitchen", Title='Baking Illustrated: A Best Recipe Classic (The Best Recipe Series)'),
#  Row(Publisher='American Alpine Club', Title='High Alaska: A Historical Guide to Denali Mount Foraker and Mount Hunter'),
#  Row(Publisher='American Alpine Club', Title='Accidents in North American Mountaineering 2001: Issue 54 (Accidents in North American Mountaineering, 2001)'),
#  Row(Publisher='American Diabetes Association', Title='The Commonsense Guide to Weight Loss'),
#  Row(Publisher='American Photographic Book Pub. Co', Title='Amphoto guide to SLR photography (Amphoto guide series)'),
#  Row(Publisher='American Planning Association', Title='City Zoning: The Once and Future Frontier'),
#  Row(Publisher='American Psychiatric Association', Title='Diagnostic and Statistical Manual of Mental Disorders DSM-IV-TR (Text Revision)'),
#  Row(Publisher='American Publishing Corp.', Title='Proven Health Tips Encyclopedia'),
#  Row(Publisher='American Self-Help Group Clearinghouse', Title='The Self-Help Group Sourcebook: Your Guide to Community & Online Support Groups'),
#  Row(Publisher='American Trust Publications', Title="The Child in Islam: A Muslim Parent's Handbook"),
#  Row(Publisher='American Value Tales', Title='Jacob JingleHinder (Earth angels)'),
#  Row(Publisher='Amethyst Books', Title='AIDS and the Healer Within'),
#  Row(Publisher='Amok Books', Title='Amok Journal Sensurround Edition'),
#  Row(Publisher='An RGA Production', Title="Sometimes it's O.K. to be Angry! (A Parent/Child Manual for the Education of Children)"),
#  Row(Publisher='An RGA Production', Title="Sometimes it's O.K. to be Angry! (A Parent/Child Manual for the Education of Children)"),
#  Row(Publisher='An RGA Production', Title="Sometimes it's O.K. to be Angry! (A Parent/Child Manual for the Education of Children)"),
#  Row(Publisher='Anagrama, Editorial S.A.', Title='Gressiones, Eyaculaciones, Exhibiciones'),
#  Row(Publisher='Anagrama, Editorial S.A.', Title='El Lector'),
#  Row(Publisher='Anchor Bible Commentary', Title='Judges (Anchor Bible)'),
#  Row(Publisher='Anchor Books', Title='A street in Marrakech'),
#  Row(Publisher='Anchor Distributors', Title="Bringin' Em Back Alive: Reaching Your World for Jesus"),
#  Row(Publisher='Anchor Press', Title='Darkness and scattered light: Four talks on the future'),
#  Row(Publisher='Anderson World', Title="Women's Running"),
#  Row(Publisher='AndrÃ© Deutsch', Title="Pa's top hat"),
#  Row(Publisher='Angel Books', Title="Deutschland: A Winter's Tale : Bilingual Edition"),
#  Row(Publisher='Angela Royal Publishing', Title='Food for Love'),
#  Row(Publisher='Anglican Book Centre', Title='Moratorium: Justice, energy, the north, and the native people'),
#  Row(Publisher='Angsana Books', Title='The Seriously Funny Anti-Stress Book'),
#  Row(Publisher='Ann Arbor Media Group', Title='The Road to Oz'),
#  Row(Publisher='Annick Press', Title='Foo (Annikins #16)'),
#  Row(Publisher='Annick Press', Title='I Have to See This (Jesse Adventure Series)'),
#  Row(Publisher='Annick Press', Title='I Have to See This (Jesse Adventure Series)'),
#  Row(Publisher='Annick Press', Title='Purple, Green and Yellow'),
#  Row(Publisher='Annick Press', Title='Red Is Best'),
#  Row(Publisher='Annick Press', Title='Mortimer (Munsch for Kids)'),
#  Row(Publisher='Annick Press', Title="Le Rouge C'Est Bien Meiux / Red is Best"),
#  Row(Publisher='Annick Press', Title='On the Go'),
#  Row(Publisher='Annick Press', Title='Milocent & the Wind (Annikins #07)'),
#  Row(Publisher='Annick Press', Title='Something Good (Munsch for Kids)'),
#  Row(Publisher='Annick Press', Title='Paper Bag Princess (Munsch for Kids)'),
#  Row(Publisher='Annick Press', Title='Foo (Jesse Adventure Series)'),
#  Row(Publisher='Annick Press', Title='Foo (Jesse Adventure Series)'),
#  Row(Publisher='Annick Press', Title='Stella Street and Everything That Happened'),
#  Row(Publisher='Annick Press', Title='Why the West Was Wild'),
#  Row(Publisher='Annick Press', Title='Generals Die in Bed: A Story from the Trenches'),
#  Row(Publisher="Antique Collectors' Club", Title='The Glitter & the Gold: Fashioning Americas Jewelry'),
#  Row(Publisher="Antique Collectors' Club", Title='Fountain Pens: History and Design'),
#  Row(Publisher='Anything Books', Title='Anything Book : Unicorn Silver On Blue'),
#  Row(Publisher='Apollo Editions', Title='Trilogy of Desire, Vol. 3 the Stoic'),
#  Row(Publisher='Apple Signature (Scholastic)', Title='Into the Land of the Unicorns (Unicorn Chronicles)'),
#  Row(Publisher='Apple Signature (Scholastic)', Title='Into the Land of the Unicorns (Unicorn Chronicles)'),
#  Row(Publisher='Apple Signature (Scholastic)', Title='The Illusion (Animorphs, 33)'),
#  Row(Publisher='Apricot Press', Title='How to Make People Think You Are Normal'),
#  Row(Publisher='Apricot Press', Title="Geezerhood: What to expect from life now that you're as old as dirt"),
#  Row(Publisher='Aqua Explorers', Title='Florida Shipwrecks: The Divers Guide to Shipwrecks Around the State of Florida and the Florida Keys'),
#  Row(Publisher='Aramith', Title='Turbo-taal: Van socio-babble tot yuppie-speak'),
#  Row(Publisher='Aramith', Title='Turbo-taal: Van socio-babble tot yuppie-speak'),
#  Row(Publisher='Arbeiderspers', Title='Het instituut: Roman'),
#  Row(Publisher='Arbeiderspers', Title='De laatste deur: Essays over zelfmoord in de Nederlandstalige letteren (Synopsis)'),
#  Row(Publisher='Arcade Pub', Title='Dictionary of word origins'),
#  Row(Publisher='Arch Books', Title="Mary's Christmas Story: Luke 1:26-56, Luke 2:1-20 for Children (Learning Bible Stories Is Fun With Arch Books)"),
#  Row(Publisher='Arch Books', Title='The Week That Led to Easter: The Story of Holy Week Matthew 21:1-28:10, Mark 11:1-16:8, Luke 12:29-24:12, and John 12:12-20:10 for Children (Arch Books)'),
#  Row(Publisher='Arch Books', Title='Baby Born in a Stable (Arch Books (English))'),
#  Row(Publisher='Archiv der Deutschen Jugendbewegung', Title='Aufbruch und Erinnerung: Der Freideutsche Kreis als Generationseinheit im 20. Jahrhundert (Edition Archiv der Deutschen Jugendbewegung)'),
#  Row(Publisher='Archive Press', Title='Earth Abides'),
#  Row(Publisher='Arden Publishers', Title='The Tempest (Arden Shakespeare, Third Series Editions)'),
#  Row(Publisher='Ardis Publishers', Title='Collected Narrative and Lyrical Poetry'),
#  Row(Publisher='Arena Verlag GmbH', Title='Der Schonste Hund Der Welt = The Best Dog in the World'),
#  Row(Publisher='Argyll Publishing', Title='Far from the Rowan Tree'),
#  Row(Publisher='Ariel Publications', Title='Atila'),
#  Row(Publisher='Ariel Publications', Title='John F. Kennedy Jr.: A Life in the Spotlight'),
#  Row(Publisher='ArlÃ?Â©a', Title='La Mouette juive'),
#  Row(Publisher='ArlÃ?Â©a', Title='Neige'),
#  Row(Publisher='Arno Press; distributed by Crown Publishers', Title='The dictionary of needlework;: An encyclopaedia of artistic, plain, and fancy needlework'),
#  Row(Publisher='Arrow Designs', Title='The Mummy Garden'),
#  Row(Publisher='ArsDigita Press', Title='Travels with Samantha'),
#  Row(Publisher='Arsenale', Title='Churches of Venice (I Piccoli Di Arsenale)'),
#  Row(Publisher='Arte Publico Press', Title='Luis Valdez Early Works: Actos, Bernabe and Pensamiento Serpentino'),
#  Row(Publisher='Arte Publico Press', Title='Zoot Suit and Other Plays'),
#  Row(Publisher='Arte Publico Press', Title='A Fabricated Mexican'),
#  Row(Publisher='Arthur A. Levine', Title='The Year of Secret Assignments'),
#  Row(Publisher='Arx Publishing', Title='Dream of Fire'),
#  Row(Publisher='Ashford Press', Title='All gourmets great and small'),
#  Row(Publisher='Ashford Press', Title='All gourmets great and small'),
#  Row(Publisher='Asia Books', Title='Another Quiet American: Stories of Life in Laos'),
#  Row(Publisher="Asian American Writers' Workshop", Title="Flippin': Filipinos on America"),
#  Row(Publisher='Asn Pub', Title='The Crochet Yearbook Volume 1 (1303)'),
#  Row(Publisher='Aspen Law & Business Publishers', Title='Kohn on Music Licensing (2nd Editon)'),
#  Row(Publisher='Aspen Systems Corp', Title='Abnormal postural reflex activity caused by brain lesions'),
#  Row(Publisher='Aspen West Publishing', Title="Where's Mom Now That I Need Her?: Surviving Away from Home"),
#  Row(Publisher='Assn for Childhood Education Intl', Title='Opening, Mixing, Matching'),
#  Row(Publisher='Associated Publishers Group', Title='The Dilemma: A Memoir'),
#  Row(Publisher='Association for Supervision & Curriculum Deve', Title='Winning Strategies for Classroom Management'),
#  Row(Publisher='Assouline', Title='Portraits'),
#  Row(Publisher='Athena V Lord', Title='Pilot for Spaceship Earth: R. Buckminster Fuller, Architect, Inventor, and Poet'),
#  Row(Publisher='Athenaeum/Polak & Van Gennep', Title='Gebroken lied: Een vriendschap met Ida Gerhardt'),
# ...
#  Row(Publisher='BRAVA', Title='All Through the Night'),
#  Row(Publisher='BRAVA', Title='Too Much Temptation'),
#  Row(Publisher='BRAVA', Title='Too Much Temptation'),
#  Row(Publisher='BRAVA', Title='Bad Boys on Board'),
#  Row(Publisher='Bad Dog Pr', Title='How to Get Rid of a Telemarketer'),
#  Row(Publisher='Bad Intentions Press', Title='Murdering America, Inc.'),
#  Row(Publisher='Badlands Natural History Assn', Title='Where Buffalo Roam'),
#  Row(Publisher='Baker & Taylor Video', Title='Favorite Lullaby Songs to Share (My First Sing-Along)'),
#  Row(Publisher='Baker Publishing', Title='One Hundred One Simple Things You Can Do to Stay on a Diet and Lose Weight'),
#  Row(Publisher='Baldini & Castoldi', Title='Bastogne (Romanzi e racconti)'),
#  Row(Publisher='Baldini & Castoldi', Title="Va' dove ti porta il cuore (Romanzi e racconti)"),
#  Row(Publisher='Ballantine', Title='Have space suit--will travel'),
#  Row(Publisher='Ballantine', Title='Crystal singer'),
#  Row(Publisher='Ballantine Books (Trd Pap)', Title='Widows'),
#  Row(Publisher='Ballentyne & Balfour', Title='The Trusted'),
#  Row(Publisher='Balmur Book Publishing', Title='What A Wonderful World'),
#  Row(Publisher='Bantam Books', Title='The Depths of Time (Bantam Spectra Book)'),
#  Row(Publisher='Bantam Books', Title='Strangers at Dawn'),
#  Row(Publisher='Bantam Books', Title='Four Great Plays by Chekhov'),
#  Row(Publisher='Bantam Books', Title='The Pill Book (8th ed)'),
#  Row(Publisher='Bantam Books', Title='Tad Overweight, but Violet Eyes to Die for'),
#  Row(Publisher='Bantam Books', Title='Bearer of the Pipe (Spanish Bit Saga of the Plains Indians)'),
#  Row(Publisher='Bantam Books', Title='Disney Library, 2 (Walt Disney Fun-To-Learn Library)'),
#  Row(Publisher='Bantam Books', Title='River of Swans (Spanish Bit Saga, No 10)'),
#  Row(Publisher='Bantam Books', Title='Akin to Anne: Tales of Other Orphans'),
#  Row(Publisher='Bantam Books', Title='Hannibal'),
#  Row(Publisher='Bantam Books', Title='House Atreides (Dune: House Trilogy, Book 1)'),
#  Row(Publisher='Bantam Books', Title='House Atreides (Dune: House Trilogy, Book 1)'),
#  Row(Publisher='Bantam Books', Title='House Atreides (Dune: House Trilogy, Book 1)'),
#  Row(Publisher='Bantam Books', Title='The Wakefields of Sweet Valley (Sweet Valley Saga (Paperback))'),
#  Row(Publisher='Bantam Books', Title='How to Survive the Loss of a Love: 58 Things to Do when There is Nothing to be Done'),
#  Row(Publisher='Bantam Books', Title='How to Survive the Loss of a Love: 58 Things to Do when There is Nothing to be Done'),
#  Row(Publisher='Bantam Books', Title='The Guinness Book of World Records 1998 (Guinness Book of Records, 1998)'),
#  Row(Publisher='Bantam Books', Title='The Cosmic Code: Quantum Physics As the Language of Nature'),
#  Row(Publisher='Bantam Books', Title='Sins of Innocence'),
#  Row(Publisher='Bantam Books', Title='Out of the Shadows (Shadows Trilogy (Paperback))'),
#  Row(Publisher='Bantam Books', Title='Sons and Lovers (Bantam Classics)'),
#  Row(Publisher='Bantam Books', Title='Distraction: A Novel'),
#  Row(Publisher='Bantam Books', Title='Of Mice and Men'),
#  Row(Publisher='Bantam Books', Title='Of Mice and Men'),
#  Row(Publisher='Bantam Books', Title='Of Mice and Men'),
#  Row(Publisher='Bantam Books', Title='Of Mice and Men'),
#  Row(Publisher='Bantam Books', Title='Wild Kat (Kat Colorado Mysteries)'),
#  Row(Publisher='Bantam Books', Title='Dream Country'),
#  Row(Publisher='Bantam Books', Title='Dream Country'),
#  Row(Publisher='Bantam Books', Title='Dream Country'),
#  Row(Publisher='Bantam Books', Title='Dream Country'),
#  Row(Publisher='Bantam Books', Title='Dream Country'),
#  Row(Publisher='Bantam Books', Title='Trinity'),
#  Row(Publisher='Bantam Books', Title='Trinity'),
#  Row(Publisher='Bantam Books', Title='Dragonsinger'),
#  Row(Publisher='Bantam Books', Title='Dragonsinger'),
#  Row(Publisher='Bantam Books', Title="George's Marvelous Medicine"),
#  Row(Publisher='Bantam Books', Title='Vertical Run'),
#  Row(Publisher='Bantam Books', Title='Vertical Run'),
#  Row(Publisher='Bantam Books', Title='Vertical Run'),
#  Row(Publisher='Bantam Books', Title='The Main Corpse (Culinary Mysteries (Paperback))'),
#  Row(Publisher='Bantam Books', Title='The Main Corpse (Culinary Mysteries (Paperback))'),
#  Row(Publisher='Bantam Books', Title='The Main Corpse (Culinary Mysteries (Paperback))'),
#  Row(Publisher='Bantam Books', Title='The Main Corpse (Culinary Mysteries (Paperback))'),
#  Row(Publisher='Bantam Books', Title='The Main Corpse (Culinary Mysteries (Paperback))'),
#  Row(Publisher='Bantam Books', Title='The Main Corpse (Culinary Mysteries (Paperback))'),
#  Row(Publisher='Bantam Books', Title='The Main Corpse (Culinary Mysteries (Paperback))'),
#  Row(Publisher='Bantam Books', Title='The Main Corpse (Culinary Mysteries (Paperback))'),
#  Row(Publisher='Bantam Books', Title='The Main Corpse (Culinary Mysteries (Paperback))'),
#  Row(Publisher='Bantam Books', Title='The Main Corpse (Culinary Mysteries (Paperback))'),
#  Row(Publisher='Bantam Books', Title='Battle Born'),
#  Row(Publisher='Bantam Books', Title='Battle Born'),
#  Row(Publisher='Bantam Books', Title='After Caroline'),
#  Row(Publisher='Bantam Books', Title='After Caroline'),
#  Row(Publisher='Bantam Books', Title="Dutchman's Flat"),
#  Row(Publisher='Bantam Books', Title='In a Class by Itself'),
#  Row(Publisher='Bantam Books', Title='The Patient'),
#  Row(Publisher='Bantam Books', Title='The Patient'),
#  Row(Publisher='Bantam Books', Title='Once an Angel'),
#  Row(Publisher='Bantam Books', Title='Persuasion'),
#  Row(Publisher='Bantam Books', Title='Persuasion'),
#  Row(Publisher='Bantam Books', Title="Robin Macnaughton's Sun Sign Personality Guide"),
#  Row(Publisher='Bantam Books', Title='Screwtape Letters'),
#  Row(Publisher='Bantam Books', Title='The Perfect Summer'),
#  Row(Publisher='Bantam Books', Title='The Perfect Summer'),
#  Row(Publisher='Bantam Books', Title='Lila: An Inquiry Into Morals'),
#  Row(Publisher='Bantam Books', Title='Lila: An Inquiry Into Morals'),
#  Row(Publisher='Bantam Books', Title='Lila: An Inquiry Into Morals'),
#  Row(Publisher='Bantam Books', Title='Moon of Thunder (Spanish Bit Saga of the Plains Indians)'),
#  Row(Publisher='Bantam Books', Title='Sensuous Perception'),
#  Row(Publisher='Bantam Books', Title='Magister Ludi: The Glass Bead Game'),
#  Row(Publisher='Bantam Books', Title='Penny Pinching'),
#  Row(Publisher='Bantam Books', Title='Brazen Virtue'),
#  Row(Publisher='Bantam Books', Title='Magister Ludi'),
#  Row(Publisher='Bantam Books', Title='Tinker Tailor Soldier Spy'),
#  Row(Publisher='Bantam Books', Title='A Better Way to Live'),
#  Row(Publisher='Bantam Books', Title='A Better Way to Live'),
#  Row(Publisher='Bantam Books', Title='A Better Way to Live'),
#  Row(Publisher='Bantam Books', Title='Off the Mangrove Coast'),
#  Row(Publisher='Bantam Books', Title='The Secret Adversary'),
#  Row(Publisher='Bantam Books', Title='Colour of Magic (Graphic Edition)'),
#  Row(Publisher='Bantam Books', Title='The Northbury Papers'),
#  Row(Publisher='Bantam Books', Title='People of the Deer (Seal Books)'),
#  Row(Publisher='Bantam Books', Title='People of the Deer (Seal Books)'),
#  Row(Publisher='Bantam Books', Title='People of the Deer (Seal Books)'),
#  Row(Publisher='Bantam Books', Title='The Herb Book'),
#  Row(Publisher='Bantam Books', Title='The Herb Book'),
#  Row(Publisher='Bantam Books', Title='The Herb Book'),
#  Row(Publisher='Bantam Books', Title='The Herb Book'),
#  Row(Publisher='Bantam Books', Title='Shadow Dawn (Chronicles of the Shadow War, Book 2)'),
#  Row(Publisher='Bantam Books', Title='Shadow Dawn (Chronicles of the Shadow War, Book 2)'),
#  Row(Publisher='Bantam Books', Title='A Complete Guide to the Tarot'),
#  Row(Publisher='Bantam Books', Title='Six of One'),
#  Row(Publisher='Bantam Books', Title='Trinity'),
#  Row(Publisher='Bantam Books', Title='Canticle for Leibowitz'),
#  Row(Publisher='Bantam Books', Title='The Tin Man'),
#  Row(Publisher='Bantam Books', Title='The Tin Man'),
#  Row(Publisher='Bantam Books', Title='Final Target'),
#  Row(Publisher='Bantam Books', Title='Final Target'),
#  Row(Publisher='Bantam Books', Title='Final Target'),
#  Row(Publisher='Bantam Books', Title='Final Target'),
#  Row(Publisher='Bantam Books', Title='Final Target'),
#  Row(Publisher='Bantam Books', Title='Final Target'),
#  Row(Publisher='Bantam Books', Title='Carnal Innocence'),
#  Row(Publisher='Bantam Books', Title='Carnal Innocence'),
#  Row(Publisher='Bantam Books', Title='Carnal Innocence'),
#  Row(Publisher='Bantam Books', Title='Carnal Innocence'),
#  Row(Publisher='Bantam Books', Title='Carnal Innocence'),
#  Row(Publisher='Bantam Books', Title='Carnal Innocence'),
#  Row(Publisher='Bantam Books', Title='Carnal Innocence'),
#  Row(Publisher='Bantam Books', Title='Even Cowgirls Get the Blues'),
#  Row(Publisher='Bantam Books', Title='Ishmael'),
#  Row(Publisher='Bantam Books', Title='Ishmael'),
#  Row(Publisher='Bantam Books', Title='Ishmael'),
#  Row(Publisher='Bantam Books', Title='Ishmael'),
#  Row(Publisher='Bantam Books', Title='Zen in the Art of Writing'),
#  Row(Publisher='Bantam Books', Title='Zen in the Art of Writing'),
#  Row(Publisher='Bantam Books', Title='Exodus'),
#  Row(Publisher='Bantam Books', Title='Exodus'),
#  Row(Publisher='Bantam Books', Title='Exodus'),
#  Row(Publisher='Bantam Books', Title='Exodus'),
#  Row(Publisher='Bantam Books', Title='Against Our Will'),
#  Row(Publisher='Bantam Books', Title='The Accidental Bride'),
#  Row(Publisher='Bantam Books', Title='The Accidental Bride'),
#  Row(Publisher='Bantam Books', Title='Nathaniel'),
#  Row(Publisher='Bantam Books', Title='Nathaniel'),
#  Row(Publisher='Bantam Books', Title='Nathaniel'),
#  Row(Publisher='Bantam Books', Title='Sold Down the River (Benjamin January (Paperback))'),
#  Row(Publisher='Bantam Books', Title='The Postman'),
#  Row(Publisher='Bantam Books', Title='Dark Force Rising (Star Wars, Vol 2)'),
#  Row(Publisher='Bantam Books', Title='Self-Defense (Alex Delaware Novels (Paperback))'),
#  Row(Publisher='Bantam Books', Title='Self-Defense (Alex Delaware Novels (Paperback))'),
#  Row(Publisher='Bantam Books', Title='Encyclopedia Brown Saves the Day (Encyclopedia Brown (Paperback))'),
#  Row(Publisher='Bantam Books', Title='Toxic Parents: Overcoming Their Hurtful Legacy and Reclaiming Your Life'),
#  Row(Publisher='Bantam Books', Title='Pride and Prejudice'),
#  Row(Publisher='Bantam Books', Title='Pride and Prejudice'),
#  Row(Publisher='Bantam Books', Title='Night'),
#  Row(Publisher='Bantam Books', Title='Night'),
#  Row(Publisher='Bantam Books', Title='The Matarese Countdown'),
#  Row(Publisher='Bantam Books', Title='The Matarese Countdown'),
#  Row(Publisher='Bantam Books', Title='The Widows Club'),
#  Row(Publisher='Bantam Books', Title='Narcissus and Goldmund'),
#  Row(Publisher='Bantam Books', Title='Narcissus and Goldmund'),
#  Row(Publisher='Bantam Books', Title='Narcissus and Goldmund'),
#  Row(Publisher='Bantam Books', Title='A Most Contagious Game'),
#  Row(Publisher='Bantam Books', Title='Rightfully Mine'),
#  Row(Publisher='Bantam Books', Title='Rightfully Mine'),
#  Row(Publisher='Bantam Books', Title='Still Life with Woodpecker'),
#  Row(Publisher='Bantam Books', Title='Red Pony'),
#  Row(Publisher='Bantam Books', Title='Firefly Beach'),
#  Row(Publisher='Bantam Books', Title='Blood Test (Alex Delaware Novels (Paperback))'),
#  Row(Publisher='Bantam Books', Title='Silent Partner (Alex Delaware Novels (Paperback))'),
#  Row(Publisher='Bantam Books', Title='Silent Partner (Alex Delaware Novels (Paperback))'),
#  Row(Publisher='Bantam Books', Title='Time Bomb (Alex Delaware Novels (Paperback))'),
#  Row(Publisher='Bantam Books', Title='Time Bomb (Alex Delaware Novels (Paperback))'),
#  Row(Publisher='Bantam Books', Title='Time Bomb (Alex Delaware Novels (Paperback))'),
#  Row(Publisher='Bantam Books', Title='Time Bomb (Alex Delaware Novels (Paperback))'),
#  Row(Publisher='Bantam Books', Title='Flowers for Algernon'),
#  Row(Publisher='Bantam Books', Title='The Further Adventures of the Joker'),
#  Row(Publisher='Bantam Books', Title='A Girl from Yamhill: A Memoir'),
#  Row(Publisher='Bantam Books', Title='The Psychology of Self-Esteem'),
#  Row(Publisher='Bantam Books', Title='Brothers Karamazov'),
#  Row(Publisher='Bantam Books', Title='Spiritwalker: Messages from the Future'),
#  Row(Publisher='Bantam Books', Title='The Choice'),
#  Row(Publisher='Bantam Books', Title='Miracle Cure'),
#  Row(Publisher='Bantam Books', Title='In the Beginning : The Story of the King James Bible and How it Changed a Nation, a Language, and a Culture'),
#  Row(Publisher='Bantam Books', Title='The Guinness Book of Records 1996 (Guinness Book of Records, 1996)'),
#  Row(Publisher='Bantam Books', Title='Love Pirate (Volume 70)'),
#  Row(Publisher='Bantam Books', Title="Adventures in Color and Shapes (Disney's Fun to Learn Ser)"),
#  Row(Publisher='Bantam Books', Title='Whose Little Girl Are You?'),
#  Row(Publisher='Bantam Books', Title="The Emperor's General: A Novel"),
#  Row(Publisher='Bantam Books', Title='A Whale for the Killing'),
#  Row(Publisher='Bantam Books', Title="Paramedic: The True Story of a New York Paramedic's Battles With Life and Death"),
#  Row(Publisher='Bantam Books', Title='Final Target'),
#  Row(Publisher='Bantam Books', Title='Final Target'),
#  Row(Publisher='Bantam Books', Title='Final Target'),
#  Row(Publisher='Bantam Books', Title='Final Target'),
#  Row(Publisher='Bantam Books', Title='Trevayne'),
#  Row(Publisher='Bantam Books', Title="Don't Shoot the Dog: The New Art of Teaching and Training"),
#  Row(Publisher='Bantam Books', Title='Dead Aim'),
#  Row(Publisher='Bantam Books', Title='Dead Aim'),
#  Row(Publisher='Bantam Books', Title='The right stuff'),
#  Row(Publisher='Bantam Books', Title='Chopping Spree'),
#  Row(Publisher='Bantam Books', Title='Chopping Spree'),
#  Row(Publisher='Bantam Books', Title='Chopping Spree'),
#  Row(Publisher='Bantam Books', Title='Chopping Spree'),
#  Row(Publisher='Bantam Books', Title='A Great Deliverance'),
#  Row(Publisher='Bantam Books', Title='A Great Deliverance'),
#  Row(Publisher='Bantam Books', Title='The Killing Game: Only One Can Win...and the Loser Dies'),
#  Row(Publisher='Bantam Books', Title='The Killing Game: Only One Can Win...and the Loser Dies'),
#  Row(Publisher='Bantam Books', Title='The Killing Game: Only One Can Win...and the Loser Dies'),
#  Row(Publisher='Bantam Books', Title='The Killing Game: Only One Can Win...and the Loser Dies'),
#  Row(Publisher='Bantam Books', Title='The Killing Game: Only One Can Win...and the Loser Dies'),
#  Row(Publisher='Bantam Books', Title='The Killing Game: Only One Can Win...and the Loser Dies'),
#  Row(Publisher='Bantam Books', Title='The Killing Game: Only One Can Win...and the Loser Dies'),
#  Row(Publisher='Bantam Books', Title='The Killing Game: Only One Can Win...and the Loser Dies'),
#  Row(Publisher='Bantam Books', Title='Critical Judgment'),
#  Row(Publisher='Bantam Books', Title='Critical Judgment'),
#  Row(Publisher='Bantam Books', Title='The Odessa File'),
#  Row(Publisher='Bantam Books', Title='Positive Match'),
#  Row(Publisher='Bantam Books', Title='The Elk-Dog Heritage (Spanish Bit Saga : Book 2)'),
#  Row(Publisher='Bantam Books', Title='The Elk-Dog Heritage (Spanish Bit Saga : Book 2)'),
#  Row(Publisher='Bantam Books', Title='Men in Black: A Novel'),
#  Row(Publisher='Bantam Books', Title='Johnny Got His Gun'),
#  Row(Publisher='Bantam Books', Title='Johnny Got His Gun'),
#  Row(Publisher='Bantam Books', Title='Johnny Got His Gun'),
#  Row(Publisher='Bantam Books', Title='Johnny Got His Gun'),
#  Row(Publisher='Bantam Books', Title='Johnny Got His Gun'),
#  Row(Publisher='Bantam Books', Title='Johnny Got His Gun'),
#  Row(Publisher='Bantam Books', Title='Johnny Got His Gun'),
#  Row(Publisher='Bantam Books', Title='Johnny Got His Gun'),
#  Row(Publisher='Bantam Books', Title='Johnny Got His Gun'),
#  Row(Publisher='Bantam Books', Title='Johnny Got His Gun'),
#  Row(Publisher='Bantam Books', Title='Johnny Got His Gun'),
#  Row(Publisher='Bantam Books', Title='Johnny Got His Gun'),
#  Row(Publisher='Bantam Books', Title='Johnny Got His Gun'),
#  Row(Publisher='Bantam Books', Title="Under the Beetle's Cellar"),
#  ...]

# %%
data = books.join(ratings, 'ISBN', 'left')
overRating = Window.partitionBy(data.Publisher).orderBy(F.desc("num_ratings"))
# data.groupBy("Publisher", "Title").agg(F.count(data.Rating).alias("num_ratings")).select("Publisher", "Title", "num_ratings").collect()
data.groupBy("Publisher", "Title").agg(F.count(data.Rating).alias("num_ratings")).withColumn("rank", F.dense_rank().over(overRating)).where("rank <= 1").select("Publisher", "Title").collect()
# Out:
# [Row(Publisher='"""Otokar Kersovani\\"""', Title='"Gdje pijevac ne pjeva (Biblioteka ""Zlatni paun\\"")"'),
#  Row(Publisher='"Flemish-Netherlands Foundation ""Stichting Ons Erfdeel,\\"""', Title='Contemporary poetry of the low countries'),
#  Row(Publisher='(3 Queen Sq., WC1N 3AU), Faber and Faber Ltd', Title='The big chapel'),
#  Row(Publisher='101 Productions; [distributed by Scribner, New York]', Title='Manna: foods of the frontier'),
#  Row(Publisher='22nd. Century, New York', Title='Portraits of Cities'),
#  Row(Publisher='3', Title="Restoring Intimacy: The Patient's Guide to Maintaining Relationships During Depression"),
#  Row(Publisher='300Incredible.com', Title='300 Incredible Things for Sports Fans on the Internet'),
#  Row(Publisher='3D Press', Title='Denver Hiking Guide:  45 Hikes within 45 Minutes of Denver'),
#  Row(Publisher='3H Productions, Inc.', Title="Haley's Cleaning Hints"),
#  Row(Publisher='3rd Bed', Title='Stories in the Worst Way'),
#  Row(Publisher='3rd Woman Press', Title='Dictee'),
#  Row(Publisher='A & W Pub', Title='Clever Puzzles for Clever People'),
#  Row(Publisher='A & W Pub', Title='Book of Numbers'),
#  Row(Publisher='A & W Visual Library', Title='Save an alligator, shoot a preppie: A terrorist guide'),
#  Row(Publisher='A Golden Book', Title="What's In Oscar's Trash Can? (Sesame Street Good-Night Stories)"),
#  Row(Publisher='A H M Publications', Title='The Subjection of Women (Crofts Classics)'),
#  Row(Publisher='A New Hope Pub', Title='Pent Up Passion'),
#  Row(Publisher='A Plume Book', Title='The Prodigal Project: Genesis (Book 1)'),
#  Row(Publisher='A V Pubns', Title="New Age Bible Versions: An Exhaustive Documentation of the Message, Men & Manuscripts Moving Mankind to the Antichrist's One World Religion"),
#  Row(Publisher='A&b Publishers Group', Title='Afrikan Holistic Health   : Complete Herb Remedy Guide, Disease Treatment, Nutrition, Diet, Wholistic Perspectives,African Herb History, Self Diagnosis'),
#  Row(Publisher='A. & C. Black', Title="Writing for television in the 70's"),
#  Row(Publisher='A. & M. Muchnik', Title='Comuna Verdad (Analectas)'),
#  Row(Publisher='A. Bernhardt Pub. Co', Title='Mohammed: Life and work of the forerunner in Arabia : received in the proximity of Abd-ru-shin through the special gift of one called for the purpose ([Forerunners])'),
#  Row(Publisher='A. Bonnier', Title='I skuggan av oron'),
#  Row(Publisher='A. Bonniers', Title='Oskuldens minut'),
#  Row(Publisher='A. Deutsch', Title='Moon Tiger'),
#  Row(Publisher='A. Michel', Title='Milarepa'),
#  Row(Publisher='A. Michel', Title='Le jour des fourmis: Roman'),
#  Row(Publisher='A. Salani', Title='Pancreas: Trapianto del libro Cuore'),
#  Row(Publisher='A.T.E', Title='El triÃ¡ngulo mortal de las Bermudas'),
#  Row(Publisher='AAAI Press', Title='Computers and Thought'),
#  Row(Publisher='ADV Manga', Title='PrÃ©tear Volume 1'),
#  Row(Publisher='AIMS International Books', Title='El Guardian Entre El Centeno'),
#  Row(Publisher='AIT-Planet Lar', Title='Sky Ape: Waiting For Crime'),
#  Row(Publisher='AK Press', Title='Scum Manifesto'),
#  Row(Publisher='AM', Title='La tahona de FroilÃ¡n'),
#  Row(Publisher='AMEX/Time Warn', Title='The Best of Food & Wine the Chicken Collection'),
#  Row(Publisher='AMG Publishers', Title='Learning English through the Bible'),
#  Row(Publisher='AVON', Title='Wedding Night'),
#  Row(Publisher='AVON Books', Title='Adventures of a Scottish Heiress'),
#  Row(Publisher='Abc-Clio Inc', Title='Circulation, Interlibrary Loan, Patron Use and Collection Maintenance: A Handbook for Library Management (Handbooks for library management)'),
#  Row(Publisher='Abc-Clio Inc', Title='Cannery Row (Mainstream Series)'),
#  Row(Publisher='Abc-Clio Inc', Title='Dictionary of Symbols'),
#  Row(Publisher='Able Inc', Title='Your Journey of Healing, A Workbook'),
#  Row(Publisher='Abradale Press', Title='An illustrated treasury of Bible stories,'),
#  Row(Publisher='Abradale/Abrams', Title='Dali (Great Modern Masters)'),
#  Row(Publisher='Abradale/Abrams', Title='Jackie Robinson: An Intimate Portrait'),
#  Row(Publisher='Abson Books', Title='Scottish-English, English-Scottish;'),
#  Row(Publisher='Abstract Studio, Incorporated', Title='The Collected Strangers In Paradise'),
#  Row(Publisher='Acada Books', Title='The Bank Teller and Other Essays on the Politics of Meaning'),
#  Row(Publisher='Academic Press', Title='Advances in Magnetic & Optical Resonance (Advances in Magnetic &amp; Optical Resonance)'),
#  Row(Publisher='Ace', Title='The Lost Years of Merlin'),
#  Row(Publisher='Ace', Title="Isaac Asimov's Inferno"),
#  Row(Publisher='Acento Editorial', Title='Cuentos a la intemperie (Club)'),
#  Row(Publisher='Acme Press', Title='Superfan'),
#  Row(Publisher='Acolyte Media', Title='Monsters from the Id (Brainstorm)'),
#  Row(Publisher='Acorn Books', Title='Forbidden Grief: The Unspoken Pain of Abortion'),
#  Row(Publisher='Acta Pubns', Title='A Contemporary Celtic Prayer Book'),
#  Row(Publisher='Actar', Title='HD: Holland Design--New Graphics'),
#  Row(Publisher='Active Synapse', Title='Clan Apis'),
#  Row(Publisher='Ad Vice Marketing Inc', Title='Media Tried Justice Denied, Behind the truth and Lies of the Darlie Lynn Routier Murder Case'),
#  Row(Publisher='Adam Smith Institute', Title='Economy and Local Government'),
#  Row(Publisher='Adam Smith Institute', Title='The Myths of Privatisation'),
#  Row(Publisher='Adamis International, Incorporated', Title='Exploring Atlantis, No I (Exploring Atlantis)'),
#  Row(Publisher='Adams & Ambrose Pub', Title='The Legal Research Manual: A Game Plan for Legal Research and Analysis'),
#  Row(Publisher='Adams Media Corp', Title='365 Tv-Free Activities You Can Do With Your Child'),
#  Row(Publisher='Adams Media+corporation', Title='Animal Miracles Inspirational and Heroic'),
#  Row(Publisher='Adams Media+corporation', Title='Knock Em Dead'),
#  Row(Publisher='Adams Pub Co', Title="Becoming: A Master's Manual (Becoming series)"),
#  Row(Publisher='Adams-Blake Publishing', Title='Tears and Rage: The Nursing Crisis in America'),
#  Row(Publisher='Addison Books', Title='Business and Information Systems'),
#  Row(Publisher='Addison-wesley', Title='Taking Care of Your Child'),
#  Row(Publisher='Adrenaline Audiobooks', Title='Survive: Stories of Castaways and Cannibals'),
#  Row(Publisher='Advaita Pr', Title='From Consciousness to Consciousness'),
#  Row(Publisher='Advance Pub Llc', Title="My First Word Book (Disney's Fun to Learn Ser)"),
#  Row(Publisher='Advanced Neuro Dynamics', Title='Secret of Creating Your Future'),
#  Row(Publisher='Advantage Books', Title='Help4Add High School'),
#  Row(Publisher='Adventure Imports', Title='Guatemalan Ikat Unlined Journal'),
#  Row(Publisher='Adventures Into Time', Title='Self Hypnosis, Creating Your Own Destiny'),
#  Row(Publisher='Advice Press', Title='Love Advice for Women'),
#  Row(Publisher='Aero Publishers', Title="Space shuttle: America's wings to the future"),
#  Row(Publisher='Aero Publishers', Title='U.S. bombers,'),
#  Row(Publisher='Ageless Pr', Title='Computer Tales of Fact and Fantasy: Or How We Learned to Stop Worrying and Love the Computer'),
#  Row(Publisher='Ageless Pr', Title='Computer Legends, Lies & Lore'),
#  Row(Publisher='Aglow', Title='Secrets: Unlocking the mystery of intimacy with God'),
#  Row(Publisher='Aglow Pubns', Title='When Love Is Not Perfect: Discovering Gods Reparenting Process'),
#  Row(Publisher='Agreka Tm Llc', Title='Jackals In Iron'),
#  Row(Publisher='Aguabonita Books', Title='Fly Fishing the Sierra Nevada'),
#  Row(Publisher='Aguilar', Title='LA Caverna De Las Ideas'),
#  Row(Publisher='Aguilar S.A. de Ediciones-Grupo Santillana', Title='El Crimen De Lord Arthur Savile (Relatos Cortos - Short Stories)'),
#  Row(Publisher='Ahrens Pub. Co', Title="The bakers' manual for quantity baking and pastry making"),
#  Row(Publisher='Air USA Inc', Title='Fundamentals of Aircraft Material Factors (2nd ed - JS312646)'),
#  Row(Publisher='Ajuntament de Lleida', Title='Nadal a Lleida (1940-1995) (Quaderns de divulgaciÃ³ ciutadana. ColÂ¨lecciÃ³ La banqueta)'),
#  Row(Publisher='Ajuntament de Lleida', Title='La premsa a Lleida (Quaderns de divulgaciÃ³ ciutadana)'),
#  Row(Publisher='Akadine Press', Title='The Inn at the Edge of the World (Common Reader Editions)'),
#  Row(Publisher='Alabaster', Title='The Prayer Tree'),
#  Row(Publisher='Alabaster', Title='Tangled Vines (Alabaster Books)'),
#  Row(Publisher='Aladdin Publishing Company', Title='Turnabout'),
#  Row(Publisher='Alaf 21', Title='Original'),
#  Row(Publisher='Alan Richards Co', Title='Stop! Are You Thinking of Moving From the City to the Country?'),
#  Row(Publisher='Alan Sutton Publ Ltd', Title='Ups and Downs of Umbrellas'),
#  Row(Publisher='Alaska Pacific Univ Pr', Title='Minus Thirty-One and the Wind Blowing: Nine Reflections About Living on Land (Alaskana book)'),
#  Row(Publisher='Alba', Title='Muerte de Kurt Cobain, La (Alba Joven)'),
#  Row(Publisher='Alba', Title='Mercader de Venecia, El'),
#  Row(Publisher='Albin Michel', Title='Oscar et la dame rose'),
#  Row(Publisher='Albury Publishing', Title="Shout to the Lord: Stories of God's Love and Power"),
#  Row(Publisher='Alchemical Press', Title='The Triumphal Chariot of Antimony: With the Commentary of Theodore Kerchringius, Doctor of Medicine'),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='La Carta Esferica / The Nautical Chart (Spanish edition)'),
#  Row(Publisher='Alfaguara Infantil', Title='LA Tabla De Flandes (Alfaguara Extra)'),
#  Row(Publisher='Alfranpedoc Publishing', Title='A Family Tree, Taking Root'),
#  Row(Publisher='Alfred A. Knopf', Title='Timeline'),
#  Row(Publisher='Alfred E Knopf', Title='The History of Luminous Motion'),
#  Row(Publisher='Algaida', Title='Las Llamas Tiemblan'),
#  Row(Publisher='Algonquin Books Of Chapel Hill', Title='Virtuous Woman'),
#  Row(Publisher='Algonquin Books Of Chapel Hill', Title='Ellen Foster'),
#  Row(Publisher='Alianza', Title='Artificios'),
#  Row(Publisher='Aliform Pub', Title='My World Is Not of This Kingdom'),
#  Row(Publisher='Alistair Press (IN)', Title="'Great Speeches for Criticism and Analysis'"),
#  Row(Publisher='Allan', Title='Warships of World War II'),
#  Row(Publisher='Allcat Pr', Title='A Trellis for Mr. Ellis Or, How I Saved the World from Global Warming'),
#  Row(Publisher='Allen', Title="The widower's son"),
#  Row(Publisher='Allen & Unwin Pty Ltd', Title='The sunken road'),
#  Row(Publisher='Allen & Unwin Pty., Limited (Australia)', Title='Kindling Does for Firewood'),
#  Row(Publisher='Allen & Unwin Pty., Limited (Australia)', Title='Buddhism for Mothers: A Calm Approach to Caring for Yourself and Your Children'),
#  Row(Publisher='Allen & Unwin Pty., Limited (Australia)', Title="It's My Party and I'll Knit If I Want To!"),
#  Row(Publisher='Allen & Unwin Pty., Limited (Australia)', Title='Antonio S and the Mystery of Theodore Guzman (Little Ark Book)'),
#  Row(Publisher="Allen & Unwin children's books", Title='The Baboon King (Ark Fiction)'),
#  Row(Publisher="Allen & Unwin children's books", Title='The Quicksand Pony (A Little Ark Book)'),
#  Row(Publisher='Allia', Title='"Une apologie des oisifs, suivi de ""causerie et causeurs\\"""'),
#  Row(Publisher='Allia', Title='Le droit Ã?Â\xa0 la paresse'),
#  Row(Publisher='Allia', Title='De la bÃ?Âªtise'),
#  Row(Publisher='Allia', Title='JÃ?Â©sus-Christ rastaquouÃ?Â¨re'),
#  Row(Publisher='Allia', Title='Le Paresseux'),
#  Row(Publisher='Allia', Title='Lipstick traces'),
#  Row(Publisher='Allia', Title='Livre et typographie'),
#  Row(Publisher='Alliance for Committed Civic Engagement & Social Solutions (ACCESS)', Title='Savoring Seattle'),
#  Row(Publisher='Allied Mouse', Title='The Heartstone Odyssey'),
#  Row(Publisher='Allyn &amp; Bacon', Title='Book Publishing Industry, The: (Part of the Allyn & Bacon Series in Mass Communication)'),
#  Row(Publisher='Allyn &amp; Bacon', Title='Statistics Without Tears: A Primer for Non-Mathematicians (Allyn & Bacon Classics Edition)'),
#  Row(Publisher='Almarabu', Title='Por boca de los dioses (Textos tÃ\xadmidos)'),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Knitting & Crocheting"),
#  Row(Publisher='Alpine Publications, Inc.', Title='A Guide to Backpacking With Your Dog'),
#  Row(Publisher='Alpine Publications, Inc.', Title='How to Raise a Puppy You Can Live With'),
#  Row(Publisher='Alpine Publications, Inc.', Title='Scent: Training to Track, Search and Rescue'),
#  Row(Publisher='Alpine Publications, Inc.', Title='Understanding Showmanship: Everything You Need to Know to Win in Showmanship Classes'),
#  Row(Publisher='Alpine Publications, Inc.', Title='Sheltie Talk'),
#  Row(Publisher='Altitude Publishing Ltd', Title='Vancouver Panorama'),
#  Row(Publisher='Alvarellos', Title='Os mil e un refrÃ¡ns galegos da muller'),
#  Row(Publisher='Alyson Pubns', Title="That's Mr. Faggot to You : Further Trials from My Queer Life"),
#  Row(Publisher='Amadeus', Title="The Invaluable Guide to Life After Stroke: An Owner's Manual"),
#  Row(Publisher='Amazon Press', Title='Off on a Comet'),
#  Row(Publisher='Amazon Press', Title='The Oval Portrait'),
#  Row(Publisher='Amer Education Pub', Title='Comprehensive Curriculum Plus Test Practice'),
#  Row(Publisher='Amer Education Pub', Title='Pooh Helps Out'),
#  Row(Publisher='Amer Federation of Astrologers', Title='How to Give an Astrological Health Reading'),
#  Row(Publisher='Amer Federation of Astrologers', Title='Your Hidden Powers: Intercepted Signs and Retrograde Planets'),
#  Row(Publisher='Amer Inst of Chemical Engineers', Title='Safety Health and Loss Prevention in Chemical Processes: Problems for Undergraduate Engineering Curricula Student Problems'),
#  Row(Publisher='Amer Inst of Chemical Engineers', Title='Project Management for the Process Industry'),
#  Row(Publisher='Amer Philosophical Society', Title="One Grand Pursuit: A Brief History of the American Philosophical Society's First 250 Years, 1743-1993"),
#  Row(Publisher='Amer Psychological Assn', Title='Publication Manual of the American Psychological Association (Publication Manual of the American Psychological Association, 4th ed)'),
#  Row(Publisher='Amer Red Cross', Title='Advanced First Aid and Emergency Care'),
#  Row(Publisher='Amer Society for Microbiology', Title='Manual of Clinical Microbiology/Pa1-030-6'),
#  Row(Publisher="America's Test Kitchen", Title='Baking Illustrated: A Best Recipe Classic (The Best Recipe Series)'),
#  Row(Publisher='American Alpine Club', Title='American Alpine Journal 2002 (American Alpine Journal, 2002)'),
#  Row(Publisher='American Alpine Club', Title='High Alaska: A Historical Guide to Denali Mount Foraker and Mount Hunter'),
#  Row(Publisher='American Alpine Club', Title='Accidents in North American Mountaineering 2001: Issue 54 (Accidents in North American Mountaineering, 2001)'),
#  Row(Publisher='American Business Visions', Title='Effort-Less Marketing for Financial Advisors'),
#  Row(Publisher='American Diabetes Association', Title='Reflections on Diabetes (Diabetes Forecast Book)'),
#  Row(Publisher='American Health Press', Title='Harley, The Shaggy Professor'),
#  Row(Publisher='American Library Association', Title='The Whole Library Handbook 3: Current Data, Professional Advice, and Curiosa About Libraries and Library Sciences (Whole Library Handbook)'),
#  Row(Publisher='American Library Association', Title='The Coretta Scott King Awards Book, 1970-1999 (Coretta Scott King Awards Book)'),
#  Row(Publisher='American Library Association', Title='New Steps to Service: Common-Sense Advice for the School Library Media Specialist'),
#  Row(Publisher='American Library Association', Title="Bare Bones Children's Services: Tips for Public Library Generalists"),
#  Row(Publisher='American Library Association', Title='Information Power: Building Partnerships for Learning'),
#  Row(Publisher='American Library Association', Title='Anglo-American Cataloguing Rules'),
#  Row(Publisher='American Philological Association', Title='Managing Your Mind: The Mental Fitness Guide'),
#  Row(Publisher='American Photographic Book Pub. Co', Title='Amphoto guide to SLR photography (Amphoto guide series)'),
#  Row(Publisher='American Planning Association', Title='City Zoning: The Once and Future Frontier'),
#  Row(Publisher='American Psychiatric Association', Title='Diagnostic and Statistical Manual of Mental Disorders DSM-IV-TR (Text Revision)'),
#  Row(Publisher='American Publishing Corp.', Title='Proven Health Tips Encyclopedia'),
#  Row(Publisher='American Self-Help Group Clearinghouse', Title='The Self-Help Group Sourcebook: Your Guide to Community & Online Support Groups'),
#  Row(Publisher='American Trust Publications', Title="The Child in Islam: A Muslim Parent's Handbook"),
#  Row(Publisher='American Value Tales', Title='Hannah GoBrightly (Earth angels)'),
#  Row(Publisher='Americas Natl Parks', Title='Interpreting for Park Visitors'),
#  Row(Publisher='Amethyst Books', Title='AIDS and the Healer Within'),
#  Row(Publisher='Ammann', Title='Monsieur Ibrahim und die Blumen des Koran. ErzÃ?Â¤hlung.'),
#  Row(Publisher='Amok Books', Title='Amok Journal Sensurround Edition'),
#  Row(Publisher='Amok Books', Title='Severed: The True Story of the Black Dahlia Murder'),
#  Row(Publisher='An RGA Production', Title="Sometimes it's O.K. to be Angry! (A Parent/Child Manual for the Education of Children)"),
#  Row(Publisher='Anabasi', Title='La fuga del cavallo morto (Ariele)'),
#  Row(Publisher='Anagrama, Editorial S.A.', Title='Tocarnos La Cara'),
#  Row(Publisher='Anagrama, Editorial S.A.', Title='Gressiones, Eyaculaciones, Exhibiciones'),
#  Row(Publisher='Anchor Bible Commentary', Title='Judges (Anchor Bible)'),
#  Row(Publisher='Anchor Books', Title='Almost Heaven'),
#  Row(Publisher='Anchor Books', Title='Freud: A collection of critical essays (Modern studies in philosophy)'),
#  Row(Publisher='Anchor Distributors', Title='Confession Brings Possession'),
#  Row(Publisher='Anchor Press', Title='The double E'),
#  Row(Publisher='Anchor Press', Title='The astrology of change: Horary astrology and its humanistic applications'),
#  Row(Publisher='Anchor Press', Title='Darkness and scattered light: Four talks on the future'),
#  Row(Publisher='Anchor Press', Title='African odyssey: An anthropological adventure'),
#  Row(Publisher='Anchor Press', Title='Prisoners of liberation;: Four years in a Chinese Communist prison'),
#  Row(Publisher='Anchor Press', Title="The well-played game: A player's philosophy"),
#  Row(Publisher='Anchor Press', Title='Know your type: Maps of identity'),
#  Row(Publisher='Anchor Press', Title='Human beings: The psychology of human experience'),
#  Row(Publisher='Anchor Press', Title='The malnourished mind'),
#  Row(Publisher='Anchor Press', Title='Jails, the ultimate ghetto'),
#  Row(Publisher='Anchor Press', Title='Burnout: The High Cost of High Achievement'),
#  Row(Publisher='Anderson World', Title="Women's Running"),
#  Row(Publisher='Anderson World', Title="Runner's World natural foods cookbook (Instructional book / Runner's World)"),
#  Row(Publisher='AndrÃ© Deutsch', Title="Pa's top hat"),
#  Row(Publisher='Angel Books', Title="Deutschland: A Winter's Tale : Bilingual Edition"),
#  Row(Publisher='Angela Royal Publishing', Title='Food for Love'),
#  Row(Publisher='Anglican Book Centre', Title='Moratorium: Justice, energy, the north, and the native people'),
#  Row(Publisher='Angsana Books', Title='Got Singapore'),
#  Row(Publisher='Ann Arbor Media Group', Title='The Road to Oz'),
#  Row(Publisher='Annick Pr', Title='Bonnie McSmithers is at It Again! (Annikins #09)'),
#  Row(Publisher='Annick Press', Title='Paper Bag Princess (Munsch for Kids)'),
#  Row(Publisher="Antique Collectors' Club", Title='Opera Houses of Europe'),
#  Row(Publisher='Anything Books', Title='Anything Book : Unicorn Silver On Blue'),
#  Row(Publisher='Apollo Editions', Title='Life in a medieval city'),
#  Row(Publisher='Apple Press, Incorporated', Title='Art of Aubrey Beardsley'),
#  Row(Publisher='Apple Signature (Scholastic)', Title='The First Journey (Animorphs. Alternamorphs, 1)'),
#  Row(Publisher='Apricot Press', Title="Geezerhood: What to expect from life now that you're as old as dirt"),
#  Row(Publisher='Apricot Press', Title='How to Make People Think You Are Normal'),
#  Row(Publisher='Aqua Explorers', Title='Florida Shipwrecks: The Divers Guide to Shipwrecks Around the State of Florida and the Florida Keys'),
#  Row(Publisher='Aramith', Title='Turbo-taal: Van socio-babble tot yuppie-speak'),
#  Row(Publisher='Arbeiderspers', Title='Zuiderkruis: Roman'),
#  Row(Publisher='Arcade Books', Title="Balthasar's Odyssey: A Novel"),
#  Row(Publisher='Arcade Books', Title='Judge Savage: A Novel'),
#  Row(Publisher='Arcade Books', Title='A Masterpiece of Revenge'),
#  Row(Publisher='Arcade Pub', Title='Dictionary of word origins'),
#  Row(Publisher='Arch Books', Title="Mary's Christmas Story: Luke 1:26-56, Luke 2:1-20 for Children (Learning Bible Stories Is Fun With Arch Books)"),
#  Row(Publisher='Arch Books', Title='The Week That Led to Easter: The Story of Holy Week Matthew 21:1-28:10, Mark 11:1-16:8, Luke 12:29-24:12, and John 12:12-20:10 for Children (Arch Books)'),
#  Row(Publisher='Arch Books', Title='Baby Born in a Stable (Arch Books (English))'),
#  Row(Publisher='Archiv der Deutschen Jugendbewegung', Title='Aufbruch und Erinnerung: Der Freideutsche Kreis als Generationseinheit im 20. Jahrhundert (Edition Archiv der Deutschen Jugendbewegung)'),
#  Row(Publisher='Archive Press', Title='Earth Abides'),
#  Row(Publisher='Arden Publishers', Title='The Tempest (Arden Shakespeare, Third Series Editions)'),
#  Row(Publisher='Ardis Publishers', Title='Collected Narrative and Lyrical Poetry'),
#  Row(Publisher='Arena Verlag GmbH', Title='Der Schonste Hund Der Welt = The Best Dog in the World'),
#  Row(Publisher='Argyll Publishing', Title='Far from the Rowan Tree'),
#  Row(Publisher='Ariel Publications', Title='Atila'),
#  Row(Publisher='Ariel Publications', Title='John F. Kennedy Jr.: A Life in the Spotlight'),
#  Row(Publisher='ArkHaven Publications', Title='Dawning : The Next Great Move of God'),
#  Row(Publisher='ArlÃ?Â©a', Title='La Mouette juive'),
#  Row(Publisher='Arner Pub.', Title="Mush: A Beginner's Manual of Sled Dog Training"),
#  Row(Publisher='Arno Press; distributed by Crown Publishers', Title='The dictionary of needlework;: An encyclopaedia of artistic, plain, and fancy needlework'),
#  Row(Publisher='Arrow Designs', Title='The Mummy Garden'),
#  Row(Publisher='ArsDigita Press', Title='Travels with Samantha'),
#  Row(Publisher='Arsenale', Title='Churches of Venice (I Piccoli Di Arsenale)'),
#  Row(Publisher='Art-Works!', Title='Art-Works! Hands on Projects for Children'),
#  Row(Publisher='Arte Publico Press', Title='Playing With Light: A Novel'),
#  Row(Publisher='Arthur A. Levine', Title='The Year of Secret Assignments'),
#  Row(Publisher='Arthur A. Levine Books', Title="Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))"),
#  Row(Publisher='Arx Publishing', Title='Dream of Fire'),
#  Row(Publisher='ArÃ¨nes', Title='Les sentinelles du soir'),
#  Row(Publisher='Ashford Press', Title='All gourmets great and small'),
#  Row(Publisher='Asia Books', Title='The big mango'),
#  Row(Publisher="Asian American Writers' Workshop", Title="Flippin': Filipinos on America"),
#  Row(Publisher='Asn Pub', Title='365 Quick Cross Stitch Christmas Designs'),
#  Row(Publisher='Asn Pub', Title='365 Designs: Cross Stitch All Through the Year'),
#  Row(Publisher='Asn Pub', Title='The Crochet Yearbook Volume 1 (1303)'),
#  Row(Publisher='Asn Pub', Title='Learn to Do Hand Quilting in Just 1 Day'),
#  Row(Publisher='Asn Pub', Title="Quilting for People Who Still Don't Have Time to Quilt (#4183)"),
#  Row(Publisher='Aspen Law & Business Publishers', Title='Kohn on Music Licensing (2nd Editon)'),
#  Row(Publisher='Aspen Light Publishing', Title='The Why Are You Here CafÃ©'),
#  Row(Publisher='Aspen Systems Corp', Title='Abnormal postural reflex activity caused by brain lesions'),
#  Row(Publisher='Aspen West Publishing', Title="Where's Mom Now That I Need Her?: Surviving Away from Home"),
#  Row(Publisher='Assn for Childhood Education Intl', Title='Opening, Mixing, Matching'),
#  Row(Publisher='Associated Press', Title='Torch Is Passed'),
#  Row(Publisher='Associated Publishers Group', Title='The Dilemma: A Memoir'),
#  Row(Publisher='Association for Supervision & Curriculum Deve', Title="The Hero's Journey: How Educators Can Transform Schools and Improve Learning"),
#  Row(Publisher='Association for Supervision & Curriculum Deve', Title='Visual Literacy: Learn to See, See to Learn'),
#  Row(Publisher='Association for Supervision & Curriculum Deve', Title="A Celebration of Neurons: An Educator's Guide to the Human Brain"),
#  Row(Publisher='Assouline', Title='Red'),
#  Row(Publisher='Assouline', Title='The Allure Of Men'),
#  Row(Publisher='Assouline', Title='Portraits'),
#  Row(Publisher='Assouline', Title='Hitchcock Style'),
#  Row(Publisher='Athena V Lord', Title='Pilot for Spaceship Earth: R. Buckminster Fuller, Architect, Inventor, and Poet'),
#  Row(Publisher='Athenaeum/Polak & Van Gennep', Title='Gebroken lied: Een vriendschap met Ida Gerhardt'),
#  Row(Publisher='Atheneum', Title='Treasure Island (Scribner Classics)'),
#  Row(Publisher='Atheneum Books', Title='The Adventures of Arthur and Edmund: A Tale of Two Seals'),
#  Row(Publisher='Atheneum Publishers', Title='Chad and the elephant engine'),
#  Row(Publisher='Atheneum/Richard Jackson Books', Title='The True Meaning of Cleavage (Junior Library Guild Selection)'),
#  Row(Publisher='Atlantic Bridge Publishing', Title='The Summerland'),
#  Row(Publisher='Atlantic Bridge Publishing', Title='Impatient Passion'),
#  Row(Publisher='Atlantic Transport Publishers', Title='Railways in the British Isles: Landscape, Land Use and Society'),
#  Row(Publisher='Atlantik-Brucke', Title='These Strange German Ways'),
#  Row(Publisher='Atomium Books', Title='Women: Around the World and Through the Ages'),
#  Row(Publisher='Attic Press', Title='Ride on Rapunzel (Fairytales for Feminists)'),
#  Row(Publisher='Attic Press', Title="Rapunzel's Revenge: More Feminist Fairytales (Fairytales for Feminists)"),
#  Row(Publisher='Attic Press', Title='Positive Parenting: A Survival Guide'),
#  Row(Publisher='Au Diable Vauvert', Title='American gods'),
#  Row(Publisher='Au diable Vauvert', Title='Rihla'),
#  Row(Publisher='Aubier', Title="FranÃ§oise Dolto, itinÃ©raire d'une psychanalyste: Essai"),
#  Row(Publisher='Aubier Montaigne', Title="Dialogues avec l'ange, Ã?Â©dition intÃ?Â©grale"),
#  Row(Publisher='Aubier Montaigne', Title='Les tests dÃ©mystifiÃ©s: Manuel pratique pour comprendre, analyser, utiliser les tests'),
#  Row(Publisher='Audio Partners', Title='The Reduced Shakespeare Company Radio Show'),
#  Row(Publisher='Audio Renaissance', Title='Singing in the Comeback Choir'),
#  Row(Publisher='Audio Renaissance', Title="Robert Ludlum's The Hades Factor : A Covert-One Novel (A Covert-One Novel)"),
#  Row(Publisher='Audio Renaissance', Title='Mom, Inc: Taking Your Work Skills Home'),
#  Row(Publisher='Audioworks', Title='Blood And Smoke'),
#  Row(Publisher='Auer', Title='Lernen aus WidersprÃ?Â¼chen. Dilemmageschichten im Religionsunterricht. (Lernmaterialien)'),
#  Row(Publisher='Aufbau', Title='Dass Ich Nicht Ersticke Am Leisesein: Gesammelte Texte'),
#  Row(Publisher='Aufbau Taschenbuch Verlag', Title='Die verleugnete Utopie: Zeitkritische Texte (AtV Dokument und Essay)'),
#  Row(Publisher='Aufbau-Verlag', Title='Der Untertan: Roman'),
#  Row(Publisher='Aulis Verlag Deubner', Title='SilvestergesprÃ?Â¤che eines Sechsecks.'),
#  Row(Publisher='Aussaat', Title='Alternativer Lebensstil: Christsein mit politischem Horizont (Aktuelle Themen)'),
#  Row(Publisher='Austin & Nelson', Title='Big Book of Everything: Preschool'),
#  Row(Publisher='Austin Junior Forum', Title='Lone Star Legacy: A Texas Cookbook'),
#  Row(Publisher='Authorhouse', Title='The Sea Shack'),
#  Row(Publisher='Authorlink', Title='The Only Living Witness: The True Story of Serial Sex Killer Ted Bundy'),
#  Row(Publisher='Avatar Press', Title='Strange Kiss'),
#  Row(Publisher='Avery Color Studios', Title='Mysteries and Histories: Shipwrecks of the Great Lakes'),
#  Row(Publisher='Avery Pub. Group', Title='The complete & up-to-date fat book: A guide to the fat, calories, and fat percentages in your food'),
#  Row(Publisher='Avian Books', Title='Handbook of Birds, Cages,& Aviaries'),
#  Row(Publisher='Avon Publishers', Title='The House in Munich'),
#  Row(Publisher='Avons Books', Title='The Marriage Lesson'),
#  Row(Publisher='Ayers &amp; James', Title='Wonderful Ways to Prepare Stews & Casseroles'),
#  Row(Publisher='B Store Pr', Title='Sex With a Mountain Bike and Other Stories'),
#  Row(Publisher='BD Lire /du Lys', Title='StratÃ?Â©gies de nÃ?Â©gociation'),
#  Row(Publisher='BFI Publishing', Title='Luchino Visconti'),
#  Row(Publisher='BRAVA', Title='Too Much Temptation'),
#  Row(Publisher='Bad Dog Pr', Title='How to Get Rid of a Telemarketer'),
#  Row(Publisher='Bad Intentions Press', Title='Murdering America, Inc.'),
#  Row(Publisher='Badlands Natural History Assn', Title='Where Buffalo Roam'),
#  Row(Publisher='Baker & Taylor Video', Title='Favorite Lullaby Songs to Share (My First Sing-Along)'),
#  Row(Publisher='Baker Publishing', Title='One Hundred One Simple Things You Can Do to Stay on a Diet and Lose Weight'),
#  Row(Publisher='Baldini & Castoldi', Title="Va' dove ti porta il cuore (Romanzi e racconti)"),
#  Row(Publisher='Ballantine', Title='Crystal singer'),
#  Row(Publisher='Ballantine Books (Trd Pap)', Title='Widows'),
#  Row(Publisher='Ballentyne & Balfour', Title='The Trusted'),
#  Row(Publisher='Balmur Book Publishing', Title='What A Wonderful World'),
#  Row(Publisher='Banned Books', Title='Skiptrace'),
#  Row(Publisher='Banned Books', Title='Intricate Passions'),
#  Row(Publisher='Banned Books', Title='Candy Holidays & Other Short Fictions'),
#  Row(Publisher='Banned Books', Title='Who Wears the Tux the Great American Dyke Quiz'),
#  Row(Publisher='Banned Books', Title='Free Fall'),
#  Row(Publisher='Banned Books', Title='Death With Dignity'),
#  Row(Publisher='Banner of Truth', Title='Creature'),
#  Row(Publisher='Banner of Truth', Title="Heart's Landing"),
#  Row(Publisher='Banner of Truth', Title='Emerald Desire'),
#  Row(Publisher='Bantam Books', Title='The Alienist'),
#  Row(Publisher='Bantam Books-Audio', Title='Harry Potter and the Goblet of Fire (Book 4, Audio)'),
#  Row(Publisher='Bantam Books-Audio', Title='Harry Potter and the Goblet of Fire (Book 4 Audio CD)'),
#  Row(Publisher='Bantam Classic & Loveswept', Title='Count of Monte Cristo'),
#  Row(Publisher='Bantam Classic & Loveswept', Title='David Copperfield'),
#  Row(Publisher='Bantam Classic & Loveswept (Mm)', Title='Bill Baileys Daughter'),
#  Row(Publisher='Bantam Classic & Loveswept (Mm)', Title='Murder in Three Acts (Hc Collection Series)'),
#  Row(Publisher='Bantam Classic & Loveswept (Mm)', Title='A Very Reluctant Knight, Number Sixteen'),
#  Row(Publisher='Bantam Classic & Loveswept (Mm)', Title='Vortex'),
#  Row(Publisher='Bantam Doubleday Dell Pub (T)', Title='Apple of My Eye'),
#  Row(Publisher='Barbour Bargain Books', Title='As American As Apple Pie'),
#  Row(Publisher='Barbour Publishing &amp; Humble Creek', Title='Light for My Path Prayers & Promises'),
#  Row(Publisher='Bard', Title='Tale of a Sky-Blue Dress'),
#  Row(Publisher='Bare Bones Press', Title='Rough Cut'),
#  Row(Publisher='Barnes & Nobel', Title='Persuasion'),
#  Row(Publisher='Barnes &amp; Noble Books', Title='The Cat Who Went To Paris & A Cat Abroad: Two Volumes In One'),
#  Row(Publisher='Barnes Noble Books', Title='War and Peace'),
#  Row(Publisher='Barney Pub', Title='Where are my shoes?'),
#  Row(Publisher='Barney Publishing', Title='"Barney Says, ""Please and Thank You\\"""'),
#  Row(Publisher='Baronet Books', Title='Alice In Wonderland Great Illustrated CL (Alice in Wonderland)'),
#  Row(Publisher='Barricade Books', Title='Living the Martial Way : A Manual for the Way of Modern Warrior Should Think'),
#  Row(Publisher='Barrytown Limited', Title="How to Spin Gold: A Woman's Tale"),
#  Row(Publisher='Barrytown Limited', Title='Rekindling the Spirit in Work'),
#  Row(Publisher='Bartholomew', Title='United States of America, western'),
#  Row(Publisher='Bartholomew', Title='Edinburgh streetfinder colour street atlas'),
#  Row(Publisher='Bartlett Publishing', Title="You Can't Get Pizza Delivered to a Doghouse (Animal Series)"),
#  Row(Publisher='Basic Civitas Books', Title='Some of Us Did Not Die: Selected Essays of June Jordan'),
#  Row(Publisher='Baton Wicks', Title='At the Rising of the Moon'),
#  Row(Publisher='Batsford Brassey,  Inc.', Title="The Road to Victory: The Untold Story of World War Ii's Red Ball Express"),
#  Row(Publisher='Battiston Pub', Title='How Mother Nature Flowered the Fields of Earth and Mars'),
#  Row(Publisher='Baxter Press', Title='The Big Picture'),
#  Row(Publisher='Bay Books (CA)', Title='Manor House: Life in an Edwardian Country House'),
#  Row(Publisher='Bbc Pubns', Title='The Velvet Claw: A Natural History of the Carnivores'),
#  Row(Publisher='Bbc Pubns', Title='Pride and Prejudice (BBC Series)'),
#  Row(Publisher='Be-Mused Publications', Title='The Demon Plague'),
#  Row(Publisher='Bear Tribe Pub', Title='Sun Bear, the path of power: As told to Wabun and to Barry Weinstock'),
#  Row(Publisher='Bear Tribe Pub.', Title='Black Dawn Bright Day'),
#  Row(Publisher='Beascoa', Title='Pocahontas'),
#  Row(Publisher='Beascoa', Title='El Boton Oscar'),
#  Row(Publisher='Beaufort Books', Title='Riding the Dolphin'),
#  Row(Publisher='Beaufort Books Publishers', Title='Teddy bears: A celebration'),
#  Row(Publisher='Beaufort Books Publishers', Title='Shadow kills: A novel of mystery'),
#  Row(Publisher='Bedford Arts', Title='Fine Print on Type: The Best of Fine Print Magazine on Type and Typography'),
#  Row(Publisher='Bedford Books', Title='Scarlet Letter: A Case Study in Contemporary Criticism (Case Studies in Contemporary Criticism)'),
#  Row(Publisher='Bedford Books', Title='Hamlet: Complete, Authoritative Text With Biographical and Historical Contexts, Critical History, and Essays from Five Contemporary Critical Perspectives (Case Studies in Contemporary Criticism)'),
#  Row(Publisher='Bedford Books', Title='Oroonoko: Or, the Royal Slave (Bedford Cultural Editions)'),
#  Row(Publisher='Bedrick', Title='The Pendragon Chronicles: Heroic Fantasy from the Time of King Arthur'),
#  Row(Publisher='Bedrick', Title='Solved!: Famous Mystery Writers on Classic True-Crime Cases'),
#  Row(Publisher='Bedrick', Title='Pyramids: Tombs for Eternity'),
#  Row(Publisher='Bedrick', Title="Shakespeare's Stories: Tragedies"),
#  Row(Publisher='Beekman House', Title='The Scots Book of Lore and Folklore'),
#  Row(Publisher='Beekman House', Title='Favorite Brand Name Recipe Cookbook'),
#  Row(Publisher='Beeline Books', Title='The Publishing Center: How to Create a Successful Publishing Center in Your School, Church, or Other Community Group (Bee Line Books)'),
#  Row(Publisher='Behany House Publishers', Title='Roses for Mama'),
#  Row(Publisher='Behrman House Publishing', Title='As a Driven Leaf'),
#  Row(Publisher='Bell', Title='Dyes from natural sources'),
#  Row(Publisher='Bell Pub. Co.', Title='50 Great Ghost Stories'),
#  Row(Publisher='Bell Pub. Co.', Title='How to Interpret Your Own Dreams: An Encyclopedic Dictionary'),
#  Row(Publisher='Belle Grove Publishing Company', Title='Writing & Fighting the Civil War: Soldier Correspondence to the New York Sunday Mercury (Writing &amp; Fighting Series)'),
#  Row(Publisher='Belle Publishing', Title='The Boy with the Betty Grable Legs'),
#  Row(Publisher='Beltz & Gelberg', Title='Zwei Wochen im Mai: Mein Vater, der Rudi, der Hansi und ich : Roman'),
#  Row(Publisher='Beltz & Gelberg', Title='Fundevogel, oder, Was war, hÃ¶rt nicht einfach auf: Roman'),
#  Row(Publisher='Beltz &amp; Gelberg', Title='Die Menschenrechte haben kein Geschlecht: Die Lebensgeschichte der Hedwig Dohm (Beltz & Gelberg Biographie)'),
#  Row(Publisher='Beltz und Gelberg', Title='Herabsetzende Ã?usserungen: ErzÃ¤hlung'),
#  Row(Publisher='Benbella Books', Title='The Man Who Folded Himself'),
#  Row(Publisher='Benchmark Books (NY)', Title='If You Were a Firefighter (If You Were a...)'),
#  Row(Publisher='Benchmark Books (NY)', Title='The Atlantic Coast (Ecosystems of North America, Set 2)'),
#  Row(Publisher='Benchmark Books (NY)', Title='The Cooking of Italy (Superchef)'),
#  Row(Publisher='Benchmark Publishing and Design', Title='The Price'),
#  Row(Publisher='Benedict Lust Publications', Title='The Herb Book'),
#  Row(Publisher='Benedict Lust Publications', Title='Back to Eden'),
#  Row(Publisher='Benedict Lust Publications', Title='The Story of My Life'),
#  Row(Publisher='Benedict Lust Publications', Title="Rational Fasting (Ehret's Health Literature)"),
#  Row(Publisher='Benedikt Taschen Verlag', Title='Gustav Klimt (Postcardbooks)'),
#  Row(Publisher='Benjamin Co', Title="McCormick/Schilling's New Spice Cookbook"),
#  Row(Publisher='Benjamin Co', Title='The Knox Gelatine Cookbook'),
#  Row(Publisher='Bentlight Media', Title='Tours for Free Colorado 2003 (Tours for Free Colorado)'),
#  Row(Publisher='Berita Pub', Title='The early years, 1947-1972'),
#  Row(Publisher='Berkeley Books', Title='Come Together'),
#  Row(Publisher='Berkeley Publishing Group', Title='Key of Valor'),
#  Row(Publisher='Berkley Boulevard Books', Title='The Mummy Returns'),
#  Row(Publisher='Berkley Jam Books', Title='College Life 101: Cameron: The Sorority (College Life 101)'),
#  Row(Publisher='Berkley Prime Crime', Title='A Little Traveling Music, Please (Honey Huckleberry Mysteries)'),
#  Row(Publisher='Berkshire House Publishers', Title="The Berkshire Reader: Writings from New England's Secluded Paradise"),
#  Row(Publisher='Berkshire House Publishers', Title="Norman Rockwell's Four Freedoms: Images That Inspire a Nation"),
#  Row(Publisher='Berkshire House Publishers', Title='Country Inns and Back Roads Cookbook'),
#  Row(Publisher='Berkshire House Publishers', Title='French Ways and Their Meaning'),
#  Row(Publisher='Berkshire House Publishers', Title='The Charleston, Savannah & Coastal Islands Book: A Complete Guide (Great Destinations Series)'),
#  Row(Publisher='Berlitz Guides', Title='Berlitz Morocco Pocket Guide (Berlitz Pocket Guides)'),
#  Row(Publisher='Berlitz Guides', Title='Berlitz Essential Spanish (Berlitz Phrase Books)'),
#  Row(Publisher='Berlitz Guides', Title='Berlitz Italian'),
#  Row(Publisher='Berlitz Guides', Title='Berlitz Toronto Pocket Guide (Berlitz Pocket Guide Series)'),
#  Row(Publisher='Bertelsmann', Title='Inseln der SÃ¼dsee: 7 Reisen ins Paradies'),
#  Row(Publisher='Bertelsmann', Title='Abenteuer der Ferne'),
#  Row(Publisher='Bertelsmann-Lexikon-Verlag', Title='Das Verhalten des Menschen (Aktuelles Wissen)'),
#  Row(Publisher='Beso Entertainment', Title='Hooked on Raw'),
#  Row(Publisher='Bess Press', Title='How to Recycle a Dead Gecko'),
#  Row(Publisher='Best Bistros & Brasseries', Title='Favorite Paris Bistros: Twenty-first Century Edition'),
#  Row(Publisher='Betania', Title='La resaca del absurdo: (confusos recuerdos de las Isla de la Siguaraya y sus consecuencias) (ColecciÃ³n Betania de poesÃ\xada)'),
#  Row(Publisher='Bethany House', Title='Love Comes Softly (Love Comes Softly, Book 1)'),
#  Row(Publisher='Bethel Publishing', Title="Prodigal Cat (Classic Children's Story)"),
#  Row(Publisher='Better Homes and Gardens Books', Title='The New Decorating Book (Better Homes and Gardens(R))'),
#  Row(Publisher='Better Homes and Gardens Books', Title='101 Full-Size Quilt Blocks and Borders'),
#  Row(Publisher='Betz', Title='1 + 2=4: Das Gigelchen geht in die Schule'),
#  Row(Publisher='Bev Hawley & Company', Title='Held in the Arms of Love : A Blessing'),
#  Row(Publisher='Bewrite Books', Title='Matabele Gold'),
#  Row(Publisher='Bibliographisches Institut, Mannheim', Title='Das KÃ?Â¤nguru.'),
#  Row(Publisher='Bibliographisches Institut, Mannheim', Title='Am FluÃ?Â?.'),
#  Row(Publisher='Bibliographisches Institut, Mannheim', Title='Kleiner Deutschlandatlas.'),
#  Row(Publisher='Bicycle Books', Title='Major Taylor: The Extraordinary Career of a Champion Bicycle Racer'),
#  Row(Publisher='Big 4 Media', Title='Agony and Ecstacy'),
#  Row(Publisher='Big Cat Press', Title='The Kitchen and the Cook'),
#  Row(Publisher='BigHead Press', Title='A Drug War Carol'),
#  Row(Publisher='Billy Graham Evangelistic Association', Title='The Vision of His Glory'),
#  Row(Publisher='Billy Graham Evangelistic Association', Title='Intense Moments with the Savior: Learning to Feel'),
#  Row(Publisher='Billy Graham Evangelistic Association', Title="The Incredible Patience of God : (How Come It's Taking Me So Long?)"),
#  Row(Publisher='Biosphere Press', Title='Eating in: From the Field to the Kitchen in Biosphere 2'),
#  Row(Publisher='Birch Brook Press', Title='How to Attain Moral Perfection'),
#  Row(Publisher='Birkhauser Verlag', Title='Zukunftsfahiges Deutschland: Ein Beitrag Zu Einer Global Nachhaltigen Entsicklung'),
#  Row(Publisher='Birlinn', Title='The complete patter'),
#  Row(Publisher='Black Classic Pr', Title="Gone Fishin': An Easy Rawlins Novel (Easy Rawlins Mysteries (Hardcover))"),
#  Row(Publisher='Black Dog &amp; Leventhal Publishers', Title='Big Little Book of Irish Wit & Wisdom: Six Volumes in One : Irish Blessings, Irish Toasts, Irish Proverbs, Irish Riddles, Irish Laws, Irish Wisdom'),
#  Row(Publisher='Black Dome Press', Title='Old Eagle Nester: The Lost Legends of the Catskills'),
#  Row(Publisher='Black Rose Books', Title='Requiem for a Lightweight: Stockwell Day and Image Politics'),
#  Row(Publisher='Black Rose Books', Title='Academic Corporation'),
#  Row(Publisher='Black Rose Books', Title='Radical Papers'),
#  Row(Publisher='Black Rose Books', Title='The Heart of a Heartless World: Religion As Ideology'),
#  Row(Publisher='Black Rose Books', Title='Making Waves: The Origin and Future of Greenpeace'),
#  Row(Publisher='Black Rose Books', Title='Finding Our Way: Rethinking Eco-Feminist Politics'),
#  Row(Publisher='Blacklock Nature Photography', Title='Border Country: Photographs from the Quentico-Superior Wilderness'),
#  Row(Publisher='Blacksmith Corp', Title="Paintball, the Wizard's Way: The Authoritative Book on Paintball Equipment, Strategy, and Tactics"),
#  Row(Publisher='Blackstaff Press Ltd', Title='Desire Lines'),
#  Row(Publisher='Blackstone Press', Title='A Practical Approach to Family Law (Practical Approach S.)'),
#  Row(Publisher='Blackstone Press', Title="Learning legal rules: A student's guide to legal method and reasoning"),
#  Row(Publisher='Blake Publishing, Ltd.', Title='Will I See You in Heaven?: Thoughts on Heaven from the Rich, the Famous, the Poor, the Needy, and the Notorious'),
#  Row(Publisher='Blake Publishing, Ltd.', Title='The Broken Biscuit'),
#  Row(Publisher='Blake et Mortimer', Title='Blake et Mortimer, tome 12 : Les 3 formules du professeur Sato 2'),
#  Row(Publisher='Blake et Mortimer', Title='"Blake et Mortimer, Le Rayon ""U\\"""'),
#  Row(Publisher='Blake et Mortimer', Title="Blake et Mortimer, tome 13 : L'affaire Francis Blake"),
#  Row(Publisher='Blake et Mortimer', Title="Blake et Mortimer, tome 7 : L'Ã?Â©nigme de l'Atlantide"),
#  Row(Publisher='Blake et Mortimer', Title='Blake et Mortimer, tome 6 : La marque jaune'),
#  Row(Publisher='Blake et Mortimer', Title='Blake et Mortimer, tome 4 : Le mystÃ?Â¨re de la grande pyramide 1'),
#  Row(Publisher='Blanvalet', Title='Am Ende des Schweigens. Roman'),
#  Row(Publisher='Bloodletting Pr', Title='Rage'),
#  Row(Publisher='Bloomberg Press', Title='The New Commonsense Guide to Mutual Funds'),
#  Row(Publisher='Bloomberg Press', Title='Clicking Through: A Survival Guide for Bringing Your Company Online'),
#  Row(Publisher='Bloomberg Press', Title="Get in the Game!: The Girls' Guide to Money and Investing"),
#  Row(Publisher='Bloomsbury Pub', Title='Magic'),
#  Row(Publisher='Blue Harbor Press', Title="The mariner's trivia book"),
#  Row(Publisher='Blue Moon Books', Title='Sacred Exchange: Stories of Spirituality and Transcendence in Dominance and Submission'),
#  Row(Publisher='Blue Moon Books', Title='Story of O'),
#  Row(Publisher='Blue Moon Books', Title='Flesh on Fire'),
#  Row(Publisher='Blue Mountain Arts', Title='The One World, One Heart: Everyone Has the Same Basic Needs and Emotions. We Must Put Aside Our Differences and Come Together as One in Peace, U'),
#  Row(Publisher='Blue Mountain Press', Title='Between Two Sisters: Heartfelt Notes Of Love And Appreciation'),
#  Row(Publisher='Blue Penguin Publications', Title='Amazing Traveler: Isabella Bird'),
#  Row(Publisher='Blue Sky Press', Title='Captain Underpants and the Big, Bad Battle of the Bionic Booger Boy, Part 2 : Revenge of the Ridiculous Robo-boogers (Captain Underpants)'),
#  Row(Publisher='Bluedoor Publishing', Title='Gang Ranch the Real Story'),
#  Row(Publisher='Bogfire Inc.', Title='Tales of the Sacred Heart'),
#  Row(Publisher='Boise State Univ', Title='Carol Ryrie Brink (Western Writers Series, No 100)'),
#  Row(Publisher='Bolchazy-Carducci Publishers', Title='Ovid: Selections from Ars Amatoria Remedia Amoris'),
#  Row(Publisher='Bolinda', Title='Darkness, Be My Friend'),
#  Row(Publisher='Bompiani Italian', Title='Il Piccolo Principe Prince Italn'),
#  Row(Publisher='Bon Vivant Press', Title='"The Great Vegetarian Cookbook: The Chef\'s Secret Recipes (Fish, Kathleen Devanna. Books of the ""Secrets\\"" Series.)"'),
#  Row(Publisher='Bonneville Books', Title='"Bless My Soul: A ""Soul\\""-ution for All"'),
#  Row(Publisher='Bonneville Books', Title='Surrounded by Strangers'),
#  Row(Publisher='Book Pub Co', Title='The Art of Tofu'),
#  Row(Publisher='Book Pub Co', Title='Foods That Cause You to Lose Weight'),
#  Row(Publisher='Book Pub. Co', Title='Spiritual midwifery'),
#  Row(Publisher='Book Pub. Co', Title='Tofu cookery'),
#  Row(Publisher='Book of Hope', Title='Book of Hope'),
#  Row(Publisher='Book-Lab', Title="Mr. Wizard's 400 Experiments in Science"),
#  Row(Publisher='Books For Pleasure Ltd', Title='Herbs and Spices'),
#  Row(Publisher='Books for Libraries Press', Title='The sins of Saint Anthony;: Tales of the theatre (Short story index reprint series)'),
#  Row(Publisher='Books for Midwives Pr', Title='Feeding Our Babies: Exploring Traditions of Breastfeeding and Infant Nutrition'),
#  Row(Publisher='Books in Motion', Title='The Minotaur and the Golden Fleece'),
#  Row(Publisher='Books in Motion', Title='Tribulation Force: The Continuing Drama of Those Left Behind (Left Behind, Book 2)'),
#  Row(Publisher='Books in Motion', Title='Stories from Tanglewood Tales'),
#  Row(Publisher='Booksurge Llc', Title="January's Paradigm"),
#  Row(Publisher='Bookthrift', Title='Fifty Years of the Movies'),
#  Row(Publisher='Bookthrift', Title="Norman Rockwell's Christmas"),
#  Row(Publisher='Bookthrift', Title='America the Beautiful'),
#  Row(Publisher='Booth-Clibborn Editions', Title='Fax You : Urgent Images'),
#  Row(Publisher='Booth-Clibborn Editions', Title='The Sneaker Book'),
#  Row(Publisher='Boru Books', Title="A Soul's Journey: Empowering the Present Through Past Life Regression"),
#  Row(Publisher='Bossiney', Title='The South Hams'),
#  Row(Publisher='Boston Mills Press', Title="Toronto's Ravines: Walking the Hidden Country"),
#  Row(Publisher='Boston Mills Press', Title='The Antique Mystique: Guide to Southern Ontario'),
#  Row(Publisher='Bourget Bros', Title='Basics of Bead Stringing'),
#  Row(Publisher='Bowerdean Publishing Company', Title='I Write What I Like: A Selection of His Writings'),
#  Row(Publisher='Boy Scouts Of America', Title='Cub Scout Magic Tricks Magic Puzzles Stu'),
#  Row(Publisher='Bradford Book', Title="Shannon Miller: America's Most Decorated Gymnast : A Biography"),
#  Row(Publisher='Bradford Books', Title='The Man Who Tasted Shapes'),
#  Row(Publisher='Bradt Publications', Title='Peru & Bolivia Backpacking: Backpacking and Trekking'),
#  Row(Publisher='BradyGames', Title=' Final Fantasy Anthology: Official Strategy Guide (Brady Games)'),
#  Row(Publisher='Bradygames', Title='Final Fantasy VIII Official Strategy Guide'),
#  Row(Publisher='Bragg Live Foods', Title='Apple Cider Vinegar - Miracle Health System'),
#  Row(Publisher='Braguelonne', Title="Shannara, tome 1 : L'EpÃ?Â©e de Shannara"),
#  Row(Publisher='Breakwater Books Ltd', Title='Random Passage'),
#  Row(Publisher='Brepols Publishers', Title='Investigating Jan Van Eyck.'),
#  Row(Publisher='Brepols Publishers', Title='Rubens and the Judgement of Paris: A Question of Choice.'),
# ...
#  Row(Publisher='Compass American Guides', Title="Compass American Guides New Hampshire (Fodor's Compass American Guids)"),
#  Row(Publisher='Compute', Title="The Official Guide to Sid Meier's Civilization"),
#  Row(Publisher='Computer Book Division/Simon & Schuster', Title='The fully powered PC (PC world books)'),
#  Row(Publisher='Concello de Ourense', Title='O poema dos lustros'),
#  Row(Publisher='Congdon & Weed', Title='In Deep Woods: Jackie-Cn'),
#  Row(Publisher='Conran', Title='Chinese Style: The Art of Living'),
#  Row(Publisher='Conran Octopus', Title='Simple Country Style: And How to Achieve It'),
#  Row(Publisher='Consolidated Book Publishers', Title='The new color-picture dictionary for children'),
#  Row(Publisher='Consortium Book Sales &amp; Dist', Title='Art & Fear: Observations on the Perils (And Rewards of Artmaking)'),
#  Row(Publisher='Constable Robinson', Title='Come and Hug Me'),
#  Row(Publisher='Constable Robinson', Title='A Modern Magician'),
#  Row(Publisher='Consultant Press, Ltd.', Title='Matting and Hinging of Works of Art on Paper'),
#  Row(Publisher='Consumer Reports', Title='Consumer Reports Guide to Baby Products (Best Baby Products)'),
#  Row(Publisher='Contemporary Arts Museum', Title='When 1 is 2: The Art of Alighiero e Boetti'),
#  Row(Publisher='Contemporary Books', Title="Unbelievably Good Deals and Great Adventures That You Absolutely Can't Get Unless You're over 50 (4th Ed)"),
#  Row(Publisher='Contemporary Books', Title='The Nautilus book'),
#  Row(Publisher='Contemporary Perspectives Inc.', Title='Finn, the Foolish Fish: Trouble With Bubbles : A Bob Miller Picture Story (Orange Blossom See How I Read Book)'),
#  Row(Publisher='Context Books', Title='After Dachau: A Novel'),
#  Row(Publisher='Continental Press', Title="In whose best interest?: One child's odyssey, a nation's responsibility"),
#  Row(Publisher='Continuum International Publishing Group', Title='Pedagogy of the Oppressed'),
#  Row(Publisher='Continuum International Publishing Group', Title='The Bedside, Bathtub & Armchair Companion to Agatha Christie'),
#  Row(Publisher='Continuum International Publishing Group', Title="Donna Tartt's The Secret History: A Reader's Guide (Continuum Contemporaries)"),
#  Row(Publisher='Continuum International Publishing Group', Title='The Art of Loving'),
#  Row(Publisher='Continuum International Publishing Group', Title='Open Mind, Open Heart: The Contemplative Dimension of the Gospel'),
#  Row(Publisher='Continuum International Publishing Group', Title='To Have or to Be?'),
#  Row(Publisher='Continuum International Publishing Group', Title="Haruki Murakami's The Wind-up Bird Chronicle: A Reader's Guide (Continuum Contemporaries)"),
#  Row(Publisher='Continuum International Publishing Group', Title='Prose and Poetry (German Library)'),
#  Row(Publisher='Continuum International Publishing Group', Title="Philip Pullman's His Dark Materials Trilogy: A Reader's Guide (Continum Contemporaries)"),
#  Row(Publisher='Convenant Communications', Title='Emma and Joseph: Their Divine Mission'),
#  Row(Publisher='Conversations with Millionaires LLC', Title='Conversations with Millionaires: What Millionaires Do to Get Rich, That You Never Learned About in School!'),
#  Row(Publisher='Cook Communications Ministries International', Title='Cherry Cola Champions (Alex)'),
#  Row(Publisher='Cooper Square Publishers', Title='Lennon in America: Based in Part on the Lost Lennon Diaries 1971-1980'),
#  Row(Publisher='Copernic', Title="Les Dieux maudits: RÃ©cits de mythologie nordique (Mythes et Ã©popÃ©es d'Europe)"),
#  Row(Publisher='Coppenrath, MÃ?Â¼nster', Title='Das kleine Duftzauberbuch. Von der Welt der DÃ?Â¼fte und Aromen.'),
#  Row(Publisher='Coppenrath, MÃ?Â¼nster', Title='Das kleine Zahlenzauberbuch. Von der Mystik und Magie der Zahlen.'),
#  Row(Publisher='Copper Beech', Title="Sharks Keep Losing Teeth And (I Didn't Know That)"),
#  Row(Publisher='Copper Beech', Title='Big Event, The (Me and My Horse)'),
#  Row(Publisher='Copper Beech', Title='New Book Of Pharaohs (New Book Of... (Hardcover))'),
#  Row(Publisher='Coppola', Title='Le siciliane: Quindici storie vere / Giacomo Pilati'),
#  Row(Publisher='Corax Press', Title='Handbook of the Canadian Rockies'),
#  Row(Publisher='Cordovan Corp', Title='Eyes of Texas travel guide'),
#  Row(Publisher='Corgi Books', Title='Web Site Story'),
#  Row(Publisher='Corgi Childrens', Title='Pure Dead Magic'),
#  Row(Publisher='Coriolis Technology Press', Title='Windows Admin Scripting Little Black Book: A Concise Guide to Essential Scripting for Administrators'),
#  Row(Publisher='Coriolus Group Books', Title='How to Get Into Your Dream College Using the Web: Find the College You Want Without the Hassle'),
#  Row(Publisher='Cork Hill Press', Title='New England Interlude'),
#  Row(Publisher='Cork Hill Press', Title='The Autobiography of Jesus Christ as Told to: Neil Elliott'),
#  Row(Publisher='Corkscrew Press', Title='1,000,001 Things That Make You Crabby: The Official Checklist for Complainers, Ranters, Ravers and Bellyachers, and Everybody Else'),
#  Row(Publisher='Cornelsen', Title='Moon Palace. (Lernmaterialien)'),
#  Row(Publisher='Cornelsen', Title='La vie est comme ca. Scenes de la vie mouvementee du Petit Nicholas. (Lernmaterialien)'),
#  Row(Publisher='Cornelsen', Title='Klassische SchullektÃ?Â¼re, Klassische und moderne Kurzgeschichten'),
#  Row(Publisher='Cornelsen', Title='Fahrenheit 451. Text des Romans. (Lernmaterialien)'),
#  Row(Publisher='Cornelsen', Title='The Twelfth Day of July. (Lernmaterialien)'),
#  Row(Publisher='Cornelsen', Title='The Quiet American. FÃ?Â¼r die Sek.II. Senior English Library'),
#  Row(Publisher='Cornelsen Lernhilfen', Title='Pocket Teacher, Sekundarstufe I, Chemie'),
#  Row(Publisher='Cornerstone Books', Title='Alpha centauri'),
#  Row(Publisher='Coronet Books & Publications', Title='The Solitary Man (Stephen Leather Thrillers)'),
#  Row(Publisher='Corporation of Sheffield; Wakefield, EP Publishing Ltd', Title="'Isms: a dictionary of words ending in -ism, -ology, and -phobia,: With some similar terms, arranged in subject order"),
#  Row(Publisher='Cosmos Press', Title='Sodom and a Greek Passion: Rags and Old Iron'),
#  Row(Publisher='Coulsong List', Title="Out of Isak Dinesen in Africa: Karen Blixen's Untold Story"),
#  Row(Publisher='Council on Foreign Relations Press', Title='Minority Rights in Europe (Chatham House Papers (Unnumbered).)'),
#  Row(Publisher='Council on Foreign Relations Press', Title='How Can Africa Survive'),
#  Row(Publisher='Country Scenics Pub', Title='The Glorious Seasons of Sedona'),
#  Row(Publisher='Countryside Books', Title='Ghosts of East Anglia'),
#  Row(Publisher='Course Technology Ptr', Title='MCSE Lab Manual for Microsoft Windows 2000 Active Directory'),
#  Row(Publisher='Course Technology Ptr', Title='i-Net+ Guide to Internet Technologies (Lab Manual)'),
#  Row(Publisher='Course Technology Ptr', Title='Microsoft Windows 95 - Illustrated Standard Edition'),
#  Row(Publisher='Course Technology Ptr', Title='New Perspectives on Microsoft FrontPage 98 -- Introductory'),
#  Row(Publisher='Course Technology Ptr', Title='MCSE LabSim for Windows 2000 Server'),
#  Row(Publisher='Coutinho', Title='Statistiek voor historici'),
#  Row(Publisher='Covenant House', Title="Sometimes God Has a Kid's Face"),
#  Row(Publisher='Cox Publishing', Title='Roadside Ron'),
#  Row(Publisher='Cq Products', Title='Gifts in a Jar: Cookies'),
#  Row(Publisher='Crafty Secrets Publications', Title='500 Great Heartwarming Expressions For Scrapbooking & Cards'),
#  Row(Publisher='Craigs', Title='The southern scenic collection: New Zealand'),
#  Row(Publisher='Creating Keepsakes Books', Title="Mom's Little Book of Photo Tips"),
#  Row(Publisher='Creative Education Inc', Title='Serendipity (Serendipity Book)'),
#  Row(Publisher='Creative Press', Title='Rubber Stamping Beyond the Basics'),
#  Row(Publisher='Creative Pub Intl', Title='Haunted Wisconsin'),
#  Row(Publisher='Creepy Little Productions', Title='Madame M Presents Creepy Little Bedtime Stories'),
#  Row(Publisher='Crippen & Landru Publishers', Title='Suitable for Hanging: Selected Stories'),
#  Row(Publisher='Crippen & Landru, Publishers', Title='The Tragedy of Errors and Others'),
#  Row(Publisher='Critica Barcelona', Title='Historia De Espana'),
#  Row(Publisher='Critics Choice Paperbacks', Title='Freeze'),
#  Row(Publisher='Critics Choice Paperbacks', Title='Morning Ran Red'),
#  Row(Publisher='Critics Choice Paperbacks', Title="Jenny's War"),
#  Row(Publisher='Critics Choice Paperbacks/Lorevan Publishing', Title="His Lordship's Arsenal"),
#  Row(Publisher='Critics Choice Paperbacks/Lorevan Publishing', Title='The Proud Castles'),
#  Row(Publisher='Critics Choice Paperbacks/Lorevan Publishing', Title='Buck Alice and the Actor Robot'),
#  Row(Publisher='Crocodile Books', Title='Little Turtle: And the Song of the Sea'),
#  Row(Publisher='Crocodile Books', Title="Finnegan's Wind"),
#  Row(Publisher='Crossing', Title='The Power of A Praying Woman'),
#  Row(Publisher='Crossroad', Title='Sacred Texts of the World: A Universal Anthology'),
#  Row(Publisher='Crotalus Publishing', Title='Lake Desire'),
#  Row(Publisher='Crown Forum', Title='Treason : Liberal Treachery from the Cold War to the War on Terrorism'),
#  Row(Publisher='Crown House Publishing', Title='The Power Process: An NLP Approach to Writing'),
#  Row(Publisher='Crown Publishers Harmony Books', Title="The Hitchhiker's Trilogy"),
#  Row(Publisher='Crowswing Books', Title='Jesse Jameson and the Golden Glow (Alpha to Omega Series)'),
#  Row(Publisher='Cryptic Press (NY)', Title='A Cat Named Rush Limbaugh, a Dog Named Howard Stern'),
#  Row(Publisher='Cune Press', Title='Searching Jenin: Eyewitness Accounts of the Israeli Invasion 2002'),
#  Row(Publisher='Currier-Davis Pub', Title='Death from Child Abuse... and No One Heard'),
#  Row(Publisher='Cycle America', Title="Seeing Myself Seeing the World: A Woman's Journey Around the World on a Bicycle"),
#  Row(Publisher='D. C. Cook Pub', Title='Uncle Alphonso and the puffy proud dinosaurs (An On my own book)'),
#  Row(Publisher='D. McKay', Title='History of the SS'),
#  Row(Publisher='D. R. Godine', Title="Printer's abecedarium"),
#  Row(Publisher='D. R. Godine', Title='Lost highway: Journeys & arrivals of American musicians'),
#  Row(Publisher='D. R. Godine', Title='The Battle for Gaul'),
#  Row(Publisher='D. Spears', Title='In Search of Goodpussy: Living Without Love'),
#  Row(Publisher='D. Wood', Title="Debby Wood's Florida: A slice of paradise"),
#  Row(Publisher='DAW', Title='River of Blue Fire (Otherland, Volume 2)'),
#  Row(Publisher='DCI Publishing', Title='All-American Low-Fat Meals in Minutes: Recipes and Menus for Special Occasions or Every Day'),
#  Row(Publisher='DOPESA 2', Title='Los seductores (ColecciÃ³n Los Marginados)'),
#  Row(Publisher='DTP', Title='The Princessa : Machiavelli for Women'),
#  Row(Publisher='DTP', Title='The Dr. Drew and Adam Book: A Survival Guide To Life and Love'),
#  Row(Publisher='DTV Premium', Title='Autopol: Ilija Trojanow ; in Zusammenarbeit mit Rudolf Spindler'),
#  Row(Publisher='DUMONT monte', Title='Art: From Prehistoric Art Until Modernism (Flipguide)'),
#  Row(Publisher='DUMONT monte', Title='365 Steps Towards Harmony: Feng Shui (365 Tips a Year)'),
#  Row(Publisher='Daedalus Books', Title="What's Bred in the Bone"),
#  Row(Publisher='Daily Telegraph', Title='The London Transport golden jubilee book, 1933-1983'),
#  Row(Publisher='Dale Seymour Publications', Title='Every Minute Counts: Making Your Math Class Work'),
#  Row(Publisher='Dale Seymour Publications', Title='Fascinating Fibonaccis: Mystery and Magic in Numbers'),
#  Row(Publisher='Dale Seymour Publications', Title="The Teacher's Quotation Book: Little Lessons on Learning"),
#  Row(Publisher='Dalkey Archive Pr', Title='The Dalkey Archive: A Novel'),
#  Row(Publisher='Dalmatian Press', Title='The Call of the Wild (Dalmatian Press Adapted Classic)'),
#  Row(Publisher='Dalmatian Press', Title='Treasure Island (Dalmatian Press Adapted Classic)'),
#  Row(Publisher='Dalmatian Press', Title='Peter Pan (Dalmatian Press Adapted Classic)'),
#  Row(Publisher='Dalmatian Press', Title='Adventures of Huckleberry Finn (Dalmatian Press Adapted Classic)'),
#  Row(Publisher='Dalmatian Press', Title='Heidi (Dalmatian Press Adapted Classic)'),
#  Row(Publisher='Dalmatian Press', Title='The Lion and the Mouse'),
#  Row(Publisher='Dancing Ground Pr', Title='The Road to Shamballah'),
#  Row(Publisher='Dandy Lion Pubns', Title='Quotation Quizzlers: Puzzling Your Way Through Famous Quotations'),
#  Row(Publisher='Dandy Lion Pubns', Title='One Hour Mysteries'),
#  Row(Publisher='Danielle Girard', Title="Cold Silence: When There's No Place Left To Hide, All You Can Do is Run"),
#  Row(Publisher='Darling & Company', Title='Zaftig: The Case for Curves'),
#  Row(Publisher='Dartnell Corp.', Title='Teams: Together Each Achieves More Success: How to Develop Peak Performance Teams for World-Class Results'),
#  Row(Publisher='Darton Longman and Todd', Title='The Broken Body: Journey to Wholeness'),
#  Row(Publisher='Darwin Pubns', Title='Far Pastures'),
#  Row(Publisher='Daughters, inc.]', Title='In her day'),
#  Row(Publisher='David &amp; Charles Publishers', Title='Cross Stitch Myth & Magic: Wizards, Angels, Dragons, Mermaids, Cherubs, Unicorns, Fairies'),
#  Row(Publisher='David Brown Book Co', Title='A History of Suffolk (The Darwen county history series)'),
#  Row(Publisher='David Ling', Title='My name is Paradiso'),
#  Row(Publisher='David Ling Publishers', Title='Cutting loose'),
#  Row(Publisher='David P. Schloss', Title="Don't Tie Yourself Up in Nots: How to Untie Yourself from the Can Nots and Should Nots of Life"),
#  Row(Publisher='David Porteous Editions', Title='Silhouettes in Cross Stitch'),
#  Row(Publisher='David R. Godine Publisher', Title="The Superior Person's Book of Words"),
#  Row(Publisher='Davies-Black Publishing', Title="What's Your Type of Career?: Unlock the Secrets of Your Personality to Find Your Perfect Career Path"),
#  Row(Publisher='Dawn', Title="Sadat's strategy (History in the making)"),
#  Row(Publisher='Dawn Pubns', Title='Sharing the Joy of Nature: Nature Activities for All Ages'),
#  Row(Publisher='Daybue Publishing', Title='Church of the Dog'),
#  Row(Publisher='De Haan', Title='Het verstoorde leven: Dagboek van Etty Hillesum, 1941-1943'),
#  Row(Publisher='Dearborn Financial Publishing', Title="Anatomy of a Business Plan: A Step-By-Step Guide to Starting Smart, Building the Business, and Securing Your Company's Future (Anatomy of a Business Plan)"),
#  Row(Publisher='Decent Exposure Press', Title='Breakfast with a cereal killer (The rainbow mystery series)'),
#  Row(Publisher='Dedalus', Title='De man zonder lijk'),
#  Row(Publisher='Dedalus Press', Title='The Revenants'),
#  Row(Publisher='Deer Publishing Company (CA)', Title='The Butterfly Touch: Recovery Through Poetry'),
#  Row(Publisher='Deirdre McDonald Books', Title='Brilliant Advice!'),
#  Row(Publisher='Del Rey', Title='Fahrenheit 451'),
#  Row(Publisher='Delacorte Books for Young Readers', Title='Sisterhood of the Traveling Pants'),
#  Row(Publisher='Delacorte Press Books for Young Readers', Title='Who Are You?'),
#  Row(Publisher='Delacorte Press Books for Young Readers', Title="Dragon's Blood: Pit Dragons : Book One"),
#  Row(Publisher='Delacorte Press/S. Lawrence', Title='A child is born: New photographs of life before birth and up-to-date advice for expectant parents'),
#  Row(Publisher='Delacorte Press/Seymour Lawrence', Title='Jailbird: A novel'),
#  Row(Publisher='Delair Pub Co', Title='Polish Cookbook'),
#  Row(Publisher='Dell Publishing', Title='Dating Game'),
#  Row(Publisher='Delmar Learning', Title='Photography: The Concise Guide'),
#  Row(Publisher='Delmar Learning', Title='101 Great Resumes'),
#  Row(Publisher='Delmar Publishers', Title="The Smart Woman's Guide to Resumes and Job Hunting, Second Edition"),
#  Row(Publisher='Delphi Books', Title='Cat Tracks'),
#  Row(Publisher='Delphi Books', Title='Once A Warrior'),
#  Row(Publisher='Delta', Title='Confessions of a Shopaholic (Summer Display Opportunity)'),
#  ...]

# %%
data = books.join(ratings, 'ISBN', 'left')
overRating = Window.partitionBy(data.Publisher).orderBy(F.desc("num_ratings"))
data.groupBy("Publisher", "Title").agg(F.count(data.Rating).alias("num_ratings")).withColumn("diff", F.max("num_ratings").over(overRating) - F.col("num_ratings")).select("Publisher", "Title", "diff").collect()
# Out:
# [Row(Publisher='"""Otokar Kersovani\\"""', Title='"Gdje pijevac ne pjeva (Biblioteka ""Zlatni paun\\"")"', diff=0),
#  Row(Publisher='"Flemish-Netherlands Foundation ""Stichting Ons Erfdeel,\\"""', Title='Contemporary poetry of the low countries', diff=0),
#  Row(Publisher='3D Press', Title='Denver Hiking Guide:  45 Hikes within 45 Minutes of Denver', diff=0),
#  Row(Publisher='3H Productions, Inc.', Title="Haley's Cleaning Hints", diff=0),
#  Row(Publisher='A H M Publications', Title='The Subjection of Women (Crofts Classics)', diff=0),
#  Row(Publisher='A. & C. Black', Title="Writing for television in the 70's", diff=0),
#  Row(Publisher='A. & M. Muchnik', Title='Comuna Verdad (Analectas)', diff=0),
#  Row(Publisher='A. Deutsch', Title='Moon Tiger', diff=0),
#  Row(Publisher='A. Deutsch', Title='Russia in revolution, 1900-1930', diff=1),
#  Row(Publisher='A. Deutsch', Title='Apple of my eye', diff=1),
#  Row(Publisher='A. Deutsch', Title='Pictures from the water trade: An Englishman in Japan', diff=1),
#  Row(Publisher='A. Deutsch', Title='Good behaviour', diff=1),
#  Row(Publisher='A.T.E', Title='El triÃ¡ngulo mortal de las Bermudas', diff=0),
#  Row(Publisher='AAAI Press', Title='Computers and Thought', diff=0),
#  Row(Publisher='AM', Title='La tahona de FroilÃ¡n', diff=0),
#  Row(Publisher='AVON', Title='Wedding Night', diff=0),
#  Row(Publisher='AVON', Title="Project Moon Dust: : Beyond Roswell--exposing The Government's Covert Investigations And Cover-ups", diff=1),
#  Row(Publisher='Abc-Clio Inc', Title='Circulation, Interlibrary Loan, Patron Use and Collection Maintenance: A Handbook for Library Management (Handbooks for library management)', diff=0),
#  Row(Publisher='Abc-Clio Inc', Title='Cannery Row (Mainstream Series)', diff=0),
#  Row(Publisher='Abc-Clio Inc', Title='Dictionary of Symbols', diff=0),
#  Row(Publisher='Abradale Press', Title='An illustrated treasury of Bible stories,', diff=0),
#  Row(Publisher='Abson Books', Title='Scottish-English, English-Scottish;', diff=0),
#  Row(Publisher='Abson Books', Title='Rhyming Cockney slang;', diff=2),
#  Row(Publisher='Acme Press', Title='Superfan', diff=0),
#  Row(Publisher='Acta Pubns', Title='A Contemporary Celtic Prayer Book', diff=0),
#  Row(Publisher='Actar', Title='HD: Holland Design--New Graphics', diff=0),
#  Row(Publisher='Actar', Title='Jordi Bernado: Very Very Bad News', diff=9),
#  Row(Publisher='Actar', Title='Chillida: 1948-1998', diff=9),
#  Row(Publisher='Active Synapse', Title='Clan Apis', diff=0),
#  Row(Publisher='Active Synapse', Title='The Sandwalk Adventures: An Adventure in Evolution Told in Five Chapters', diff=1),
#  Row(Publisher='Ad Vice Marketing Inc', Title='Media Tried Justice Denied, Behind the truth and Lies of the Darlie Lynn Routier Murder Case', diff=0),
#  Row(Publisher='Adamis International, Incorporated', Title='Exploring Atlantis, No I (Exploring Atlantis)', diff=0),
#  Row(Publisher='Adams Media Corp', Title='365 Tv-Free Activities You Can Do With Your Child', diff=0),
#  Row(Publisher='Adams Media Corp', Title='The Verbally Abusive Relationship: How to Recognize It and How to Respond', diff=3),
#  Row(Publisher='Adams Media Corp', Title="Jacob Marley's Christmas Carol", diff=6),
#  Row(Publisher='Adams Media Corp', Title='Show Biz Tricks for Cats: 30 Fun and Easy Tricks You Can Teach Your Cat', diff=6),
#  Row(Publisher='Adams Media Corp', Title='The Complete Single Mother: Reassuring Answers to Your Most Challenging Concerns', diff=7),
#  Row(Publisher='Adams Media Corp', Title='Museum of Science Book of Answers & Questions', diff=8),
#  Row(Publisher='Adams Media Corp', Title="Mr. Cheap's Chicago", diff=8),
#  Row(Publisher='Adams Media Corp', Title='The Everything Wedding Book; Everything you need to know to survive your wedding and actually even enjoy it.', diff=8),
#  Row(Publisher='Adams Media Corp', Title="Knock 'Em Dead: The Ultimate Job Seeker's Handbook/1995", diff=8),
#  Row(Publisher='Adams Media Corp', Title='Around the American Table: Treasured Recipes and Food Traditions from the American Cookery Collections of the New York Public Library', diff=8),
#  Row(Publisher='Adams Media Corp', Title='Banned: Classical Erotica : Forty Sensual and Erotic Excepts from Aristophanes to Whitman-Uncensored', diff=8),
#  Row(Publisher='Adams Media Corp', Title='What Every American Should Know About American History: 200 Events That Shaped the Nation', diff=9),
#  Row(Publisher='Adams Media Corp', Title="Cover Letters That Knock 'Em Dead", diff=9),
#  Row(Publisher='Adams Media Corp', Title='Table Talk!: 365 Ways to Reclaim the Family Dinner Hour', diff=9),
#  Row(Publisher='Adams Media Corp', Title='Call the Briefing: Bush and Reagan, Sam and Helen - A Decade With Presidents and the Press', diff=9),
#  Row(Publisher='Adams Media Corp', Title="Resumes That Knock 'Em Dead (Resumes That Knock 'em Dead)", diff=9),
#  Row(Publisher='Adams Media Corp', Title='Single in New York', diff=9),
#  Row(Publisher='Adams Media Corp', Title="Mr. Cheap's Boston: Bargains, Factory Outlets, Off-Price Stores, Deep Discount Stores, Cheap Eats, and Cheap Fun Things to Do.", diff=9),
#  Row(Publisher='Adams Media Corp', Title='The Everything Wedding Vows Book; Anything and everything you could possibly say at the altar-and then some', diff=9),
#  Row(Publisher='Adams Media Corp', Title='The Minority Career Book', diff=9),
#  Row(Publisher='Adams Media Corp', Title='Omni Best Science Fiction, 3', diff=9),
#  Row(Publisher='Adams Media Corp', Title='I Fall to Pieces: The Music and the Life of Patsy Cline', diff=9),
#  Row(Publisher='Adams Media Corp', Title='The Book of Women: 300 Notable Women History Passed by', diff=9),
#  Row(Publisher='Adams Media Corp', Title='The Job Search Handbook', diff=9),
#  Row(Publisher='Adams Media Corp', Title='The Remarkable Lives of 100 Women Writers and Journalists (20th Century Women)', diff=9),
#  Row(Publisher='Adams Media Corp', Title='Why Men Commit: Men Explain What It Takes to Turn a Casual Relationship into the Love of a Lifetime', diff=9),
#  Row(Publisher='Adams Media Corp', Title='50 Great Answers to Tough Interview Questions: How to Get the Job You Want', diff=9),
#  Row(Publisher='Adams Media Corp', Title='Breakthrough Business Meetings: Shared Leadership in Action', diff=9),
#  Row(Publisher='Adams Media Corp', Title='Toy Wars: The Epic Struggle Between G.I. Joe, Barbie, and the Companies That Make Them', diff=9),
#  Row(Publisher='Adams Media Corp', Title='Selling to Vito: The Very Important Top Officer', diff=9),
#  Row(Publisher='Adams Media Corp', Title='Instant Recall: Tapping Your Hidden Memory Power', diff=9),
#  Row(Publisher='Adams Media Corp', Title='Keeping It Simple: Sorting Out What Really Matters in Your Life', diff=9),
#  Row(Publisher='Adams Media Corp', Title="Wake Me When It's Funny: How to Break into Show Business and Stay There", diff=9),
#  Row(Publisher='Adams Media Corp', Title="Golf Is a Woman's Game", diff=9),
#  Row(Publisher='Adams Media Corp', Title='Marketing for the Home-Based Business', diff=9),
#  Row(Publisher='Adams Media Corp', Title='Knock `Em Dead 1997: The Ultimate Job Seekers Handbook (10th ed)', diff=9),
#  Row(Publisher='Adams Pub Co', Title="Becoming: A Master's Manual (Becoming series)", diff=0),
#  Row(Publisher='Adams-Blake Publishing', Title='Tears and Rage: The Nursing Crisis in America', diff=0),
#  Row(Publisher='Addison Books', Title='Business and Information Systems', diff=0),
#  Row(Publisher='Addison-wesley', Title='Taking Care of Your Child', diff=0),
#  Row(Publisher='Addison-wesley', Title='Men Without Masks', diff=1),
#  Row(Publisher='Addison-wesley', Title='Take Care of Yourself Consumers Guide to Medic', diff=1),
#  Row(Publisher='Addison-wesley', Title='Take Care of Yourself 4ED', diff=1),
#  Row(Publisher='Addison-wesley', Title='Artificial Intelligence Edition (Addison-Wesley series in computer science)', diff=2),
#  Row(Publisher='Adrenaline Audiobooks', Title='Survive: Stories of Castaways and Cannibals', diff=0),
#  Row(Publisher='Advaita Pr', Title='From Consciousness to Consciousness', diff=0),
#  Row(Publisher='Advantage Books', Title='Help4Add High School', diff=0),
#  Row(Publisher='Ageless Pr', Title='Computer Tales of Fact and Fantasy: Or How We Learned to Stop Worrying and Love the Computer', diff=0),
#  Row(Publisher='Ageless Pr', Title='Computer Legends, Lies & Lore', diff=0),
#  Row(Publisher='Aglow Pubns', Title='When Love Is Not Perfect: Discovering Gods Reparenting Process', diff=0),
#  Row(Publisher='Ahrens Pub. Co', Title="The bakers' manual for quantity baking and pastry making", diff=0),
#  Row(Publisher='Ajuntament de Lleida', Title='Nadal a Lleida (1940-1995) (Quaderns de divulgaciÃ³ ciutadana. ColÂ¨lecciÃ³ La banqueta)', diff=0),
#  Row(Publisher='Ajuntament de Lleida', Title='La premsa a Lleida (Quaderns de divulgaciÃ³ ciutadana)', diff=0),
#  Row(Publisher='Akadine Press', Title='The Inn at the Edge of the World (Common Reader Editions)', diff=0),
#  Row(Publisher='Akadine Press', Title='Haunted Bookshop (Common Reader Editions)', diff=3),
#  Row(Publisher='Akadine Press', Title='My Cousin Rachel (Common Reader Editions)', diff=4),
#  Row(Publisher='Akadine Press', Title='Fairy Tale (Common Reader Editions)', diff=5),
#  Row(Publisher='Akadine Press', Title='Walls Came Tumbling Down (Common Reader Editions)', diff=6),
#  Row(Publisher='Akadine Press', Title='Invasion 1940 (Common Reader Editions)', diff=7),
#  Row(Publisher='Akadine Press', Title='Come, Tell Me How You Live (Common Reader Editions:  Rediscoveries: LONDON)', diff=7),
#  Row(Publisher='Akadine Press', Title='Akenfield: Portrait of an English Village (Common Reader Editions)', diff=7),
#  Row(Publisher='Akadine Press', Title='Emerald (Common Reader Editions)', diff=7),
#  Row(Publisher='Akadine Press', Title='Of All Things! (Common Reader Editions)', diff=7),
#  Row(Publisher='Akadine Press', Title='No Bed for Bacon (Common Reader Editions)', diff=7),
#  Row(Publisher='Akadine Press', Title='The Coast of Bohemia (Common Reader Editions)', diff=7),
#  Row(Publisher='Akadine Press', Title='The Return of the Twelves (Common Reader Editions)', diff=8),
#  Row(Publisher='Akadine Press', Title='The Dead Secret (Common Reader Editions)', diff=8),
#  Row(Publisher='Akadine Press', Title='Max Jamison: A Novel (Common Reader Editions)', diff=8),
#  Row(Publisher='Akadine Press', Title='Love Conquers All (Common Reader Editions)', diff=8),
#  Row(Publisher='Akadine Press', Title='The Sin Eater (Common Reader Editions)', diff=8),
#  Row(Publisher='Akadine Press', Title='The Candlemass Road (Common Reader Editions)', diff=8),
#  Row(Publisher='Akadine Press', Title='The Black Hole Of Calcutta (Common Reader Editions)', diff=8),
#  Row(Publisher='Akadine Press', Title='Lady Molly Of Scotland Yard (Common Reader Editions)', diff=8),
#  Row(Publisher='Akadine Press', Title='Personal Pleasures', diff=8),
#  Row(Publisher='Akadine Press', Title="Adam's Task: Calling Animals by Name (Common Reader Editions)", diff=8),
#  Row(Publisher='Akadine Press', Title='The Birds of the Air  (Common Reader Editions)', diff=8),
#  Row(Publisher='Akadine Press', Title='Quartered Safe Out Here', diff=8),
#  Row(Publisher='Albin Michel', Title='Oscar et la dame rose', diff=0),
#  Row(Publisher='Albin Michel', Title='Un aller simple: Roman', diff=7),
#  Row(Publisher='Albin Michel', Title='Le livre du voyage', diff=9),
#  Row(Publisher='Albin Michel', Title='Robert des noms propres', diff=10),
#  Row(Publisher='Albin Michel', Title='Monsieur Ibrahim et les Fleurs du Coran', diff=11),
#  Row(Publisher='Albin Michel', Title="L'Arbre des possibles et autres histoires", diff=12),
#  Row(Publisher='Albin Michel', Title='Lettre ouverte aux FranÃ§ais qui se croient le nombril du monde (Collection Lettre ouverte)', diff=13),
#  Row(Publisher='Albin Michel', Title="L'Evangile selon Pilate: Roman", diff=13),
#  Row(Publisher='Albin Michel', Title='MÃ©taphysique des tubes: Roman', diff=14),
#  Row(Publisher='Albin Michel', Title='Tao Te King', diff=14),
#  Row(Publisher='Albin Michel', Title='Ce que vivent les roses', diff=16),
#  Row(Publisher='Albin Michel', Title="L'empire des anges: Roman", diff=16),
#  Row(Publisher='Albin Michel', Title='Coraline', diff=17),
#  Row(Publisher='Albin Michel', Title='La vie en rose', diff=17),
#  Row(Publisher='Albin Michel', Title='Perdu!', diff=17),
#  Row(Publisher='Albin Michel', Title="Tout le monde fait l'amour", diff=17),
#  Row(Publisher='Albin Michel', Title='Running man', diff=17),
#  Row(Publisher='Albin Michel', Title='Chambre Ã?Â\xa0 part', diff=17),
#  Row(Publisher='Albin Michel', Title='Joyeux NoÃ?Â«l, Merry Christmas', diff=17),
#  Row(Publisher='Albin Michel', Title='Les honneurs perdus: Roman', diff=17),
#  Row(Publisher='Albin Michel', Title='Ito ou la vengeance du samouraÃ?Â¯', diff=17),
#  Row(Publisher='Albin Michel', Title='Les allumettes suÃ?Â©doises', diff=17),
#  Row(Publisher='Albin Michel', Title='Marche ou crÃ?Â¨ve, nouvelle Ã?Â©dition', diff=17),
#  Row(Publisher='Albin Michel', Title='Le Secret', diff=17),
#  Row(Publisher='Albin Michel', Title='EncyclopÃ?Â©die du savoir relatif et absolu', diff=17),
#  Row(Publisher='Albin Michel', Title='Le nouvel art du temps broche', diff=17),
#  Row(Publisher='Albin Michel', Title='Misery', diff=17),
#  Row(Publisher='Albin Michel', Title='Mauvais frÃ?Â¨re', diff=17),
#  Row(Publisher='Albin Michel', Title='DÃ?Â©ception et autres nouvelles', diff=17),
#  Row(Publisher='Albin Michel', Title='La femme solaire', diff=17),
#  Row(Publisher='Albin Michel', Title='A bas les Ã?Â©lÃ?Â¨ves!', diff=17),
#  Row(Publisher='Albin Michel', Title='Ni vue ni connue', diff=17),
#  Row(Publisher='Albin Michel', Title="L'Ultime Secret", diff=17),
#  Row(Publisher='Albin Michel', Title='Olivier et ses amis', diff=17),
#  Row(Publisher='Albin Michel', Title='Terre somnanbule', diff=17),
#  Row(Publisher='Albin Michel', Title='Le Concile de pierre', diff=17),
#  Row(Publisher='Albin Michel', Title='Hors de moi', diff=18),
#  Row(Publisher='Albin Michel', Title="A la poursuite d'Octobre rouge", diff=18),
#  Row(Publisher='Albin Michel', Title='Initiation et sagesse des contes de fÃ?Â©es', diff=18),
#  Row(Publisher='Albin Michel', Title='Lestat le vampire', diff=18),
#  Row(Publisher='Albin Michel', Title='Dis-moi oÃ?Â¹ tu as mal : Je te dirai pourquoi', diff=18),
#  Row(Publisher='Albin Michel', Title='"Lettre ouverte d\'un ""chien\\"" Ã?Â\xa0 FranÃ?Â§ois Mitterrand au nom de la libertÃ?Â© d\'aboyer"', diff=18),
#  Row(Publisher='Albin Michel', Title='Le Cavalier du BaÃ?Â¯kal', diff=18),
#  Row(Publisher='Albin Michel', Title="L'Enfant de pierre et autres contes bouddhistes", diff=18),
#  Row(Publisher='Albin Michel', Title='TraitÃ?Â© des cinq roues : Gorin-no-sho', diff=18),
#  Row(Publisher='Albin Michel', Title="Paroles des poÃ?Â¨tes d'aujourd'hui", diff=18),
#  Row(Publisher='Albin Michel', Title="Je m'appelle toi", diff=18),
#  Row(Publisher='Albin Michel', Title="L'Empire des loups", diff=18),
#  Row(Publisher='Albin Michel', Title='Les voyages et aventures extraordinaires du frÃ?Â¨re Angelo', diff=18),
#  Row(Publisher='Albin Michel', Title='Le Mesnevi : 150 contes soufis', diff=18),
#  Row(Publisher='Albin Michel', Title='Un printemps arabe', diff=18),
#  Row(Publisher='Albin Michel', Title='Le bal du dodo', diff=18),
#  Row(Publisher='Albin Michel', Title="Comment cuisiner son mari Ã?Â\xa0 l'africaine", diff=18),
#  Row(Publisher='Albin Michel', Title='Le mystÃ?Â¨re des Maldives', diff=18),
#  Row(Publisher='Albin Michel', Title="L'homme sans douleur", diff=18),
#  Row(Publisher='Albin Michel', Title='Le Journal de Bridget Jones', diff=18),
#  Row(Publisher='Albin Michel', Title="L'HÃ?Â´tel blanc", diff=18),
#  Row(Publisher='Albin Michel', Title='Dix dodus dindons', diff=18),
#  Row(Publisher='Albin Michel', Title='La vie interdite: Roman', diff=18),
#  Row(Publisher='Albin Michel', Title="Nanny : Journal d'une baby-sitter", diff=18),
#  Row(Publisher='Albin Michel', Title='Paroles de Gourmandise', diff=18),
#  Row(Publisher='Albin Michel', Title='ContrepÃ?Â©tines', diff=18),
#  Row(Publisher='Albin Michel', Title='Contagion', diff=18),
#  Row(Publisher='Albin Michel', Title='La Vie des mots, lÃ?Â¿ami des veaux', diff=18),
#  Row(Publisher='Albin Michel', Title='Et nous nous reverrons--', diff=18),
#  Row(Publisher='Albin Michel', Title='Hotel Des Deux Mondes', diff=18),
#  Row(Publisher='Albin Michel', Title='Les Tommyknockers', diff=18),
#  Row(Publisher='Albin Michel', Title="Bridget Jones. L'Ã?Â?ge de raison", diff=18),
#  Row(Publisher='Albin Michel', Title='Flamingo', diff=18),
#  Row(Publisher='Albin Michel', Title='Charlotte Corday', diff=18),
#  Row(Publisher='Albin Michel', Title='Le Mammy big bang', diff=18),
#  Row(Publisher='Albin Michel', Title="Merlin l'Enchanteur ou l'Eternelle quÃ?Âªte magique", diff=18),
#  Row(Publisher='Albin Michel', Title='Car nous venons tous du pays de notre enfance', diff=18),
#  Row(Publisher='Albin Michel', Title='La Vie selon Gus Orviston', diff=18),
#  Row(Publisher='Albin Michel', Title='Ce soir, je veillerai sur toi', diff=18),
#  Row(Publisher='Albin Michel', Title='Un jour tu verras--', diff=18),
#  Row(Publisher='Albin Michel', Title='Les yeux du dragon', diff=18),
#  Row(Publisher='Albin Michel', Title='Ã?Â?a', diff=18),
#  Row(Publisher='Albin Michel', Title='Comment accomoder sa vie Ã?Â\xa0 la maniÃ?Â¨re zen', diff=18),
#  Row(Publisher='Albin Michel', Title='OcÃ?Â©an mer', diff=18),
#  Row(Publisher='Albin Michel', Title='Rue des Bons-Enfants', diff=18),
#  Row(Publisher='Albin Michel', Title='Bazaar', diff=18),
#  Row(Publisher='Albin Michel', Title='Dolores Claiborne', diff=18),
#  Row(Publisher='Albin Michel', Title='Douce nuit', diff=18),
#  Row(Publisher='Albin Michel', Title="Dans la rue oÃ?Â¹ vit celle que j'aime", diff=18),
#  Row(Publisher='Albin Michel', Title='Paroles indiennes', diff=18),
#  Row(Publisher='Albin Michel', Title='Assam - Prix Renaudot 2002', diff=18),
#  Row(Publisher='Albin Michel', Title='Bien frappÃ?Â©', diff=18),
#  Row(Publisher='Albin Michel', Title='Stupeur Et Tremblements', diff=18),
#  Row(Publisher='Albin Michel', Title="Cherchez l'erreur", diff=18),
#  Row(Publisher='Albin Michel', Title="Une femme et son ombre : Le Masculin et le fÃ?Â©minin dans la femme d'aujourd'hui", diff=18),
#  Row(Publisher='Albin Michel', Title='Souviens toi', diff=18),
#  Row(Publisher='Albin Michel', Title='Paroles du Japon : haÃ?Â¯kus', diff=18),
#  Row(Publisher='Albin Michel', Title='Message des hommes vrais au monde mutant', diff=18),
#  Row(Publisher='Albin Michel', Title='Le Bonheur de la femme au foyer', diff=18),
#  Row(Publisher='Albin Michel', Title='ColÃ?Â¨re', diff=18),
#  Row(Publisher='Albin Michel', Title='Une si longue nuit', diff=19),
#  Row(Publisher='Albury Publishing', Title="Shout to the Lord: Stories of God's Love and Power", diff=0),
#  Row(Publisher='Albury Publishing', Title='Gods Generals Why They Succeeded and Why', diff=2),
#  Row(Publisher='Albury Publishing', Title='R.I.O.T. Devotional: Righteous Truths That Will Invade Your Life (R. I. O. T. Devotional)', diff=2),
#  Row(Publisher='Albury Publishing', Title='Loose That Man & Let Him Go!', diff=2),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='La Carta Esferica / The Nautical Chart (Spanish edition)', diff=0),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='La piel del tambor', diff=2),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='El hombre duplicado', diff=7),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='El maestro de esgrima', diff=8),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Todos Los Nombres (Alfaguara)', diff=9),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='El Sol de Breda', diff=9),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Ensayo Sobre LA Ceguera', diff=10),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='La Caverna', diff=11),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Plenilunio', diff=11),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='El Paraiso En La Otra Esquina', diff=12),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Ã?ngeles fugaces (Falling Angels)', diff=12),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='La piel del cielo', diff=12),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Opus Nigrum', diff=12),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Cuadernos de Don Rigoberto', diff=12),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Sefarad: Una Novela De Novelas', diff=13),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Un calor tan cercano', diff=13),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Rebeldes', diff=13),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='El Cuento De LA Isla Desconocida', diff=13),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Memorias de Una Geisha', diff=13),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='El orden alfabÃ©tico', diff=14),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Tu Rostro Manana: Fiebre Y Lanza', diff=14),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='El club Dumas (ediciÃ³n en espaÃ±ol)', diff=14),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Con Animo De Ofender', diff=14),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Carlota Fainberg', diff=14),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Las Vacaciones Del Pequeno Nicolas (Osito/Little Bear)', diff=14),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Piruleta (Osito/Little Bear)', diff=14),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='El Hombre Duplicado', diff=15),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Geografias (Alfaguara Bolsillo)', diff=15),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Volando Solo', diff=15),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Club Dumas, El', diff=15),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='El Lapiz del Carpintero', diff=15),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Agu Trot [spanish edition]', diff=15),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Sandokan (Historias de Siempre)', diff=15),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Moby Dick (Spanish Language Edition)', diff=15),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='La Mancha Humana', diff=15),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Vivir la vida', diff=15),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Balsa de Piedra, La', diff=15),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='El Anfitrion', diff=15),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Un Milagro Informal', diff=15),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Cuentos Completos, Benedetti (Alfaguara Cuentos Completos)', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Ensayo Sobre LA Cerguera (Biblioteca Jose Saramago)', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Stuart Little', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Todo Un Caracter', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='El amor, las mujeres y la vida', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='El Verano De LA Linterna Magicia', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title="No Pidas Sardinas Fuera De Temporada/Don't Ask for Sardines Out of Season (Young Adults)", diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Educacion de Un Hada, La', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Que Me Quieres, Amor?', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Empresas Y Tribulaciones De Maqroll El Gaviero', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='LA Tia Julia Y El Escribidor', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Ivanhoe', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Rayuela (Biblioteca Cortazar)', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Mi siglo', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Agonia del Dragon, La', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Pobre Manolito', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Caracol Beach (en espaÃ±ol)', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Los Mejores Relatos Latinoamericanos (Juvenil Alfaguara)', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Las llamadas perdidas', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Puro Humo', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Un Tal Lucas', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Boy (Relatos De Infancia)', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='El Secreto del Hombre Muerto', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='El libro de piel de tiburÃ³n', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Ensayo Sobre La Ceguera', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Carta Esferica, La', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Reina del Sur, La', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='La travesÃ\xada', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='El Pequeno Vampiro', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Cuentos Completos/1 (Alfaguara Cuentos Completos)', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Cuentos Completos/2: Cortazar (Alfaguara Cuentos Completos)', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Las Sombras De LA Caverna', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Diablo Guardian', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='El Desorden de Tu Nombre (Alfaguara Hispanica)', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Galvez En La Frontera', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='El gran gigante bonachÃ³n', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='La novia de Matisse', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Cuentos Completos 1933-1993', diff=16),
#  Row(Publisher='Alfaguara Ediciones, S.A. (Spain)', Title='Ensayo Sobre La Lucidez', diff=16),
#  Row(Publisher='Alfaguara Infantil', Title='LA Tabla De Flandes (Alfaguara Extra)', diff=0),
#  Row(Publisher='Alfranpedoc Publishing', Title='A Family Tree, Taking Root', diff=0),
#  Row(Publisher='Alfred A. Knopf', Title='Timeline', diff=0),
#  Row(Publisher='Alfred A. Knopf', Title='Airframe', diff=3),
#  Row(Publisher='Alfred A. Knopf', Title='The Emperor of Ocean Park (Today Show Book Club #1)', diff=27),
#  Row(Publisher='Alfred A. Knopf', Title='The Little Friend', diff=36),
#  Row(Publisher='Alfred A. Knopf', Title='Memoirs of a Geisha', diff=40),
#  Row(Publisher='Alfred A. Knopf', Title="I Don't Know How She Does It: The Life of Kate Reddy, Working Mother", diff=41),
#  Row(Publisher='Alfred A. Knopf', Title='The Lost World: A Novel', diff=45),
#  Row(Publisher='Alfred A. Knopf', Title='Paradise', diff=46),
#  Row(Publisher='Alfred A. Knopf', Title='Balzac and the Little Chinese Seamstress', diff=48),
#  Row(Publisher='Alfred A. Knopf', Title='Lasher', diff=56),
#  Row(Publisher='Alfred A. Knopf', Title='Merrick (Vampire Chronicles)', diff=58),
#  Row(Publisher='Alfred A. Knopf', Title='The Tale of the Body Thief (Vampire Chronicles)', diff=61),
#  Row(Publisher='Alfred A. Knopf', Title='Disclosure', diff=65),
#  Row(Publisher='Alfred A. Knopf', Title="In the Kitchen With Rosie: Oprah's Favorite Recipes", diff=66),
#  Row(Publisher='Alfred A. Knopf', Title='Vittorio the Vampire: New Tales of the Vampires', diff=68),
#  Row(Publisher='Alfred A. Knopf', Title='Taltos: Lives of the Mayfair Witches', diff=70),
#  Row(Publisher='Alfred A. Knopf', Title='Plainsong', diff=71),
#  Row(Publisher='Alfred A. Knopf', Title='Servant of the Bones', diff=74),
#  Row(Publisher='Alfred A. Knopf', Title='Violin', diff=75),
#  Row(Publisher='Alfred A. Knopf', Title='The White', diff=77),
#  Row(Publisher='Alfred A. Knopf', Title='Blood and Gold (Vampire Chronicles)', diff=78),
#  Row(Publisher='Alfred A. Knopf', Title='Sick Puppy', diff=79),
#  Row(Publisher='Alfred A. Knopf', Title='The Subtle Knife (His Dark Materials, Book 2)', diff=81),
#  Row(Publisher='Alfred A. Knopf', Title='The Prophet', diff=82),
#  Row(Publisher='Alfred A. Knopf', Title="Eight Weeks to Optimum Health: A Proven Program for Taking Full Advantage of Your Body's Natural Healing Power (Proven Program for Taking Full Advantage of Your Body's Natural Healing Power)", diff=83),
#  Row(Publisher='Alfred A. Knopf', Title='Queen of the Damned (Vampire Chronicles, Book III)', diff=84),
#  Row(Publisher='Alfred A. Knopf', Title='The Vampire Armand : The Vampire Chronicles (Rice, Anne, Vampire Chronicles)', diff=86),
#  Row(Publisher='Alfred A. Knopf', Title='Dark Lady', diff=87),
#  Row(Publisher='Alfred A. Knopf', Title='The Piano Tuner', diff=87),
#  Row(Publisher='Alfred A. Knopf', Title='Blackwood Farm (The Vampire Chronicles)', diff=90),
#  Row(Publisher='Alfred A. Knopf', Title='All the Pretty Horses (Border Trilogy, Vol 1)', diff=91),
#  Row(Publisher='Alfred A. Knopf', Title='The Amber Spyglass (His Dark Materials, Book 3)', diff=93),
#  Row(Publisher='Alfred A. Knopf', Title='Chasing Cezanne', diff=94),
#  Row(Publisher='Alfred A. Knopf', Title='Personal History', diff=94),
#  Row(Publisher='Alfred A. Knopf', Title='When We Were Orphans', diff=96),
#  Row(Publisher='Alfred A. Knopf', Title='Russia House', diff=96),
#  Row(Publisher='Alfred A. Knopf', Title='A Certain Justice (Adam Dalgliesh Mysteries (Hardcover))', diff=96),
#  Row(Publisher='Alfred A. Knopf', Title='The Night Manager', diff=98),
#  Row(Publisher='Alfred A. Knopf', Title='The Final Judgement', diff=99),
#  Row(Publisher='Alfred A. Knopf', Title='Stormy Weather', diff=103),
#  Row(Publisher='Alfred A. Knopf', Title='Anything Considered', diff=103),
#  Row(Publisher='Alfred A. Knopf', Title='Caramelo', diff=103),
#  Row(Publisher='Alfred A. Knopf', Title='Rising Sun', diff=104),
#  Row(Publisher='Alfred A. Knopf', Title='The Family Orchard: A Novel', diff=105),
#  Row(Publisher='Alfred A. Knopf', Title='The House of the Spirits', diff=105),
#  Row(Publisher='Alfred A. Knopf', Title='Secrets of the Flesh: A Life of Colette', diff=105),
#  Row(Publisher='Alfred A. Knopf', Title='The Tailor of Panama', diff=106),
#  Row(Publisher='Alfred A. Knopf', Title='Lying Awake', diff=106),
#  Row(Publisher='Alfred A. Knopf', Title="Spontaneous Healing: How to Discover and Enhance Your Body's Natural Ability to Maintain and Heal Itself", diff=107),
#  Row(Publisher='Alfred A. Knopf', Title="A Dog's Life", diff=107),
#  Row(Publisher='Alfred A. Knopf', Title='Flipped', diff=108),
#  Row(Publisher='Alfred A. Knopf', Title='Being Digital', diff=109),
#  Row(Publisher='Alfred A. Knopf', Title='Hotel Pastis: A Novel of Provence', diff=109),
#  Row(Publisher='Alfred A. Knopf', Title='Witches of Eastwick', diff=109),
#  Row(Publisher='Alfred A. Knopf', Title='The Crossing (Border Trilogy, Vol 2)', diff=109),
#  Row(Publisher='Alfred A. Knopf', Title='Cities of the Plain : A Novel (Border Trilogy, V. 3.)', diff=110),
#  Row(Publisher='Alfred A. Knopf', Title='Everyone Is Entitled to My Opinion', diff=110),
#  Row(Publisher='Alfred A. Knopf', Title='Encore Provence', diff=110),
#  Row(Publisher='Alfred A. Knopf', Title='True History of the Kelly Gang', diff=110),
#  Row(Publisher='Alfred A. Knopf', Title='American Rhapsody', diff=111),
#  Row(Publisher='Alfred A. Knopf', Title='In the Cut: A Novel', diff=111),
#  Row(Publisher='Alfred A. Knopf', Title='The Fatal Shore', diff=111),
#  Row(Publisher='Alfred A. Knopf', Title="How We Die: Reflections on Life's Final Chapter", diff=111),
#  Row(Publisher='Alfred A. Knopf', Title='The Cold Six Thousand: A Novel', diff=111),
#  Row(Publisher='Alfred A. Knopf', Title='Family Matters', diff=112),
#  Row(Publisher='Alfred A. Knopf', Title='Gertrude and Claudius', diff=112),
#  Row(Publisher='Alfred A. Knopf', Title='A Fine Balance', diff=112),
#  Row(Publisher='Alfred A. Knopf', Title='Bare: On Women, Dancing, Sex, and Power', diff=113),
#  Row(Publisher='Alfred A. Knopf', Title="Ava's Man", diff=113),
#  Row(Publisher='Alfred A. Knopf', Title='Uncle Tungsten: Memories of a Chemical Boyhood', diff=113),
#  Row(Publisher='Alfred A. Knopf', Title='S.', diff=113),
#  Row(Publisher='Alfred A. Knopf', Title='The Powerbook', diff=113),
#  Row(Publisher='Alfred A. Knopf', Title='A Thousand Acres', diff=113),
#  Row(Publisher='Alfred A. Knopf', Title='The Book on the Bookshelf', diff=113),
#  Row(Publisher='Alfred A. Knopf', Title='Evening', diff=113),
#  Row(Publisher='Alfred A. Knopf', Title='Push', diff=114),
#  Row(Publisher='Alfred A. Knopf', Title='MotherKind', diff=114),
#  Row(Publisher='Alfred A. Knopf', Title='The Wind-Up Bird Chronicle', diff=114),
#  Row(Publisher='Alfred A. Knopf', Title='A Year in Provence', diff=115),
#  Row(Publisher='Alfred A. Knopf', Title='Good Morning, Killer', diff=115),
#  Row(Publisher='Alfred A. Knopf', Title='A Lesson Before Dying', diff=115),
#  Row(Publisher='Alfred A. Knopf', Title='Pobby and Dingan', diff=115),
#  Row(Publisher='Alfred A. Knopf', Title='Rabbit Is Rich', diff=116),
#  Row(Publisher='Alfred A. Knopf', Title='National Audubon Society Field Guide to North American Birds: Eastern Region', diff=116),
#  Row(Publisher='Alfred A. Knopf', Title='The Good People of New York', diff=116),
#  Row(Publisher='Alfred A. Knopf', Title="James and the Giant Peach: A Children's Story", diff=116),
#  Row(Publisher='Alfred A. Knopf', Title='Dinner at the Homesick Restaurant', diff=116),
#  Row(Publisher='Alfred A. Knopf', Title='The New Yorker Book of Dog Cartoons', diff=116),
#  Row(Publisher='Alfred A. Knopf', Title='How Can I Help: Stories and Reflections on Service', diff=116),
#  Row(Publisher='Alfred A. Knopf', Title='The Terminal Man', diff=117),
#  Row(Publisher='Alfred A. Knopf', Title='Tales from Watership Down', diff=117),
#  Row(Publisher='Alfred A. Knopf', Title='Toward the End of Time', diff=117),
#  Row(Publisher='Alfred A. Knopf', Title='For the Relief of Unbearable Urges', diff=117),
#  Row(Publisher='Alfred A. Knopf', Title='After the Quake: Stories', diff=117),
#  Row(Publisher='Alfred A. Knopf', Title="The Biographer's Tale", diff=117),
#  Row(Publisher='Alfred A. Knopf', Title='My Name Is Red', diff=117),
#  Row(Publisher='Alfred A. Knopf', Title='Living a Life That Matters: Resolving the Conflict Between Conscience and Success', diff=117),
#  Row(Publisher='Alfred A. Knopf', Title='Unto the Sons', diff=117),
#  Row(Publisher='Alfred A. Knopf', Title='Teresa of Avila: The Progress of a Soul', diff=117),
#  Row(Publisher='Alfred A. Knopf', Title='Mortals: A Novel', diff=117),
#  Row(Publisher='Alfred A. Knopf', Title='French Lessons: Adventures with Knife, Fork, and Corkscrew', diff=117),
#  Row(Publisher='Alfred A. Knopf', Title='The Girls: A Novel', diff=117),
#  Row(Publisher='Alfred A. Knopf', Title='Pain Management: A Burke Novel', diff=117),
#  Row(Publisher='Alfred A. Knopf', Title='You and Your Aquarium', diff=117),
#  Row(Publisher='Alfred A. Knopf', Title='The Informers', diff=117),
#  Row(Publisher='Alfred A. Knopf', Title='The Chocolate War', diff=117),
#  Row(Publisher='Alfred A. Knopf', Title='The Wonder Worker', diff=117),
#  Row(Publisher='Alfred A. Knopf', Title='National Audubon Society Field Guide to North American Wildflowers: Eastern Region (Audubon Society Field Guide)', diff=117),
#  Row(Publisher='Alfred A. Knopf', Title='The Love of a Good Woman: Stories', diff=117),
#  Row(Publisher='Alfred A. Knopf', Title='The First Man', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='Love, Etc.', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='Licks of Love: Short Stories and a Sequel, Rabbit Remembered', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='Day of the Bees', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='Toujours Provence', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='Charlie and the Great Glass Elevator: The Further Adventures of Charlie Bucket and Willy Wonka, Chocolate-Maker Extraordinary', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='The Man Who Ate Everything: And Other Gastronomic Feats, Disputes and Pleasurable Pursuits', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='The Elementary Particles', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='Fugitive Pieces', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='Yeats Is Dead! A Mystery by 15 Irish Writers', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='Rocks and Minerals (Eyewitness Books)', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='Now', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='Schmidt Delivered', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='Mystery Ride', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='Prophet (Kahlil Gibran Pocket Library Series)', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='Light Action in the Caribbean: Stories', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='Night Crossing', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='The High Flyer: A Novel', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='In the Beauty of the Lilies', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='True North: A Memoir', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='The Healthy Kitchen: Recipes for a Better Body, Life, and Spirit', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='The Book of Revelation', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='A Trial by Jury', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='Sort of Forever', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='Charlie and the Chocolate Factory', diff=118),
#  Row(Publisher='Alfred A. Knopf', Title='Caramelo (Today Show Book Club #9)', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='The Northern Lights: The True Story of the Man Who Unlocked the Secrets of the Aurora Borealis', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='The House on Mango Street', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='The Boomer', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='The House of Sleep', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='Ladysmith', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='Two Good Friends', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='The grass sister', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title="The Endurance: Shackleton's Legendary Antarctic Expedition", diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='Gut Symmetries', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='The Quick and the Dead', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='Dogwalker: Stories', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='Key West Tales', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='Your Baby and Child from Birth to Age Five', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='National Audubon Society Field Guide to North American Butterflies (Audubon Society Field Guide)', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title="Catch-22 (Everyman's Library (Cloth))", diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='The Tiny One', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='The Sibley Guide to Birds', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='No Shame in My Game: The Working Poor in the Inner City', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='Lost World', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='Thriving on Chaos: Handbook for a Management Revolution', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='Beard on Pasta', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title="Julia's Kitchen Wisdom: Essential Techniques and Recipes from a Lifetime of Cooking", diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='Beyond Freedom and Dignity', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='E-Mail This Book!', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='Old Men at Midnight', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='National Audubon Society Field Guide to North American Insects and Spiders (Audubon Society Field Guide)', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='California Fire and Life', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='The New Yorker Book of Doctor Cartoons and Psychiatrist', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='Birds of America: Stories', diff=119),
#  Row(Publisher='Alfred A. Knopf', Title='The Prairie Train', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Eyewitness Books : Sports', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title="Flaubert's Parrot", diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Cinderella & Company: Backstage at the Opera With Cecilia Bartoli', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Hey, Cowboy!', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='In My Hands: Memories of a Holocaust Rescuer', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Song and Dance Man', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title="Temperament: The Idea That Solved Music's Greatest Riddle", diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Shroud', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Berlin Game', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='A Regular Guy', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='The Puttermesser Papers', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='The Snow Goose', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='The Ash Garden: A Novel', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Visible Spirits', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='The Remains of the Day', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Black Leopard', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='The Farewell Symphony: A Novel', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Chic Simple: Scarves (Chic Simple Components)', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Where Is the Mango Princess?', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='The World of Charles Addams', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='The Gold Cell (Knopf Poetry Series)', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Buddies', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Jane Austen: A Life', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Dreaming in Cuban', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Lewis & Clark: The Journey of the Corps of Discovery: An Illustrated History', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Without Blood', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='The Evolution of Useful Things', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='For the Time Being', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Unspeakable Acts, Ordinary People: The Dynamics of Torture', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Dead and Gone (Burke Novels)', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Costume (Eyewitness Books)', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title="The Circle of Innovation: You Can't Shrink Your Way to Greatness", diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Off Camera: Private Thoughts Made Public', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Looking for Lovedu: Days and Nights in Africa', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Amazing Poisonous Animals (Eyewitness Junior)', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Dear Mr. Sprouts', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Archeology (Eyewitness Books)', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Cruising Paradise: Tales', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Full Moon', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Jesus the Son of Man: His Words and His Deeds As Told and Recorded by Those Who Knew Him (Kahlil Gibran Pocket Library)', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Peter and the Wolf: A Musical Fairy Tale by Sergei Prokofiev', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='The Gates of the Alamo', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title="A Woman's Education", diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Nobrow: The Culture of Marketing-The Marketing of Culture', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Snow Mountain Passage', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Masters of Death: The SS-Einsatzgruppen and the Invention of the Holocaust', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='A Field Guide to American Houses', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='The Gate', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='"The Professional Service Firm50: Or, Fifty Ways to Transform Your ""Department\\"" into a Professional Service Firm Whose Trademarks Are Passion and Innovation (Reinventing Work)"', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='The Country Under My Skin: A Memoir of Love and War', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Learned Optimism', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Run', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Rabbit at Rest', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Be the One', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Bird (Eyewitness Books)', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Skeleton (Eyewitness Books)', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='For Common Things: Irony, Trust, and Commitment in America Today', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title="Michael Crichton's Jurassic World", diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='The Married Man', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Samuel Pepys: The Unequalled Self', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='My Dark Places: An L.A. Crime Memoir', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Meditations from a Movable Chair: Essays', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Victory Garden Cookbook', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title="Tristram Shandy (Everyman's Library Series)", diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Master of the Senate: The Years of Lyndon Johnson', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='National Audubon Society Field Guide to the Night Sky (Audubon Society Field Guide Series)', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='Seashore (Eyewitness Books)', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='The Last Thing He Wanted', diff=120),
#  Row(Publisher='Alfred A. Knopf', Title='A Distant Mirror: The Calamitous 14th Century', diff=121),
#  Row(Publisher='Alfred A. Knopf', Title='The Complete Walker IV', diff=121),
#  Row(Publisher='Alfred A. Knopf', Title="Men's Wardrobe (Chic Simple)", diff=121),
#  Row(Publisher='Alfred A. Knopf', Title="Of Time and Memory: A Mother's Story", diff=121),
#  Row(Publisher='Alfred A. Knopf', Title='King Hereafter: A Novel', diff=121),
#  Row(Publisher='Alfred A. Knopf', Title='Swimming Toward the Ocean', diff=121),
#  Row(Publisher='Alfred A. Knopf', Title="Persuasion (Everyman's Library (Cloth))", diff=121),
#  Row(Publisher='Alfred A. Knopf', Title='Any Human Heart', diff=121),
#  Row(Publisher='Alfred A. Knopf', Title="Nobody's Perfect: Selected Writings from the New Yorker", diff=121),
#  Row(Publisher='Alfred A. Knopf', Title="In Pharaoh's Army: Memories of the Lost War", diff=121),
#  Row(Publisher='Alfred A. Knopf', Title='Life Estates: A Novel', diff=121),
#  Row(Publisher='Alfred A. Knopf', Title='Great Dream of Heaven: Stories', diff=121),
#  Row(Publisher='Alfred A. Knopf', Title='Bech Is Back', diff=121),
#  Row(Publisher='Alfred A. Knopf', Title='Frederick', diff=121),
# ...
#  Row(Publisher='Alfred A. Knopf', Title='Shabanu: Daughter of the Wind', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Elephant Vanishes: Stories', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Mortals', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Egg Code: A Novel', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='A Small Tall Tale from the Far Far North', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Pure Dead Wicked', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Familiar Animal Tracks (The Audubon Society Pocket Guides)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Jacob Two-Two Meets the Hooded Fang', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Soros: The Life and Times of a Messianic Billionaire', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Dinosaur (Eyewitness Books)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title="The Mermaid's Purse", diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Museum Pieces', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Midnight Train Home', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title="The Mayor of Casterbridge (Everyman's Library Series)", diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Film (Eyewitness Books)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Marry Me: A Romance', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Flag (Eyewitness Books)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Wonders of the Invisible World: Stories', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Shake My Sillies Out: Bert Simpson and Bonnie Simpson (Raffi Songs to Read (Hardcover))', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Pond and River (Eyewitness Books)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Imps, Demons, Hobgoblins, Witches, Fairies and Elves', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Dreams of Mairhe Mehan', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='To Lie With Lions (The House of Niccolo, 6)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='After the War', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title="Alexis Lichine's Guide to the Wines and Vineyards of France", diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Pieces from Berlin', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Death in Holy Orders', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='As Max Saw It', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Just Friends', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Gates of November: Chronicles of the Slepak Family', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Seventh Child: A Lucky Life', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Bury Me Standing: The Gypsies and Their Journey', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Amazing Bats (Eyewitness Juniors, No 13)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Memory Book of Starr Faithfull: A Novel', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Complete Manual of Woodworking', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Petunia, Beware', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Liberation Management: Necessary Disorganization for the Nanosecond Nineties', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title="Anna Karenina (Everyman's Library (Cloth))", diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Tuff', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Familiar Flowers of North America: Eastern Region (The Audubon Society Pocket Guides)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Amazing Animal Disguises (Eyewitness Juniors)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='World and Other Places', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Getting a Life: Stories', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Johannes Brahms: A Biography', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Learn Photography in a Weekend (Learn in a Weekend Series)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Dark Valley: A Panorama of the 1930s', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title="Hitler's Willing Executioners: Ordinary Germans and the Holocaust", diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Bech at Bay: A Quasi-Novel', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Clouds and Storms (National Audubon Society Pocket Guides)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Love Thy Neighbor: A Story of War', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='No More Magic', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='False Allegations', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title="Sibley's Birding Basics", diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Your Baby and Child: From Birth to Age Five', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Knopf Guide Athens (Knopf Guides)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Why Things Bite Back: Technology and the Revenge of Unintended Consequences', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Selected Letters of Marianne Moore', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Coming Conflict With China', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Right Hand of Sleep', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title="Who's Irish?", diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Diamond Mask: A Novel (Galactic Milieu Trilogy, Book 2)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Mythology (Eyewitness Books (Trade))', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Populuxe', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Amazing Armored Animals (Eyewitness Juniors)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title="I'll Always Love You", diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Mapmakers', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Monstruary', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title="Sleeping Beauty (Everyman's Library Children's Classics)", diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The High Window', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Age of Homespun: Objects and Stories in the Creation of an American Myth', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='American Visions: The Epic History of Art in America', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title="What's Hatching Out of That Egg?", diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Toward Commitment: A Dialogue About Marriage', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Dancing After Hours: Stories', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title="Horatio's Drive: America's First Road Trip", diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Greek Fire: The Story of Maria Callas and Aristotle Onassis', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='"In The Devil""s Snare History of Witchcraft"', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Knots in My Yo-Yo String: The Autobiography of a Kid', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='American Sphinx: The Character of Thomas Jefferson', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='A History of the Breast', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Hotel Paradise', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title="Roald Dahl's Revolting Rhymes", diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Poems of Peter Davison, 1957-1995', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title="A Midwife's Tale: The Life of Martha Ballard, Based on Her Diary, 1785-1812", diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Amazing Beetles (Eyewitness Juniors)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='National Audubon Society Guide to Marine Mammals of the World (National Audubon Society Field Guide Series.)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Familiar Birds of North America: Western Region (The Audubon Society Pocket Guides)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Indelible Acts: Stories', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Mr Ape', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Building', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Books: From Writer to Reader', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Africa (Eyewitness Books)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The New Vegetarian Epicure, Plain and Fancy: Menus for Family & Friends.', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Beard on Bread', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Oh, Freedom!: Kids Talk About the Civil Rights Movement With the People Who Made It Happen', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Dinosaurs (Audubon Society Pocket Guides)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title="From Julia Child's Kitchen", diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Open Secrets: Stories', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Not One of the Boys: Living Life As a Feminist', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Technopoly: The Surrender of Culture to Technology', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title="The Eustace Diamonds (Everyman's Library, No. 104)", diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Book of Jewish Food: An Odyssey from Samarkand to New York', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Volcano & Earthquake (Eyewitness Books, No 38)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Familiar Heat: A Novel', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title="Populuxe/the Look and Life of America in the '50s and '60S, from Tailfins and TV Dinners to Barbie Dolls and Fallout Shelters", diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='So Long, See You Tomorrow', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Complete Guide to Collecting Art', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Moviegoer', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Mother, Mother, I Want Another', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='This Crazy Thing Called Love: The Golden World and Fatal Marriage of Ann and Billy Woodward', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='When Harry Met Sally', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Judges: A Novel', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Spring-Heeled Jack', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Dreamer : A Novel', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Close Encounters of the Fourth Kind: Alien Abduction, Ufos, and the Conference at M.I.T.', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Music (Eyewitness Books)', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Jesus, Son of Man', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Engineers of Dreams: Great Bridge Builders and the Spanning of America', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Mirrorstone', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title="Marmalade's Snowy Day", diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Foods and Wines of Spain', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Genes, Girls, and Gamow: After the Double Helix', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='My Many Colored Days', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Sibley Field Guide to Birds of Eastern North America', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Thomas Mann: Eros and Literature', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='Sweet Clara and the Freedom Quilt', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Nature of Blood', diff=122),
#  Row(Publisher='Alfred A. Knopf', Title='The Houdini Box', diff=122),
#  Row(Publisher='Allan', Title='Warships of World War II', diff=0),
#  Row(Publisher='Allen & Unwin Pty Ltd', Title='The sunken road', diff=0),
#  Row(Publisher="Allen & Unwin children's books", Title='The Baboon King (Ark Fiction)', diff=0),
#  Row(Publisher="Allen & Unwin children's books", Title='The Quicksand Pony (A Little Ark Book)', diff=0),
#  Row(Publisher='Allia', Title='"Une apologie des oisifs, suivi de ""causerie et causeurs\\"""', diff=0),
#  Row(Publisher='Allia', Title='Le droit Ã?Â\xa0 la paresse', diff=0),
#  Row(Publisher='Allia', Title='De la bÃ?Âªtise', diff=0),
#  Row(Publisher='Allia', Title='JÃ?Â©sus-Christ rastaquouÃ?Â¨re', diff=0),
#  Row(Publisher='Allia', Title='Le Paresseux', diff=0),
#  Row(Publisher='Allia', Title='Lipstick traces', diff=0),
#  Row(Publisher='Allia', Title='Livre et typographie', diff=0),
#  Row(Publisher='Alliance for Committed Civic Engagement & Social Solutions (ACCESS)', Title='Savoring Seattle', diff=0),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Knitting & Crocheting", diff=0),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to the Perfect Wedding (Serial)", diff=2),
#  Row(Publisher='Alpha Books', Title="Complete Idiot's Guide to Wicca and Witchcraft", diff=3),
#  Row(Publisher='Alpha Books', Title="Complete Idiot's Guide to Urban Legends", diff=5),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Understanding Buddhism", diff=5),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Yoga (Complete Idiot's Guide to...)", diff=5),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Quilting (Complete Idiot's Guide to)", diff=5),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to the Perfect Wedding (Complete Idiot's Guide to...)", diff=5),
#  Row(Publisher='Alpha Books', Title='Mistresses of Mayhem: The Book of Women Criminals', diff=6),
#  Row(Publisher='Alpha Books', Title="Complete Idiot's Guide to Fitness", diff=6),
#  Row(Publisher='Alpha Books', Title="Complete Idiot's Guide to Spirituality for Teens", diff=6),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Feng Shui", diff=6),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Decoding Your Genes", diff=6),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide(R) to Scrapbooking", diff=6),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide(R) to World Religions (2nd Edition)", diff=6),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to a Healthy Relationship", diff=6),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Chess", diff=6),
#  Row(Publisher='Alpha Books', Title='The Zen of Organizing', diff=7),
#  Row(Publisher='Alpha Books', Title="The Pocket Idiot's Guide to Buddhism", diff=7),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Beagles", diff=7),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Creative Writing (Complete Idiot's Guide to)", diff=7),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Understanding Judaism", diff=7),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Organizing Your Life (Complete Idiots Guide)", diff=7),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Astrology (2nd Edition)", diff=7),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Dating (2nd Edition)", diff=7),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Genealogy (Complete Idiot's Guide to...)", diff=7),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Middle East Conflict", diff=7),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Philosophy (2nd Edition)", diff=7),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to the Civil War (Complete Idiot's Guides)", diff=7),
#  Row(Publisher='Alpha Books', Title='Power Over Panic (2nd Edition)', diff=7),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Twentieth Century History", diff=7),
#  Row(Publisher='Alpha Books', Title="The Complete Idiot's Guide to Classical Music", diff=7),
#  ...]

# %%
join.filter("Rating > 0").groupBy("UserId").agg(F.count("ISBN").alias("BookCount")).filter("BookCount >= 1").count()
# Out:
# 77805

# %%
data.groupBy("UserId").agg(F.count("ISBN").alias("BookCount")).filter("BookCount >= 1").count()
# Out:
# 105283

# %%
data.filter("Rating > 0").groupBy("UserId").agg(F.count("ISBN").alias("BookCount")).orderBy("BookCount", ascending=False).collect()
# Out:
# [Row(UserId=463, BookCount=1),
#  Row(UserId=15790, BookCount=1),
#  Row(UserId=29228, BookCount=1),
#  Row(UserId=211126, BookCount=1),
#  Row(UserId=227501, BookCount=1),
#  Row(UserId=237504, BookCount=1),
#  Row(UserId=218049, BookCount=1),
#  Row(UserId=82672, BookCount=1),
#  Row(UserId=90461, BookCount=1),
#  Row(UserId=45307, BookCount=1),
#  Row(UserId=37251, BookCount=1),
#  Row(UserId=36355, BookCount=1),
#  Row(UserId=199976, BookCount=1),
#  Row(UserId=203504, BookCount=1),
#  Row(UserId=252036, BookCount=1),
#  Row(UserId=265539, BookCount=1),
#  Row(UserId=246944, BookCount=1),
#  Row(UserId=253457, BookCount=1),
#  Row(UserId=245857, BookCount=1),
#  Row(UserId=243392, BookCount=1),
#  Row(UserId=276652, BookCount=1),
#  Row(UserId=144414, BookCount=1),
#  Row(UserId=33855, BookCount=1),
#  Row(UserId=14876, BookCount=1),
#  Row(UserId=212128, BookCount=1),
#  Row(UserId=230550, BookCount=1),
#  Row(UserId=210285, BookCount=1),
#  Row(UserId=209992, BookCount=1),
#  Row(UserId=78766, BookCount=1),
#  Row(UserId=99899, BookCount=1),
#  Row(UserId=34275, BookCount=1),
#  Row(UserId=66077, BookCount=1),
#  Row(UserId=201125, BookCount=1),
#  Row(UserId=182890, BookCount=1),
#  Row(UserId=203956, BookCount=1),
#  Row(UserId=260010, BookCount=1),
#  Row(UserId=276224, BookCount=1),
#  Row(UserId=270942, BookCount=1),
#  Row(UserId=265587, BookCount=1),
#  Row(UserId=269826, BookCount=1),
#  Row(UserId=265780, BookCount=1),
#  Row(UserId=121663, BookCount=1),
#  Row(UserId=128730, BookCount=1),
#  Row(UserId=156192, BookCount=1),
#  Row(UserId=152108, BookCount=1),
#  Row(UserId=145169, BookCount=1),
#  Row(UserId=169903, BookCount=1),
#  Row(UserId=148720, BookCount=1),
#  Row(UserId=8257, BookCount=1),
#  Row(UserId=23144, BookCount=1),
#  Row(UserId=14837, BookCount=1),
#  Row(UserId=276997, BookCount=1),
#  Row(UserId=1270, BookCount=1),
#  Row(UserId=213731, BookCount=1),
#  Row(UserId=95707, BookCount=1),
#  Row(UserId=82516, BookCount=1),
#  Row(UserId=98521, BookCount=1),
#  Row(UserId=89461, BookCount=1),
#  Row(UserId=37006, BookCount=1),
#  Row(UserId=63152, BookCount=1),
#  Row(UserId=43370, BookCount=1),
#  Row(UserId=181689, BookCount=1),
#  Row(UserId=199003, BookCount=1),
#  Row(UserId=248360, BookCount=1),
#  Row(UserId=242758, BookCount=1),
#  Row(UserId=248067, BookCount=1),
#  Row(UserId=139255, BookCount=1),
#  Row(UserId=159433, BookCount=1),
#  Row(UserId=174247, BookCount=1),
#  Row(UserId=150793, BookCount=1),
#  Row(UserId=21938, BookCount=1),
#  Row(UserId=19161, BookCount=1),
#  Row(UserId=29305, BookCount=1),
#  Row(UserId=227792, BookCount=1),
#  Row(UserId=217887, BookCount=1),
#  Row(UserId=237172, BookCount=1),
#  Row(UserId=72145, BookCount=1),
#  Row(UserId=80669, BookCount=1),
#  Row(UserId=91653, BookCount=1),
#  Row(UserId=104610, BookCount=1),
#  Row(UserId=90873, BookCount=1),
#  Row(UserId=55669, BookCount=1),
#  Row(UserId=178014, BookCount=1),
#  Row(UserId=199732, BookCount=1),
#  Row(UserId=207183, BookCount=1),
#  Row(UserId=181507, BookCount=1),
#  Row(UserId=275892, BookCount=1),
#  Row(UserId=245020, BookCount=1),
#  Row(UserId=263692, BookCount=1),
#  Row(UserId=118939, BookCount=1),
#  Row(UserId=131318, BookCount=1),
#  Row(UserId=113617, BookCount=1),
#  Row(UserId=107308, BookCount=1),
#  Row(UserId=7576, BookCount=1),
#  Row(UserId=21978, BookCount=1),
#  Row(UserId=22064, BookCount=1),
#  Row(UserId=216429, BookCount=1),
#  Row(UserId=73566, BookCount=1),
#  Row(UserId=79378, BookCount=1),
#  Row(UserId=104137, BookCount=1),
#  Row(UserId=82889, BookCount=1),
#  Row(UserId=95453, BookCount=1),
#  Row(UserId=47434, BookCount=1),
#  Row(UserId=36533, BookCount=1),
#  Row(UserId=39357, BookCount=1),
#  Row(UserId=54932, BookCount=1),
#  Row(UserId=65602, BookCount=1),
#  Row(UserId=38138, BookCount=1),
#  Row(UserId=44807, BookCount=1),
#  Row(UserId=69329, BookCount=1),
#  Row(UserId=39832, BookCount=1),
#  Row(UserId=185607, BookCount=1),
#  Row(UserId=182205, BookCount=1),
#  Row(UserId=243147, BookCount=1),
#  Row(UserId=268062, BookCount=1),
#  Row(UserId=268507, BookCount=1),
#  Row(UserId=274023, BookCount=1),
#  Row(UserId=264679, BookCount=1),
#  Row(UserId=133787, BookCount=1),
#  Row(UserId=142294, BookCount=1),
#  Row(UserId=157143, BookCount=1),
#  Row(UserId=24407, BookCount=1),
#  Row(UserId=12694, BookCount=1),
#  Row(UserId=235400, BookCount=1),
#  Row(UserId=220212, BookCount=1),
#  Row(UserId=229831, BookCount=1),
#  Row(UserId=84331, BookCount=1),
#  Row(UserId=74303, BookCount=1),
#  Row(UserId=34098, BookCount=1),
#  Row(UserId=189014, BookCount=1),
#  Row(UserId=200102, BookCount=1),
#  Row(UserId=270784, BookCount=1),
#  Row(UserId=273365, BookCount=1),
#  Row(UserId=245982, BookCount=1),
#  Row(UserId=169529, BookCount=1),
#  Row(UserId=164157, BookCount=1),
#  Row(UserId=4396, BookCount=1),
#  Row(UserId=277783, BookCount=1),
#  Row(UserId=15584, BookCount=1),
#  Row(UserId=233038, BookCount=1),
#  Row(UserId=220324, BookCount=1),
#  Row(UserId=227354, BookCount=1),
#  Row(UserId=230305, BookCount=1),
#  Row(UserId=94243, BookCount=1),
#  Row(UserId=105922, BookCount=1),
#  Row(UserId=106053, BookCount=1),
#  Row(UserId=72655, BookCount=1),
#  Row(UserId=49202, BookCount=1),
#  Row(UserId=36733, BookCount=1),
#  Row(UserId=58913, BookCount=1),
#  Row(UserId=37379, BookCount=1),
#  Row(UserId=55840, BookCount=1),
#  Row(UserId=58985, BookCount=1),
#  Row(UserId=37162, BookCount=1),
#  Row(UserId=183202, BookCount=1),
#  Row(UserId=197723, BookCount=1),
#  Row(UserId=192859, BookCount=1),
#  Row(UserId=185774, BookCount=1),
#  Row(UserId=243289, BookCount=1),
#  Row(UserId=269485, BookCount=1),
#  Row(UserId=118684, BookCount=1),
#  Row(UserId=149691, BookCount=1),
#  Row(UserId=19686, BookCount=1),
#  Row(UserId=31829, BookCount=1),
#  Row(UserId=213072, BookCount=1),
#  Row(UserId=87034, BookCount=1),
#  Row(UserId=53344, BookCount=1),
#  Row(UserId=48804, BookCount=1),
#  Row(UserId=202917, BookCount=1),
#  Row(UserId=185633, BookCount=1),
#  Row(UserId=178686, BookCount=1),
#  Row(UserId=181610, BookCount=1),
#  Row(UserId=195528, BookCount=1),
#  Row(UserId=242453, BookCount=1),
#  Row(UserId=106709, BookCount=1),
#  Row(UserId=165524, BookCount=1),
#  Row(UserId=162656, BookCount=1),
#  Row(UserId=171340, BookCount=1),
#  Row(UserId=21682, BookCount=1),
#  Row(UserId=24509, BookCount=1),
#  Row(UserId=277895, BookCount=1),
#  Row(UserId=17774, BookCount=1),
#  Row(UserId=241193, BookCount=1),
#  Row(UserId=240987, BookCount=1),
#  Row(UserId=225260, BookCount=1),
#  Row(UserId=231234, BookCount=1),
#  Row(UserId=88227, BookCount=1),
#  Row(UserId=62203, BookCount=1),
#  Row(UserId=35408, BookCount=1),
#  Row(UserId=47989, BookCount=1),
#  Row(UserId=183854, BookCount=1),
#  Row(UserId=200761, BookCount=1),
#  Row(UserId=197706, BookCount=1),
#  Row(UserId=175577, BookCount=1),
#  Row(UserId=176808, BookCount=1),
#  Row(UserId=179099, BookCount=1),
#  Row(UserId=270709, BookCount=1),
#  Row(UserId=121797, BookCount=1),
#  Row(UserId=122826, BookCount=1),
#  Row(UserId=125700, BookCount=1),
#  Row(UserId=154265, BookCount=1),
#  Row(UserId=142133, BookCount=1),
#  Row(UserId=150188, BookCount=1),
#  Row(UserId=148104, BookCount=1),
#  Row(UserId=13494, BookCount=1),
#  Row(UserId=11609, BookCount=1),
#  Row(UserId=234092, BookCount=1),
#  Row(UserId=85922, BookCount=1),
#  Row(UserId=84828, BookCount=1),
#  Row(UserId=92794, BookCount=1),
#  Row(UserId=103319, BookCount=1),
#  Row(UserId=36576, BookCount=1),
#  Row(UserId=55928, BookCount=1),
#  Row(UserId=269639, BookCount=1),
#  Row(UserId=257487, BookCount=1),
#  Row(UserId=126274, BookCount=1),
#  Row(UserId=127111, BookCount=1),
#  Row(UserId=136186, BookCount=1),
#  Row(UserId=132535, BookCount=1),
#  Row(UserId=25909, BookCount=1),
#  Row(UserId=30813, BookCount=1),
#  Row(UserId=25292, BookCount=1),
#  Row(UserId=236762, BookCount=1),
#  Row(UserId=213696, BookCount=1),
#  Row(UserId=85078, BookCount=1),
#  Row(UserId=66826, BookCount=1),
#  Row(UserId=53159, BookCount=1),
#  Row(UserId=35701, BookCount=1),
#  Row(UserId=190907, BookCount=1),
#  Row(UserId=201702, BookCount=1),
#  Row(UserId=209542, BookCount=1),
#  Row(UserId=267169, BookCount=1),
#  Row(UserId=244327, BookCount=1),
#  Row(UserId=273771, BookCount=1),
#  Row(UserId=112773, BookCount=1),
#  Row(UserId=141172, BookCount=1),
#  Row(UserId=5367, BookCount=1),
#  Row(UserId=193, BookCount=1),
#  Row(UserId=31921, BookCount=1),
#  Row(UserId=239845, BookCount=1),
#  Row(UserId=234113, BookCount=1),
#  Row(UserId=239251, BookCount=1),
#  Row(UserId=222842, BookCount=1),
#  Row(UserId=211963, BookCount=1),
#  Row(UserId=235712, BookCount=1),
#  Row(UserId=227062, BookCount=1),
#  Row(UserId=93041, BookCount=1),
#  Row(UserId=46685, BookCount=1),
#  Row(UserId=202653, BookCount=1),
#  Row(UserId=177515, BookCount=1),
#  Row(UserId=188188, BookCount=1),
#  Row(UserId=188397, BookCount=1),
#  Row(UserId=251457, BookCount=1),
#  Row(UserId=258851, BookCount=1),
#  Row(UserId=262295, BookCount=1),
#  Row(UserId=249946, BookCount=1),
#  Row(UserId=117895, BookCount=1),
#  Row(UserId=141231, BookCount=1),
#  Row(UserId=125072, BookCount=1),
#  Row(UserId=141703, BookCount=1),
#  Row(UserId=142494, BookCount=1),
#  Row(UserId=146987, BookCount=1),
#  Row(UserId=166116, BookCount=1),
#  Row(UserId=133010, BookCount=1),
#  Row(UserId=16189, BookCount=1),
#  Row(UserId=21016, BookCount=1),
#  Row(UserId=4865, BookCount=1),
#  Row(UserId=24529, BookCount=1),
#  Row(UserId=32309, BookCount=1),
#  Row(UserId=25446, BookCount=1),
#  Row(UserId=237498, BookCount=1),
#  Row(UserId=230598, BookCount=1),
#  Row(UserId=66667, BookCount=1),
#  Row(UserId=50284, BookCount=1),
#  Row(UserId=65904, BookCount=1),
#  Row(UserId=53075, BookCount=1),
#  Row(UserId=64365, BookCount=1),
#  Row(UserId=59712, BookCount=1),
#  Row(UserId=193138, BookCount=1),
#  Row(UserId=264630, BookCount=1),
#  Row(UserId=275433, BookCount=1),
#  Row(UserId=243524, BookCount=1),
#  Row(UserId=244941, BookCount=1),
#  Row(UserId=248381, BookCount=1),
#  Row(UserId=244427, BookCount=1),
#  Row(UserId=132479, BookCount=1),
#  Row(UserId=118303, BookCount=1),
#  Row(UserId=115330, BookCount=1),
#  Row(UserId=118456, BookCount=1),
#  Row(UserId=157433, BookCount=1),
#  Row(UserId=166737, BookCount=1),
#  Row(UserId=158802, BookCount=1),
#  Row(UserId=152493, BookCount=1),
#  Row(UserId=155336, BookCount=1),
#  Row(UserId=164299, BookCount=1),
#  Row(UserId=173621, BookCount=1),
#  Row(UserId=134172, BookCount=1),
#  Row(UserId=17808, BookCount=1),
#  Row(UserId=228020, BookCount=1),
#  Row(UserId=235023, BookCount=1),
#  Row(UserId=227259, BookCount=1),
#  Row(UserId=229228, BookCount=1),
#  Row(UserId=82750, BookCount=1),
#  Row(UserId=100486, BookCount=1),
#  Row(UserId=74271, BookCount=1),
#  Row(UserId=49825, BookCount=1),
#  Row(UserId=38004, BookCount=1),
#  Row(UserId=66766, BookCount=1),
#  Row(UserId=183418, BookCount=1),
#  Row(UserId=247322, BookCount=1),
#  Row(UserId=252649, BookCount=1),
#  Row(UserId=128034, BookCount=1),
#  Row(UserId=140082, BookCount=1),
#  Row(UserId=121617, BookCount=1),
#  Row(UserId=127257, BookCount=1),
#  Row(UserId=140885, BookCount=1),
#  Row(UserId=170911, BookCount=1),
#  Row(UserId=278446, BookCount=1),
#  Row(UserId=16366, BookCount=1),
#  Row(UserId=21577, BookCount=1),
#  Row(UserId=231592, BookCount=1),
#  Row(UserId=224807, BookCount=1),
#  Row(UserId=224090, BookCount=1),
#  Row(UserId=226969, BookCount=1),
#  Row(UserId=219721, BookCount=1),
#  Row(UserId=92603, BookCount=1),
#  Row(UserId=73148, BookCount=1),
#  Row(UserId=78552, BookCount=1),
#  Row(UserId=80731, BookCount=1),
#  Row(UserId=82209, BookCount=1),
#  Row(UserId=55579, BookCount=1),
#  Row(UserId=69216, BookCount=1),
#  Row(UserId=35567, BookCount=1),
#  Row(UserId=57490, BookCount=1),
#  Row(UserId=59552, BookCount=1),
#  Row(UserId=36439, BookCount=1),
#  Row(UserId=39253, BookCount=1),
#  Row(UserId=36430, BookCount=1),
#  Row(UserId=177939, BookCount=1),
#  Row(UserId=178659, BookCount=1),
#  Row(UserId=245399, BookCount=1),
#  Row(UserId=264871, BookCount=1),
#  Row(UserId=252098, BookCount=1),
#  Row(UserId=141441, BookCount=1),
#  Row(UserId=136233, BookCount=1),
#  Row(UserId=106738, BookCount=1),
#  Row(UserId=116064, BookCount=1),
#  Row(UserId=152537, BookCount=1),
#  Row(UserId=146895, BookCount=1),
#  Row(UserId=160237, BookCount=1),
#  Row(UserId=155208, BookCount=1),
#  Row(UserId=162514, BookCount=1),
#  Row(UserId=156485, BookCount=1),
#  Row(UserId=170104, BookCount=1),
#  Row(UserId=30623, BookCount=1),
#  Row(UserId=21915, BookCount=1),
#  Row(UserId=12286, BookCount=1),
#  Row(UserId=224334, BookCount=1),
#  Row(UserId=100390, BookCount=1),
#  Row(UserId=104463, BookCount=1),
#  Row(UserId=96926, BookCount=1),
#  Row(UserId=46591, BookCount=1),
#  Row(UserId=38003, BookCount=1),
#  Row(UserId=50458, BookCount=1),
#  Row(UserId=53987, BookCount=1),
#  Row(UserId=178590, BookCount=1),
#  Row(UserId=196842, BookCount=1),
#  Row(UserId=209782, BookCount=1),
#  Row(UserId=272248, BookCount=1),
#  Row(UserId=268872, BookCount=1),
#  Row(UserId=140488, BookCount=1),
#  Row(UserId=120064, BookCount=1),
#  Row(UserId=124543, BookCount=1),
#  Row(UserId=109830, BookCount=1),
#  Row(UserId=153798, BookCount=1),
#  Row(UserId=144643, BookCount=1),
#  Row(UserId=147892, BookCount=1),
#  Row(UserId=154083, BookCount=1),
#  Row(UserId=145173, BookCount=1),
#  Row(UserId=183012, BookCount=1),
#  Row(UserId=28598, BookCount=1),
#  Row(UserId=15260, BookCount=1),
#  Row(UserId=28002, BookCount=1),
#  Row(UserId=15588, BookCount=1),
#  Row(UserId=79047, BookCount=1),
#  Row(UserId=82424, BookCount=1),
#  Row(UserId=82629, BookCount=1),
#  Row(UserId=7796, BookCount=1),
#  Row(UserId=53095, BookCount=1),
#  Row(UserId=50891, BookCount=1),
#  Row(UserId=50634, BookCount=1),
#  Row(UserId=69920, BookCount=1),
#  Row(UserId=67784, BookCount=1),
#  Row(UserId=184391, BookCount=1),
#  Row(UserId=271382, BookCount=1),
#  Row(UserId=253046, BookCount=1),
#  Row(UserId=255900, BookCount=1),
#  Row(UserId=259282, BookCount=1),
#  Row(UserId=272859, BookCount=1),
#  Row(UserId=123809, BookCount=1),
#  Row(UserId=128521, BookCount=1),
#  Row(UserId=110604, BookCount=1),
#  Row(UserId=277930, BookCount=1),
#  Row(UserId=218842, BookCount=1),
#  Row(UserId=236503, BookCount=1),
#  Row(UserId=224832, BookCount=1),
#  Row(UserId=83593, BookCount=1),
#  Row(UserId=79117, BookCount=1),
#  Row(UserId=96463, BookCount=1),
#  Row(UserId=39407, BookCount=1),
#  Row(UserId=37599, BookCount=1),
#  Row(UserId=33875, BookCount=1),
#  Row(UserId=208747, BookCount=1),
#  Row(UserId=199471, BookCount=1),
#  Row(UserId=193508, BookCount=1),
#  Row(UserId=196570, BookCount=1),
#  Row(UserId=191389, BookCount=1),
#  Row(UserId=130275, BookCount=1),
#  Row(UserId=115701, BookCount=1),
#  Row(UserId=126921, BookCount=1),
#  Row(UserId=129984, BookCount=1),
#  Row(UserId=161602, BookCount=1),
#  Row(UserId=152570, BookCount=1),
#  Row(UserId=155145, BookCount=1),
#  Row(UserId=152629, BookCount=1),
#  Row(UserId=17312, BookCount=1),
#  Row(UserId=31922, BookCount=1),
#  Row(UserId=14644, BookCount=1),
#  Row(UserId=16015, BookCount=1),
#  Row(UserId=229040, BookCount=1),
#  Row(UserId=222910, BookCount=1),
#  Row(UserId=239951, BookCount=1),
#  Row(UserId=227819, BookCount=1),
#  Row(UserId=78675, BookCount=1),
#  Row(UserId=237787, BookCount=1),
#  Row(UserId=39821, BookCount=1),
#  Row(UserId=52662, BookCount=1),
#  Row(UserId=55269, BookCount=1),
#  Row(UserId=49500, BookCount=1),
#  Row(UserId=56016, BookCount=1),
#  Row(UserId=194901, BookCount=1),
#  Row(UserId=181021, BookCount=1),
#  Row(UserId=175891, BookCount=1),
#  Row(UserId=198003, BookCount=1),
#  Row(UserId=255536, BookCount=1),
#  Row(UserId=134513, BookCount=1),
#  Row(UserId=152200, BookCount=1),
#  Row(UserId=161730, BookCount=1),
#  Row(UserId=161954, BookCount=1),
#  Row(UserId=174548, BookCount=1),
#  Row(UserId=164376, BookCount=1),
#  Row(UserId=146257, BookCount=1),
#  Row(UserId=153567, BookCount=1),
#  Row(UserId=173403, BookCount=1),
#  Row(UserId=5396, BookCount=1),
#  Row(UserId=8303, BookCount=1),
#  Row(UserId=18819, BookCount=1),
#  Row(UserId=227051, BookCount=1),
#  Row(UserId=241649, BookCount=1),
#  Row(UserId=227634, BookCount=1),
#  Row(UserId=223851, BookCount=1),
#  Row(UserId=224538, BookCount=1),
#  Row(UserId=221695, BookCount=1),
#  Row(UserId=218213, BookCount=1),
#  Row(UserId=77113, BookCount=1),
#  Row(UserId=86995, BookCount=1),
#  Row(UserId=103237, BookCount=1),
#  Row(UserId=76428, BookCount=1),
#  Row(UserId=80465, BookCount=1),
#  Row(UserId=73967, BookCount=1),
#  Row(UserId=55683, BookCount=1),
#  Row(UserId=66748, BookCount=1),
#  Row(UserId=45631, BookCount=1),
#  Row(UserId=205449, BookCount=1),
#  Row(UserId=201980, BookCount=1),
#  Row(UserId=185531, BookCount=1),
#  Row(UserId=250932, BookCount=1),
#  Row(UserId=139892, BookCount=1),
#  Row(UserId=119979, BookCount=1),
#  Row(UserId=163394, BookCount=1),
#  Row(UserId=152153, BookCount=1),
#  Row(UserId=153948, BookCount=1),
#  Row(UserId=29401, BookCount=1),
#  Row(UserId=20054, BookCount=1),
#  Row(UserId=31234, BookCount=1),
#  Row(UserId=213789, BookCount=1),
#  Row(UserId=229936, BookCount=1),
#  Row(UserId=105489, BookCount=1),
#  Row(UserId=37615, BookCount=1),
#  Row(UserId=62955, BookCount=1),
#  Row(UserId=38127, BookCount=1),
#  Row(UserId=254403, BookCount=1),
#  Row(UserId=252659, BookCount=1),
#  Row(UserId=270482, BookCount=1),
#  Row(UserId=106918, BookCount=1),
#  Row(UserId=130210, BookCount=1),
#  Row(UserId=122653, BookCount=1),
#  Row(UserId=13477, BookCount=1),
#  Row(UserId=31281, BookCount=1),
#  Row(UserId=2169, BookCount=1),
#  Row(UserId=9716, BookCount=1),
#  Row(UserId=31405, BookCount=1),
#  Row(UserId=217980, BookCount=1),
#  Row(UserId=211286, BookCount=1),
#  Row(UserId=215473, BookCount=1),
#  Row(UserId=88160, BookCount=1),
#  Row(UserId=81518, BookCount=1),
#  Row(UserId=37755, BookCount=1),
#  Row(UserId=60783, BookCount=1),
#  Row(UserId=193920, BookCount=1),
#  Row(UserId=198020, BookCount=1),
#  Row(UserId=206630, BookCount=1),
#  Row(UserId=204521, BookCount=1),
#  Row(UserId=258878, BookCount=1),
#  Row(UserId=249766, BookCount=1),
#  Row(UserId=260956, BookCount=1),
#  Row(UserId=262023, BookCount=1),
#  Row(UserId=247731, BookCount=1),
#  Row(UserId=246081, BookCount=1),
#  Row(UserId=136967, BookCount=1),
#  Row(UserId=113912, BookCount=1),
#  Row(UserId=112727, BookCount=1),
#  Row(UserId=129779, BookCount=1),
#  Row(UserId=152909, BookCount=1),
#  Row(UserId=165449, BookCount=1),
#  Row(UserId=168093, BookCount=1),
#  Row(UserId=19010, BookCount=1),
#  Row(UserId=28913, BookCount=1),
#  Row(UserId=2804, BookCount=1),
#  Row(UserId=278431, BookCount=1),
#  Row(UserId=9873, BookCount=1),
#  Row(UserId=106199, BookCount=1),
#  Row(UserId=79882, BookCount=1),
#  Row(UserId=84027, BookCount=1),
#  Row(UserId=43175, BookCount=1),
#  Row(UserId=195084, BookCount=1),
#  Row(UserId=195264, BookCount=1),
#  Row(UserId=181494, BookCount=1),
#  Row(UserId=247024, BookCount=1),
#  Row(UserId=259404, BookCount=1),
#  Row(UserId=117287, BookCount=1),
#  Row(UserId=133280, BookCount=1),
#  Row(UserId=169726, BookCount=1),
#  Row(UserId=160926, BookCount=1),
#  Row(UserId=27560, BookCount=1),
#  Row(UserId=1398, BookCount=1),
#  Row(UserId=33480, BookCount=1),
#  Row(UserId=31550, BookCount=1),
#  Row(UserId=226434, BookCount=1),
#  Row(UserId=85145, BookCount=1),
#  Row(UserId=97107, BookCount=1),
#  Row(UserId=43787, BookCount=1),
#  Row(UserId=37491, BookCount=1),
#  Row(UserId=63139, BookCount=1),
#  Row(UserId=206505, BookCount=1),
#  Row(UserId=255294, BookCount=1),
#  Row(UserId=127488, BookCount=1),
#  Row(UserId=120531, BookCount=1),
#  Row(UserId=20342, BookCount=1),
#  Row(UserId=29320, BookCount=1),
#  Row(UserId=217372, BookCount=1),
#  Row(UserId=218657, BookCount=1),
#  Row(UserId=228253, BookCount=1),
#  Row(UserId=97990, BookCount=1),
#  Row(UserId=95487, BookCount=1),
#  Row(UserId=58225, BookCount=1),
#  Row(UserId=46360, BookCount=1),
#  Row(UserId=42130, BookCount=1),
#  Row(UserId=36198, BookCount=1),
#  Row(UserId=41656, BookCount=1),
#  Row(UserId=58838, BookCount=1),
#  Row(UserId=204418, BookCount=1),
#  Row(UserId=195199, BookCount=1),
#  Row(UserId=254055, BookCount=1),
#  Row(UserId=270877, BookCount=1),
#  Row(UserId=245363, BookCount=1),
#  Row(UserId=265325, BookCount=1),
#  Row(UserId=244283, BookCount=1),
#  Row(UserId=137103, BookCount=1),
#  Row(UserId=135737, BookCount=1),
#  Row(UserId=166618, BookCount=1),
#  Row(UserId=149663, BookCount=1),
#  Row(UserId=170474, BookCount=1),
#  Row(UserId=151031, BookCount=1),
#  Row(UserId=167648, BookCount=1),
#  Row(UserId=31348, BookCount=1),
#  Row(UserId=33679, BookCount=1),
#  Row(UserId=32254, BookCount=1),
#  Row(UserId=4033, BookCount=1),
#  Row(UserId=29698, BookCount=1),
#  Row(UserId=33100, BookCount=1),
#  Row(UserId=235706, BookCount=1),
#  Row(UserId=218756, BookCount=1),
#  Row(UserId=233413, BookCount=1),
#  Row(UserId=241500, BookCount=1),
#  Row(UserId=98703, BookCount=1),
#  Row(UserId=79697, BookCount=1),
#  Row(UserId=38608, BookCount=1),
#  Row(UserId=49718, BookCount=1),
#  Row(UserId=265109, BookCount=1),
#  Row(UserId=274010, BookCount=1),
#  Row(UserId=271853, BookCount=1),
#  Row(UserId=276067, BookCount=1),
#  Row(UserId=276056, BookCount=1),
#  Row(UserId=111831, BookCount=1),
#  Row(UserId=141300, BookCount=1),
#  Row(UserId=122466, BookCount=1),
#  Row(UserId=12232, BookCount=1),
#  Row(UserId=5062, BookCount=1),
#  Row(UserId=19212, BookCount=1),
#  Row(UserId=221414, BookCount=1),
#  Row(UserId=222242, BookCount=1),
#  Row(UserId=234255, BookCount=1),
#  Row(UserId=81992, BookCount=1),
#  Row(UserId=90564, BookCount=1),
#  Row(UserId=58716, BookCount=1),
#  Row(UserId=68480, BookCount=1),
#  Row(UserId=201819, BookCount=1),
#  Row(UserId=200936, BookCount=1),
#  Row(UserId=276255, BookCount=1),
#  Row(UserId=173935, BookCount=1),
#  Row(UserId=16394, BookCount=1),
#  Row(UserId=23390, BookCount=1),
#  Row(UserId=19589, BookCount=1),
#  Row(UserId=236161, BookCount=1),
#  Row(UserId=230790, BookCount=1),
#  Row(UserId=222289, BookCount=1),
#  Row(UserId=84744, BookCount=1),
#  Row(UserId=106288, BookCount=1),
#  Row(UserId=73844, BookCount=1),
#  Row(UserId=66288, BookCount=1),
#  Row(UserId=56071, BookCount=1),
#  Row(UserId=201461, BookCount=1),
#  Row(UserId=181595, BookCount=1),
#  Row(UserId=203456, BookCount=1),
#  Row(UserId=196237, BookCount=1),
#  Row(UserId=266798, BookCount=1),
#  Row(UserId=110346, BookCount=1),
#  Row(UserId=137997, BookCount=1),
#  Row(UserId=168836, BookCount=1),
#  Row(UserId=163382, BookCount=1),
#  Row(UserId=142420, BookCount=1),
#  Row(UserId=169523, BookCount=1),
#  Row(UserId=31632, BookCount=1),
#  Row(UserId=16609, BookCount=1),
#  Row(UserId=2668, BookCount=1),
#  Row(UserId=29518, BookCount=1),
#  Row(UserId=28856, BookCount=1),
#  Row(UserId=211147, BookCount=1),
#  Row(UserId=240017, BookCount=1),
#  Row(UserId=84877, BookCount=1),
#  Row(UserId=73259, BookCount=1),
#  Row(UserId=101727, BookCount=1),
#  Row(UserId=52804, BookCount=1),
#  Row(UserId=43364, BookCount=1),
#  Row(UserId=46988, BookCount=1),
#  Row(UserId=52038, BookCount=1),
#  Row(UserId=56641, BookCount=1),
#  Row(UserId=194632, BookCount=1),
#  Row(UserId=110037, BookCount=1),
#  Row(UserId=122025, BookCount=1),
#  Row(UserId=134939, BookCount=1),
#  Row(UserId=133291, BookCount=1),
#  Row(UserId=141009, BookCount=1),
#  Row(UserId=153759, BookCount=1),
#  Row(UserId=168890, BookCount=1),
#  Row(UserId=164844, BookCount=1),
#  Row(UserId=3586, BookCount=1),
#  Row(UserId=20628, BookCount=1),
#  Row(UserId=215560, BookCount=1),
#  Row(UserId=84508, BookCount=1),
#  Row(UserId=83819, BookCount=1),
#  Row(UserId=54526, BookCount=1),
#  Row(UserId=64592, BookCount=1),
#  Row(UserId=46696, BookCount=1),
#  Row(UserId=36226, BookCount=1),
#  Row(UserId=65131, BookCount=1),
#  Row(UserId=36963, BookCount=1),
#  Row(UserId=185230, BookCount=1),
#  Row(UserId=178991, BookCount=1),
#  Row(UserId=192724, BookCount=1),
#  Row(UserId=203779, BookCount=1),
#  Row(UserId=196063, BookCount=1),
#  Row(UserId=256979, BookCount=1),
#  Row(UserId=248127, BookCount=1),
#  Row(UserId=109377, BookCount=1),
#  Row(UserId=132164, BookCount=1),
#  Row(UserId=123445, BookCount=1),
#  Row(UserId=173592, BookCount=1),
#  Row(UserId=160137, BookCount=1),
#  Row(UserId=154416, BookCount=1),
#  Row(UserId=3200, BookCount=1),
#  Row(UserId=29263, BookCount=1),
#  Row(UserId=27775, BookCount=1),
#  Row(UserId=17785, BookCount=1),
#  Row(UserId=240471, BookCount=1),
#  Row(UserId=216852, BookCount=1),
#  Row(UserId=101571, BookCount=1),
#  Row(UserId=59527, BookCount=1),
#  Row(UserId=50937, BookCount=1),
#  Row(UserId=187778, BookCount=1),
#  Row(UserId=209421, BookCount=1),
#  Row(UserId=195170, BookCount=1),
#  Row(UserId=197796, BookCount=1),
#  Row(UserId=245535, BookCount=1),
#  Row(UserId=244797, BookCount=1),
#  Row(UserId=242926, BookCount=1),
#  Row(UserId=249721, BookCount=1),
#  Row(UserId=265197, BookCount=1),
#  Row(UserId=255516, BookCount=1),
#  Row(UserId=258149, BookCount=1),
#  Row(UserId=271626, BookCount=1),
#  Row(UserId=250070, BookCount=1),
#  Row(UserId=121143, BookCount=1),
#  Row(UserId=117116, BookCount=1),
#  Row(UserId=110486, BookCount=1),
#  Row(UserId=159752, BookCount=1),
#  Row(UserId=172608, BookCount=1),
#  Row(UserId=160475, BookCount=1),
#  Row(UserId=161746, BookCount=1),
#  Row(UserId=162577, BookCount=1),
#  Row(UserId=27084, BookCount=1),
#  Row(UserId=221650, BookCount=1),
#  Row(UserId=92375, BookCount=1),
#  Row(UserId=91498, BookCount=1),
#  Row(UserId=38853, BookCount=1),
#  Row(UserId=200875, BookCount=1),
#  Row(UserId=194399, BookCount=1),
#  Row(UserId=198886, BookCount=1),
#  Row(UserId=182933, BookCount=1),
#  Row(UserId=263017, BookCount=1),
#  Row(UserId=150682, BookCount=1),
#  Row(UserId=142794, BookCount=1),
#  Row(UserId=148196, BookCount=1),
#  Row(UserId=158290, BookCount=1),
#  Row(UserId=3884, BookCount=1),
#  Row(UserId=91906, BookCount=1),
#  Row(UserId=104138, BookCount=1),
#  Row(UserId=83026, BookCount=1),
#  Row(UserId=72744, BookCount=1),
#  Row(UserId=90235, BookCount=1),
#  Row(UserId=39870, BookCount=1),
#  Row(UserId=62485, BookCount=1),
#  Row(UserId=184423, BookCount=1),
#  Row(UserId=177193, BookCount=1),
#  Row(UserId=203858, BookCount=1),
#  Row(UserId=265785, BookCount=1),
#  Row(UserId=247492, BookCount=1),
#  Row(UserId=258360, BookCount=1),
#  Row(UserId=130339, BookCount=1),
#  Row(UserId=129767, BookCount=1),
#  Row(UserId=135832, BookCount=1),
#  Row(UserId=164098, BookCount=1),
#  Row(UserId=159181, BookCount=1),
#  Row(UserId=165779, BookCount=1),
#  Row(UserId=166305, BookCount=1),
#  Row(UserId=22397, BookCount=1),
#  Row(UserId=22755, BookCount=1),
#  Row(UserId=30881, BookCount=1),
#  Row(UserId=278204, BookCount=1),
#  Row(UserId=222715, BookCount=1),
#  Row(UserId=211609, BookCount=1),
#  Row(UserId=79608, BookCount=1),
#  Row(UserId=102933, BookCount=1),
#  Row(UserId=105029, BookCount=1),
#  Row(UserId=96824, BookCount=1),
#  Row(UserId=83607, BookCount=1),
#  Row(UserId=68178, BookCount=1),
#  Row(UserId=37946, BookCount=1),
#  Row(UserId=206303, BookCount=1),
#  Row(UserId=180463, BookCount=1),
#  Row(UserId=256726, BookCount=1),
#  Row(UserId=274209, BookCount=1),
#  Row(UserId=274270, BookCount=1),
#  Row(UserId=243618, BookCount=1),
#  Row(UserId=249449, BookCount=1),
#  Row(UserId=120980, BookCount=1),
#  Row(UserId=123343, BookCount=1),
#  Row(UserId=108096, BookCount=1),
#  Row(UserId=139841, BookCount=1),
#  Row(UserId=163906, BookCount=1),
#  Row(UserId=158169, BookCount=1),
#  Row(UserId=166510, BookCount=1),
#  Row(UserId=10269, BookCount=1),
#  Row(UserId=30584, BookCount=1),
#  Row(UserId=224, BookCount=1),
#  Row(UserId=13229, BookCount=1),
#  Row(UserId=23545, BookCount=1),
#  Row(UserId=236241, BookCount=1),
#  Row(UserId=217243, BookCount=1),
#  Row(UserId=239075, BookCount=1),
#  Row(UserId=212036, BookCount=1),
#  Row(UserId=236639, BookCount=1),
#  Row(UserId=99097, BookCount=1),
#  Row(UserId=94753, BookCount=1),
#  Row(UserId=73135, BookCount=1),
#  Row(UserId=52618, BookCount=1),
#  Row(UserId=49493, BookCount=1),
#  Row(UserId=203596, BookCount=1),
#  Row(UserId=191777, BookCount=1),
#  Row(UserId=205276, BookCount=1),
#  Row(UserId=194934, BookCount=1),
#  Row(UserId=249957, BookCount=1),
#  Row(UserId=131413, BookCount=1),
#  Row(UserId=124287, BookCount=1),
#  Row(UserId=156177, BookCount=1),
#  Row(UserId=168052, BookCount=1),
#  Row(UserId=171146, BookCount=1),
#  Row(UserId=17049, BookCount=1),
#  Row(UserId=32100, BookCount=1),
#  Row(UserId=18900, BookCount=1),
#  Row(UserId=20413, BookCount=1),
#  Row(UserId=24498, BookCount=1),
#  Row(UserId=236826, BookCount=1),
#  Row(UserId=91241, BookCount=1),
#  Row(UserId=89283, BookCount=1),
#  Row(UserId=76940, BookCount=1),
#  Row(UserId=55345, BookCount=1),
#  Row(UserId=68808, BookCount=1),
#  Row(UserId=52752, BookCount=1),
#  Row(UserId=178748, BookCount=1),
#  Row(UserId=244383, BookCount=1),
#  Row(UserId=137152, BookCount=1),
#  Row(UserId=125562, BookCount=1),
#  Row(UserId=134919, BookCount=1),
#  Row(UserId=135483, BookCount=1),
#  Row(UserId=28115, BookCount=1),
#  Row(UserId=10166, BookCount=1),
#  Row(UserId=33753, BookCount=1),
#  Row(UserId=211515, BookCount=1),
#  Row(UserId=236531, BookCount=1),
#  Row(UserId=223224, BookCount=1),
#  Row(UserId=72725, BookCount=1),
#  Row(UserId=97926, BookCount=1),
#  Row(UserId=101732, BookCount=1),
#  Row(UserId=91759, BookCount=1),
#  Row(UserId=58282, BookCount=1),
#  Row(UserId=70220, BookCount=1),
#  Row(UserId=41305, BookCount=1),
#  Row(UserId=61982, BookCount=1),
#  Row(UserId=183174, BookCount=1),
#  Row(UserId=206811, BookCount=1),
#  Row(UserId=182950, BookCount=1),
#  Row(UserId=190154, BookCount=1),
#  Row(UserId=189349, BookCount=1),
#  Row(UserId=186835, BookCount=1),
#  Row(UserId=207565, BookCount=1),
#  Row(UserId=248097, BookCount=1),
#  Row(UserId=274750, BookCount=1),
#  Row(UserId=245285, BookCount=1),
#  Row(UserId=264932, BookCount=1),
#  Row(UserId=249968, BookCount=1),
#  Row(UserId=243229, BookCount=1),
#  Row(UserId=269161, BookCount=1),
#  Row(UserId=243913, BookCount=1),
#  Row(UserId=139975, BookCount=1),
#  Row(UserId=168378, BookCount=1),
#  Row(UserId=151362, BookCount=1),
#  Row(UserId=23560, BookCount=1),
#  Row(UserId=14681, BookCount=1),
#  Row(UserId=4733, BookCount=1),
#  Row(UserId=21225, BookCount=1),
#  Row(UserId=21955, BookCount=1),
#  Row(UserId=16754, BookCount=1),
#  Row(UserId=277817, BookCount=1),
#  Row(UserId=132, BookCount=1),
#  Row(UserId=72833, BookCount=1),
#  Row(UserId=91548, BookCount=1),
#  Row(UserId=103673, BookCount=1),
#  Row(UserId=45587, BookCount=1),
#  Row(UserId=55222, BookCount=1),
#  Row(UserId=52116, BookCount=1),
#  Row(UserId=44116, BookCount=1),
#  Row(UserId=43985, BookCount=1),
#  Row(UserId=51019, BookCount=1),
#  Row(UserId=35786, BookCount=1),
#  Row(UserId=42495, BookCount=1),
#  Row(UserId=52112, BookCount=1),
#  Row(UserId=40385, BookCount=1),
#  Row(UserId=50492, BookCount=1),
#  Row(UserId=68398, BookCount=1),
#  Row(UserId=201616, BookCount=1),
#  Row(UserId=201710, BookCount=1),
#  Row(UserId=181871, BookCount=1),
#  Row(UserId=183064, BookCount=1),
#  Row(UserId=200392, BookCount=1),
#  Row(UserId=182703, BookCount=1),
#  Row(UserId=131183, BookCount=1),
#  Row(UserId=114558, BookCount=1),
#  Row(UserId=112137, BookCount=1),
#  Row(UserId=132078, BookCount=1),
#  Row(UserId=152787, BookCount=1),
#  Row(UserId=27041, BookCount=1),
#  Row(UserId=212609, BookCount=1),
#  Row(UserId=237432, BookCount=1),
#  Row(UserId=211167, BookCount=1),
#  Row(UserId=103911, BookCount=1),
#  Row(UserId=82923, BookCount=1),
#  Row(UserId=93642, BookCount=1),
#  Row(UserId=74949, BookCount=1),
#  Row(UserId=79388, BookCount=1),
#  Row(UserId=60274, BookCount=1),
#  Row(UserId=58032, BookCount=1),
#  Row(UserId=61951, BookCount=1),
#  Row(UserId=206203, BookCount=1),
#  Row(UserId=189220, BookCount=1),
#  Row(UserId=200710, BookCount=1),
#  Row(UserId=269017, BookCount=1),
#  Row(UserId=270891, BookCount=1),
#  Row(UserId=254778, BookCount=1),
#  Row(UserId=256024, BookCount=1),
#  Row(UserId=121360, BookCount=1),
#  Row(UserId=107045, BookCount=1),
#  Row(UserId=127365, BookCount=1),
#  Row(UserId=173249, BookCount=1),
#  Row(UserId=159030, BookCount=1),
#  Row(UserId=147841, BookCount=1),
#  Row(UserId=152846, BookCount=1),
#  Row(UserId=129661, BookCount=1),
#  Row(UserId=159432, BookCount=1),
#  Row(UserId=2219, BookCount=1),
#  Row(UserId=21869, BookCount=1),
#  Row(UserId=28015, BookCount=1),
#  Row(UserId=25778, BookCount=1),
#  Row(UserId=239947, BookCount=1),
#  Row(UserId=228384, BookCount=1),
#  Row(UserId=226990, BookCount=1),
#  Row(UserId=241520, BookCount=1),
#  Row(UserId=75090, BookCount=1),
#  Row(UserId=61615, BookCount=1),
#  Row(UserId=39884, BookCount=1),
#  Row(UserId=69772, BookCount=1),
#  Row(UserId=186472, BookCount=1),
#  Row(UserId=175531, BookCount=1),
#  Row(UserId=180473, BookCount=1),
#  Row(UserId=177778, BookCount=1),
#  Row(UserId=200420, BookCount=1),
#  Row(UserId=209644, BookCount=1),
#  Row(UserId=246394, BookCount=1),
#  Row(UserId=256324, BookCount=1),
#  Row(UserId=266121, BookCount=1),
#  Row(UserId=269014, BookCount=1),
#  Row(UserId=124638, BookCount=1),
#  Row(UserId=115098, BookCount=1),
#  Row(UserId=148175, BookCount=1),
#  Row(UserId=159584, BookCount=1),
#  Row(UserId=173108, BookCount=1),
#  Row(UserId=173051, BookCount=1),
#  Row(UserId=16236, BookCount=1),
#  Row(UserId=4524, BookCount=1),
#  Row(UserId=29069, BookCount=1),
#  Row(UserId=15064, BookCount=1),
#  Row(UserId=21280, BookCount=1),
#  Row(UserId=218377, BookCount=1),
#  Row(UserId=241465, BookCount=1),
#  Row(UserId=104183, BookCount=1),
#  Row(UserId=100888, BookCount=1),
#  Row(UserId=50753, BookCount=1),
#  Row(UserId=51145, BookCount=1),
#  Row(UserId=69734, BookCount=1),
#  Row(UserId=38481, BookCount=1),
#  Row(UserId=190332, BookCount=1),
#  Row(UserId=200690, BookCount=1),
#  Row(UserId=191146, BookCount=1),
#  Row(UserId=203122, BookCount=1),
#  Row(UserId=187882, BookCount=1),
#  Row(UserId=252570, BookCount=1),
#  Row(UserId=268721, BookCount=1),
#  Row(UserId=269370, BookCount=1),
#  Row(UserId=128799, BookCount=1),
#  Row(UserId=113117, BookCount=1),
#  Row(UserId=110143, BookCount=1),
#  Row(UserId=136064, BookCount=1),
#  Row(UserId=168161, BookCount=1),
#  Row(UserId=171283, BookCount=1),
#  Row(UserId=155909, BookCount=1),
#  Row(UserId=172926, BookCount=1),
#  Row(UserId=6720, BookCount=1),
#  Row(UserId=277243, BookCount=1),
#  Row(UserId=31023, BookCount=1),
#  Row(UserId=237189, BookCount=1),
#  Row(UserId=229194, BookCount=1),
#  Row(UserId=96820, BookCount=1),
#  Row(UserId=100649, BookCount=1),
#  Row(UserId=100370, BookCount=1),
#  Row(UserId=101594, BookCount=1),
#  Row(UserId=74622, BookCount=1),
#  Row(UserId=41015, BookCount=1),
#  Row(UserId=48669, BookCount=1),
#  Row(UserId=49001, BookCount=1),
#  Row(UserId=62195, BookCount=1),
#  Row(UserId=43412, BookCount=1),
#  Row(UserId=204581, BookCount=1),
#  Row(UserId=194816, BookCount=1),
#  Row(UserId=255683, BookCount=1),
#  Row(UserId=261677, BookCount=1),
#  Row(UserId=265339, BookCount=1),
#  Row(UserId=253999, BookCount=1),
#  Row(UserId=136752, BookCount=1),
#  Row(UserId=128580, BookCount=1),
#  ...]
